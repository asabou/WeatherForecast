# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import pickle
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option("display.max_columns",None)

# %%
#Import Data Set
rain = pd.read_csv('weatherAUS.csv')

# %%
rain.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0           W           44.0          W        WNW          20.0
# 1         WNW           44.0        NNW        WSW           4.0
# 2         WSW           46.0          W        WSW          19.0
# 3          NE           24.0         SE          E          11.0
# 4           W           41.0        ENE         NW           7.0
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# 0          24.0         71.0         22.0       1007.7       1007.1       8.0
# 1          22.0         44.0         25.0       1010.6       1007.8       NaN
# 2          26.0         38.0         30.0       1007.6       1008.7       NaN
# 3           9.0         45.0         16.0       1017.6       1012.8       NaN
# 4          20.0         82.0         33.0       1010.8       1006.0       7.0
#
#    Cloud3pm  Temp9am  Temp3pm RainToday RainTomorrow
# 0       NaN     16.9     21.8        No           No
# 1       NaN     17.2     24.3        No           No
# 2       2.0     21.0     23.2        No           No
# 3       NaN     18.1     26.5        No           No
# 4       8.0     17.8     29.7        No           No

# %%
#Data Preprocessing
rain.shape
# Out:
# (145460, 23)

# %%
rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %%
#categorical data:
categorical_features = [column_name for column_name in rain.columns if rain[column_name].dtype == 'O']
print("Number of Categorical Features: {}".format(len(categorical_features)))
print("Categorical Features: ",categorical_features)
# Out:
# Number of Categorical Features: 7
# Categorical Features:  ['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
#Numerical Features:

numerical_features = [column_name for column_name in rain.columns if rain[column_name].dtype != 'O']

#rain.select_dtypes(include=['float64','int64']).columns 

print("Number of Numerical Features: {}".format(len(numerical_features)))
print("Numerical Features: ",numerical_features)
# Out:
# Number of Numerical Features: 16
# Numerical Features:  ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %%
Cardinality check for Categorical Features:`

Some Machine Learning algorithms e.g. Logistic Regression, Support Vector Machine can not handle categorical variables and expect all variables to be numeric.
So, categorical data needs to be encoded to numerical data. Before encoding, we need to make sure that categorical features has minimum cardinality.
Cardinality: The number of unique values in feature column is known as cardinality. Example: A column with hundreds of zip codes is an example of a high cardinality feature
A high number of unique values within a feature column is known as high cardinality.
High cardinality may pose some serious problems in the machine learning model.
If a feature column as high cardinality, when we use encoding techniques, then that may cause a significant increase number of dimensions, which is not a good for machine learning problems.
If there is high cardinality in feature column, then:

1) Employ Feature Engineering to extract new features from the feature which possess high cardinality. (or)

2) Simply drop the feature, if that feature doesn't add value to model.

# %%
#Finding cardinality of categorical features:

for each_feature in categorical_features:
    print("Cardinality(no. of unique values) of {} are: {}".format(each_feature,len(rain[each_feature].unique())))
# Out:
# Cardinality(no. of unique values) of Date are: 3436
# Cardinality(no. of unique values) of Location are: 49
# Cardinality(no. of unique values) of WindGustDir are: 17
# Cardinality(no. of unique values) of WindDir9am are: 17
# Cardinality(no. of unique values) of WindDir3pm are: 17
# Cardinality(no. of unique values) of RainToday are: 3
# Cardinality(no. of unique values) of RainTomorrow are: 3

# %%
Date column has high cardinality which poses several problems to ml model in terms of efficency and also dimenionality of data also increases when converted to numerical data.

Feature enginerring of Date column to decrease high cardinality.

# %%
#Type conversion of Date Column to datetime type:
rain['Date'] = pd.to_datetime(rain['Date'])

# %%
rain['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
rain['year'] = rain['Date'].dt.year
rain['month'] = rain['Date'].dt.month
rain['day'] = rain['Date'].dt.day

# %%
rain.drop('Date', axis = 1, inplace = True)

# %%
rain.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6          NaN       NaN           W
# 1   Albury      7.4     25.1       0.0          NaN       NaN         WNW
# 2   Albury     12.9     25.7       0.0          NaN       NaN         WSW
# 3   Albury      9.2     28.0       0.0          NaN       NaN          NE
# 4   Albury     17.5     32.3       1.0          NaN       NaN           W
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0           44.0          W        WNW          20.0          24.0
# 1           44.0        NNW        WSW           4.0          22.0
# 2           46.0          W        WSW          19.0          26.0
# 3           24.0         SE          E          11.0           9.0
# 4           41.0        ENE         NW           7.0          20.0
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0         71.0         22.0       1007.7       1007.1       8.0       NaN
# 1         44.0         25.0       1010.6       1007.8       NaN       NaN
# 2         38.0         30.0       1007.6       1008.7       NaN       2.0
# 3         45.0         16.0       1017.6       1012.8       NaN       NaN
# 4         82.0         33.0       1010.8       1006.0       7.0       8.0
#
#    Temp9am  Temp3pm RainToday RainTomorrow  year  month  day
# 0     16.9     21.8        No           No  2008     12    1
# 1     17.2     24.3        No           No  2008     12    2
# 2     21.0     23.2        No           No  2008     12    3
# 3     18.1     26.5        No           No  2008     12    4
# 4     17.8     29.7        No           No  2008     12    5

# %%
` Null (or) NaN (or) Missing Values in Data:`

The real-world data often has a lot of missing(or null) values. The cause of missing values can be data corruption or failure to record data. The handling of missing data is very important during the preprocessing of the dataset as many machine learning algorithms do not support missing values.

# %%
#Handling Null values in categorical features:`
#categorical data: 

categorical_features = [column_name for column_name in rain.columns if rain[column_name].dtype == 'O']
print("Number of Categorical Features: {}".format(len(categorical_features)))
print("Categorical Features: ",categorical_features)
# Out:
# Number of Categorical Features: 6
# Categorical Features:  ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
#Numerical Features:

numerical_features = [column_name for column_name in rain.columns if rain[column_name].dtype != 'O']
#rain.select_dtypes(include=['float64','int64']).columns 
print("Number of Numerical Features: {}".format(len(numerical_features)))
print("Numerical Features: ",numerical_features)
# Out:
# Number of Numerical Features: 19
# Numerical Features:  ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'year', 'month', 'day']

# %%
#Checking for Null values:
rain[categorical_features].isnull().sum()
# Out:
# Location            0
# WindGustDir     10326
# WindDir9am      10566
# WindDir3pm       4228
# RainToday        3261
# RainTomorrow     3267
# dtype: int64

# %%
# list of categorical features which has null values:

categorical_features_with_null = [feature for feature in categorical_features if rain[feature].isnull().sum()]

# %%
#Filling the missing(Null) categorical features with most frequent value(mode)
for each_feature in categorical_features_with_null:
    mode_val = rain[each_feature].mode()[0]
    rain[each_feature].fillna(mode_val,inplace=True)

# %%
rain[categorical_features].isnull().sum()
# Out:
# Location        0
# WindGustDir     0
# WindDir9am      0
# WindDir3pm      0
# RainToday       0
# RainTomorrow    0
# dtype: int64

# %%
#Handling Null values in numerical features:`
#Checking null values in numerical features
rain[numerical_features].isnull().sum()
# Out:
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustSpeed    10263
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# year                 0
# month                0
# day                  0
# dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(rain[numerical_features].isnull(),linecolor='white')
# Out:
# <AxesSubplot:>

# %%
# visualizing the Null values in Numerical Features:
rain[numerical_features].isnull().sum().sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
Null values in Numerical Features can be imputed using Mean and Median. Mean is sensitive to outliers and median is immune to outliers. If you want to impute the null values with mean values, then outliers in numerical features need to be addressed properly.

# %%
#Checking for outliers using Box Plot:
for feature in numerical_features:
    plt.figure(figsize=(10,10))
    sns.boxplot(rain[feature])
    plt.title(feature)

# %%
#Checking for outliers using the statistical formulas:
rain[numerical_features].describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm   Pressure9am    Pressure3pm  \
# count  142806.000000  140953.000000  130395.00000  130432.000000
# mean       68.880831      51.539116    1017.64994    1015.255889
# std        19.029164      20.795902       7.10653       7.037414
# min         0.000000       0.000000     980.50000     977.100000
# 25%        57.000000      37.000000    1012.90000    1010.400000
# 50%        70.000000      52.000000    1017.60000    1015.200000
# 75%        83.000000      66.000000    1022.40000    1020.000000
# max       100.000000     100.000000    1041.00000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am       Temp3pm           year  \
# count  89572.000000  86102.000000  143693.000000  141851.00000  145460.000000
# mean       4.447461      4.509930      16.990631      21.68339    2012.769751
# std        2.887159      2.720357       6.488753       6.93665       2.537684
# min        0.000000      0.000000      -7.200000      -5.40000    2007.000000
# 25%        1.000000      2.000000      12.300000      16.60000    2011.000000
# 50%        5.000000      5.000000      16.700000      21.10000    2013.000000
# 75%        7.000000      7.000000      21.600000      26.40000    2015.000000
# max        9.000000      9.000000      40.200000      46.70000    2017.000000
#
#                month            day
# count  145460.000000  145460.000000
# mean        6.399615      15.712258
# std         3.427262       8.794789
# min         1.000000       1.000000
# 25%         3.000000       8.000000
# 50%         6.000000      16.000000
# 75%         9.000000      23.000000
# max        12.000000      31.000000

# %%
#Outlier Treatment to remove outliers from Numerical Features:
# features which have outliers:
features_with_outliers = ['MinTemp','MaxTemp','Rainfall','Evaporation','Sunshine','WindGustSpeed','WindSpeed9am','WindSpeed3pm','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm','Cloud9am','Cloud3pm','Temp9am','Temp3pm','Humidity9am', 'Pressure9am', 'year','month','day']

# %%
#Replacing outliers using IQR:
for feature in features_with_outliers:
    q1 = rain[feature].quantile(0.25)
    q3 = rain[feature].quantile(0.75)
    IQR = q3-q1
    lower_limit = q1 - (IQR*1.5)
    upper_limit = q3 + (IQR*1.5)
    rain.loc[rain[feature]<lower_limit,feature] = lower_limit
    rain.loc[rain[feature]>upper_limit,feature] = upper_limit

# %%
for feature in numerical_features:
    plt.figure(figsize=(10,10))
    sns.boxplot(rain[feature])
    plt.title(feature)

# %%
#Imputing null values in numerical features using mean:
# list of numerical Features with Null values:
numerical_features_with_null = [feature for feature in numerical_features if rain[feature].isnull().sum()]
numerical_features_with_null
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm']

# %%
#Filling null values uisng mean: 
for feature in numerical_features_with_null:
    mean_value = rain[feature].mean()
    rain[feature].fillna(mean_value,inplace=True)

# %%
rain.isnull().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# year             0
# month            0
# day              0
# dtype: int64

# %%
rain.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6     5.318667  7.611178           W
# 1   Albury      7.4     25.1       0.0     5.318667  7.611178         WNW
# 2   Albury     12.9     25.7       0.0     5.318667  7.611178         WSW
# 3   Albury      9.2     28.0       0.0     5.318667  7.611178          NE
# 4   Albury     17.5     32.3       1.0     5.318667  7.611178           W
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0           44.0          W        WNW          20.0          24.0
# 1           44.0        NNW        WSW           4.0          22.0
# 2           46.0          W        WSW          19.0          26.0
# 3           24.0         SE          E          11.0           9.0
# 4           41.0        ENE         NW           7.0          20.0
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0         71.0         22.0       1007.7       1007.1  8.000000   4.50993
# 1         44.0         25.0       1010.6       1007.8  4.447461   4.50993
# 2         38.0         30.0       1007.6       1008.7  4.447461   2.00000
# 3         45.0         16.0       1017.6       1012.8  4.447461   4.50993
# 4         82.0         33.0       1010.8       1006.0  7.000000   8.00000
#
#    Temp9am  Temp3pm RainToday RainTomorrow  year  month  day
# 0     16.9     21.8        No           No  2008     12  1.0
# 1     17.2     24.3        No           No  2008     12  2.0
# 2     21.0     23.2        No           No  2008     12  3.0
# 3     18.1     26.5        No           No  2008     12  4.0
# 4     17.8     29.7        No           No  2008     12  5.0

# %%
#Univariate Analysis`

#Exploring RainTomorrow label
rain['RainTomorrow'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
Looks like Target variable is imbalanced. It has more 'No' values. If data is imbalanced, then it might decrease performance of model. As this data is released by the meteorological department of Australia, it doesn't make any sense when we try to balance target variable, because the truthfullness of data might descreases. So, let me keep it as it is.

# %%
#Exploring RainToday Variable:
sns.countplot(data=rain, x="RainToday")
plt.grid(linewidth = 0.5)
plt.show()

# %%
#Multivariate Analysis`
plt.figure(figsize=(20,10))
ax = sns.countplot(x="Location", hue="RainTomorrow", data=rain)

# %%
sns.lineplot(data=rain,x='Sunshine',y='Rainfall',color='goldenrod')
# Out:
# <AxesSubplot:xlabel='Sunshine', ylabel='Rainfall'>

# %%
num_features = ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']
rain[num_features].hist(bins=10,figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'MinTemp'}>,
#         <AxesSubplot:title={'center':'MaxTemp'}>,
#         <AxesSubplot:title={'center':'Rainfall'}>,
#         <AxesSubplot:title={'center':'Evaporation'}>],
#        [<AxesSubplot:title={'center':'Sunshine'}>,
#         <AxesSubplot:title={'center':'WindGustSpeed'}>,
#         <AxesSubplot:title={'center':'WindSpeed9am'}>,
#         <AxesSubplot:title={'center':'WindSpeed3pm'}>],
#        [<AxesSubplot:title={'center':'Humidity9am'}>,
#         <AxesSubplot:title={'center':'Humidity3pm'}>,
#         <AxesSubplot:title={'center':'Pressure9am'}>,
#         <AxesSubplot:title={'center':'Pressure3pm'}>],
#        [<AxesSubplot:title={'center':'Cloud9am'}>,
#         <AxesSubplot:title={'center':'Cloud3pm'}>,
#         <AxesSubplot:title={'center':'Temp9am'}>,
#         <AxesSubplot:title={'center':'Temp3pm'}>]], dtype=object)

# %%
#Correlation:`

#Correlation is a statistic that helps to measure the strength of relationship between features. 
rain.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.733392  0.051203     0.404632  0.051295
# MaxTemp        0.733392  1.000000 -0.255978     0.501465  0.329668
# Rainfall       0.051203 -0.255978  1.000000    -0.188968 -0.261889
# Evaporation    0.404632  0.501465 -0.188968     1.000000  0.339024
# Sunshine       0.051295  0.329668 -0.261889     0.339024  1.000000
# WindGustSpeed  0.180336  0.073229  0.151293     0.170903 -0.019597
# WindSpeed9am   0.177534  0.017140  0.102499     0.157072  0.006782
# WindSpeed3pm   0.177176  0.053117  0.080050     0.113275  0.041356
# Humidity9am   -0.230718 -0.497111  0.387454    -0.421244 -0.349320
# Humidity3pm    0.006033 -0.498544  0.406205    -0.318548 -0.443121
# Pressure9am   -0.428982 -0.314920 -0.179751    -0.248039  0.029821
# Pressure3pm   -0.437161 -0.402168 -0.095155    -0.269624 -0.016637
# Cloud9am       0.062154 -0.225781  0.270881    -0.168963 -0.532497
# Cloud3pm       0.016724 -0.213214  0.234198    -0.167229 -0.553853
# Temp9am        0.897765  0.879365 -0.114011     0.477917  0.208714
# Temp3pm        0.699147  0.968905 -0.260283     0.485623  0.347710
# year           0.043007  0.061734 -0.014480     0.060169  0.006072
# month         -0.202744 -0.163190  0.011964    -0.024221  0.017589
# day            0.002342  0.000655  0.003290    -0.005429 -0.000286
#
#                WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# MinTemp             0.180336      0.177534      0.177176    -0.230718
# MaxTemp             0.073229      0.017140      0.053117    -0.497111
# Rainfall            0.151293      0.102499      0.080050     0.387454
# Evaporation         0.170903      0.157072      0.113275    -0.421244
# Sunshine           -0.019597      0.006782      0.041356    -0.349320
# WindGustSpeed       1.000000      0.578562      0.659350    -0.214349
# WindSpeed9am        0.578562      1.000000      0.507874    -0.273399
# WindSpeed3pm        0.659350      0.507874      1.000000    -0.146602
# Humidity9am        -0.214349     -0.273399     -0.146602     1.000000
# Humidity3pm        -0.028868     -0.033036      0.015137     0.658850
# Pressure9am        -0.424191     -0.214427     -0.276327     0.133181
# Pressure3pm        -0.381720     -0.164884     -0.237763     0.177319
# Cloud9am            0.050920      0.018119      0.041044     0.354042
# Cloud3pm            0.078253      0.039635      0.018156     0.273774
# Temp9am             0.154054      0.131738      0.165858    -0.468540
# Temp3pm             0.039421      0.007197      0.031299    -0.489627
# year               -0.029014     -0.017855     -0.029658     0.009745
# month               0.058281      0.051481      0.058906    -0.089070
# day                -0.009631     -0.008879     -0.010331     0.015121
#
#                Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# MinTemp           0.006033    -0.428982    -0.437161  0.062154  0.016724
# MaxTemp          -0.498544    -0.314920    -0.402168 -0.225781 -0.213214
# Rainfall          0.406205    -0.179751    -0.095155  0.270881  0.234198
# Evaporation      -0.318548    -0.248039    -0.269624 -0.168963 -0.167229
# Sunshine         -0.443121     0.029821    -0.016637 -0.532497 -0.553853
# WindGustSpeed    -0.028868    -0.424191    -0.381720  0.050920  0.078253
# WindSpeed9am     -0.033036    -0.214427    -0.164884  0.018119  0.039635
# WindSpeed3pm      0.015137    -0.276327    -0.237763  0.041044  0.018156
# Humidity9am       0.658850     0.133181     0.177319  0.354042  0.273774
# Humidity3pm       1.000000    -0.024338     0.050405  0.398762  0.406605
# Pressure9am      -0.024338     1.000000     0.959981 -0.101138 -0.114087
# Pressure3pm       0.050405     0.959981     1.000000 -0.047053 -0.065433
# Cloud9am          0.398762    -0.101138    -0.047053  1.000000  0.559800
# Cloud3pm          0.406605    -0.114087    -0.065433  0.559800  1.000000
# Temp9am          -0.216576    -0.403417    -0.446363 -0.109048 -0.098784
# Temp3pm          -0.555212    -0.272115    -0.366309 -0.232396 -0.247470
# year             -0.009463     0.028290     0.023126  0.051533  0.032182
# month            -0.018568     0.034314     0.025093 -0.007930 -0.003046
# day               0.012813    -0.019915    -0.020277  0.005702 -0.000555
#
#                 Temp9am   Temp3pm      year     month       day
# MinTemp        0.897765  0.699147  0.043007 -0.202744  0.002342
# MaxTemp        0.879365  0.968905  0.061734 -0.163190  0.000655
# Rainfall      -0.114011 -0.260283 -0.014480  0.011964  0.003290
# Evaporation    0.477917  0.485623  0.060169 -0.024221 -0.005429
# Sunshine       0.208714  0.347710  0.006072  0.017589 -0.000286
# WindGustSpeed  0.154054  0.039421 -0.029014  0.058281 -0.009631
# WindSpeed9am   0.131738  0.007197 -0.017855  0.051481 -0.008879
# WindSpeed3pm   0.165858  0.031299 -0.029658  0.058906 -0.010331
# Humidity9am   -0.468540 -0.489627  0.009745 -0.089070  0.015121
# Humidity3pm   -0.216576 -0.555212 -0.009463 -0.018568  0.012813
# Pressure9am   -0.403417 -0.272115  0.028290  0.034314 -0.019915
# Pressure3pm   -0.446363 -0.366309  0.023126  0.025093 -0.020277
# Cloud9am      -0.109048 -0.232396  0.051533 -0.007930  0.005702
# Cloud3pm      -0.098784 -0.247470  0.032182 -0.003046 -0.000555
# Temp9am        1.000000  0.846207  0.045687 -0.135289  0.000183
# Temp3pm        0.846207  1.000000  0.050555 -0.172732 -0.000271
# year           0.045687  0.050555  1.000000 -0.112375 -0.005042
# month         -0.135289 -0.172732 -0.112375  1.000000  0.009223
# day            0.000183 -0.000271 -0.005042  0.009223  1.000000

# %%
plt.figure(figsize=(20,20))
sns.heatmap(rain.corr(),linewidths=0.5,annot=True,fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
rain.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6     5.318667  7.611178           W
# 1   Albury      7.4     25.1       0.0     5.318667  7.611178         WNW
# 2   Albury     12.9     25.7       0.0     5.318667  7.611178         WSW
# 3   Albury      9.2     28.0       0.0     5.318667  7.611178          NE
# 4   Albury     17.5     32.3       1.0     5.318667  7.611178           W
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0           44.0          W        WNW          20.0          24.0
# 1           44.0        NNW        WSW           4.0          22.0
# 2           46.0          W        WSW          19.0          26.0
# 3           24.0         SE          E          11.0           9.0
# 4           41.0        ENE         NW           7.0          20.0
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0         71.0         22.0       1007.7       1007.1  8.000000   4.50993
# 1         44.0         25.0       1010.6       1007.8  4.447461   4.50993
# 2         38.0         30.0       1007.6       1008.7  4.447461   2.00000
# 3         45.0         16.0       1017.6       1012.8  4.447461   4.50993
# 4         82.0         33.0       1010.8       1006.0  7.000000   8.00000
#
#    Temp9am  Temp3pm RainToday RainTomorrow  year  month  day
# 0     16.9     21.8        No           No  2008     12  1.0
# 1     17.2     24.3        No           No  2008     12  2.0
# 2     21.0     23.2        No           No  2008     12  3.0
# 3     18.1     26.5        No           No  2008     12  4.0
# 4     17.8     29.7        No           No  2008     12  5.0

# %%
 `Encoding of Categorical Features`

Most Machine Learning Algorithms like Logistic Regression, Support Vector Machines, K Nearest Neighbours etc. can't handle categorical data. Hence, these categorical data needs to converted to numerical data for modelling, which is called as Feature Encoding.

# %%
categorical_features
# Out:
# ['Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
#Encoding Categorical Features using replace function:
rain['RainToday'].replace({'No':0, 'Yes': 1}, inplace = True)
#pd.get_dummies(rain['RainToday'],drop_first = True)
rain['RainTomorrow'].replace({'No':0, 'Yes': 1}, inplace = True)

# %%
def encode_data(feature_name):
  
     #function which takes feature name as a parameter and return mapping dictionary to replace(or map) categorical data to numerical data.
    
    mapping_dict = {}
    unique_values = list(rain[feature_name].unique())
    for idx in range(len(unique_values)):
        mapping_dict[unique_values[idx]] = idx
    print(mapping_dict)
    return mapping_dict

# %%
rain['WindGustDir'].replace(encode_data('WindGustDir'),inplace = True)
# Out:
# {'W': 0, 'WNW': 1, 'WSW': 2, 'NE': 3, 'NNW': 4, 'N': 5, 'NNE': 6, 'SW': 7, 'ENE': 8, 'SSE': 9, 'S': 10, 'NW': 11, 'SE': 12, 'ESE': 13, 'E': 14, 'SSW': 15}

# %%
rain['WindDir9am'].replace(encode_data('WindDir9am'),inplace = True)
# Out:
# {'W': 0, 'NNW': 1, 'SE': 2, 'ENE': 3, 'SW': 4, 'SSE': 5, 'S': 6, 'NE': 7, 'N': 8, 'SSW': 9, 'WSW': 10, 'ESE': 11, 'E': 12, 'NW': 13, 'WNW': 14, 'NNE': 15}

# %%
rain['WindDir3pm'].replace(encode_data('WindDir3pm'),inplace = True)
# Out:
# {'WNW': 0, 'WSW': 1, 'E': 2, 'NW': 3, 'W': 4, 'SSE': 5, 'ESE': 6, 'ENE': 7, 'NNW': 8, 'SSW': 9, 'SW': 10, 'SE': 11, 'N': 12, 'S': 13, 'NNE': 14, 'NE': 15}

# %%
rain['Location'].replace(encode_data('Location'), inplace = True)
# Out:
# {'Albury': 0, 'BadgerysCreek': 1, 'Cobar': 2, 'CoffsHarbour': 3, 'Moree': 4, 'Newcastle': 5, 'NorahHead': 6, 'NorfolkIsland': 7, 'Penrith': 8, 'Richmond': 9, 'Sydney': 10, 'SydneyAirport': 11, 'WaggaWagga': 12, 'Williamtown': 13, 'Wollongong': 14, 'Canberra': 15, 'Tuggeranong': 16, 'MountGinini': 17, 'Ballarat': 18, 'Bendigo': 19, 'Sale': 20, 'MelbourneAirport': 21, 'Melbourne': 22, 'Mildura': 23, 'Nhil': 24, 'Portland': 25, 'Watsonia': 26, 'Dartmoor': 27, 'Brisbane': 28, 'Cairns': 29, 'GoldCoast': 30, 'Townsville': 31, 'Adelaide': 32, 'MountGambier': 33, 'Nuriootpa': 34, 'Woomera': 35, 'Albany': 36, 'Witchcliffe': 37, 'PearceRAAF': 38, 'PerthAirport': 39, 'Perth': 40, 'SalmonGums': 41, 'Walpole': 42, 'Hobart': 43, 'Launceston': 44, 'AliceSprings': 45, 'Darwin': 46, 'Katherine': 47, 'Uluru': 48}

# %%
rain.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         0     13.4     22.9       0.6     5.318667  7.611178            0
# 1         0      7.4     25.1       0.0     5.318667  7.611178            1
# 2         0     12.9     25.7       0.0     5.318667  7.611178            2
# 3         0      9.2     28.0       0.0     5.318667  7.611178            3
# 4         0     17.5     32.3       1.0     5.318667  7.611178            0
#
#    WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0           44.0           0           0          20.0          24.0
# 1           44.0           1           1           4.0          22.0
# 2           46.0           0           1          19.0          26.0
# 3           24.0           2           2          11.0           9.0
# 4           41.0           3           3           7.0          20.0
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0         71.0         22.0       1007.7       1007.1  8.000000   4.50993
# 1         44.0         25.0       1010.6       1007.8  4.447461   4.50993
# 2         38.0         30.0       1007.6       1008.7  4.447461   2.00000
# 3         45.0         16.0       1017.6       1012.8  4.447461   4.50993
# 4         82.0         33.0       1010.8       1006.0  7.000000   8.00000
#
#    Temp9am  Temp3pm  RainToday  RainTomorrow  year  month  day
# 0     16.9     21.8          0             0  2008     12  1.0
# 1     17.2     24.3          0             0  2008     12  2.0
# 2     21.0     23.2          0             0  2008     12  3.0
# 3     18.1     26.5          0             0  2008     12  4.0
# 4     17.8     29.7          0             0  2008     12  5.0

# %%
#Spliting data into input features and label
X = rain.drop(['RainTomorrow'],axis=1)
y = rain['RainTomorrow']

# %%
`Feature Importance:`

- Machine Learning Model performance depends on features that are used to train a model. 
- Feature importance describes which features are relevant to build a model. 
- Feature Importance refers to the techniques that assign a score to input/label features based on how useful they are  at predicting a target variable. Feature importance helps in Feature Selection.

# %%
#finding feature importance using ExtraTreesRegressor:
from sklearn.ensemble import ExtraTreesRegressor
etr_model = ExtraTreesRegressor()
etr_model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
ExtraTreesRegressor()
# Out:
# ExtraTreesRegressor()

# %%
etr_model.feature_importances_
# Out:
# array([0.03462424, 0.03015796, 0.02870834, 0.03970919, 0.0233674 ,
#        0.04404926, 0.0297939 , 0.05642324, 0.03061397, 0.03158674,
#        0.03098738, 0.03226949, 0.03635619, 0.20380415, 0.03673977,
#        0.04966163, 0.02388874, 0.03494134, 0.02817998, 0.02816161,
#        0.05264518, 0.030728  , 0.03032826, 0.03227403])

# %%
# visualizing feature importance using bar graph:
feature_imp = pd.Series(etr_model.feature_importances_,index=X.columns)
feature_imp.nlargest(10).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
feature_imp
# Out:
# Location         0.034624
# MinTemp          0.030158
# MaxTemp          0.028708
# Rainfall         0.039709
# Evaporation      0.023367
# Sunshine         0.044049
# WindGustDir      0.029794
# WindGustSpeed    0.056423
# WindDir9am       0.030614
# WindDir3pm       0.031587
# WindSpeed9am     0.030987
# WindSpeed3pm     0.032269
# Humidity9am      0.036356
# Humidity3pm      0.203804
# Pressure9am      0.036740
# Pressure3pm      0.049662
# Cloud9am         0.023889
# Cloud3pm         0.034941
# Temp9am          0.028180
# Temp3pm          0.028162
# RainToday        0.052645
# year             0.030728
# month            0.030328
# day              0.032274
# dtype: float64

# %%
Split Data into Training and Testing Set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 0)

# %%
print("Length of Training Data: {}".format(len(X_train)))
print("Length of Testing Data: {}".format(len(X_test)))
# Out:
# Length of Training Data: 116368
# Length of Testing Data: 29092

# %%
Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
Save the Scaler object to Standardize Real Time Data feeded by users for prediction

# %%
with open('scaler.pkl', 'wb') as file:
    pickle.dump(scaler, file)

# %%
 Model Building
- Model Training
- Model Testing 
- Evaluating Model Performance using Accuracy, Confusion Matrix, Classification Report, RUC-AUC curve
- Finding whether model performance can be improved using Cross Validation Score

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
#`(i) Logistic Regression`

#Model Training:
from sklearn.linear_model import LogisticRegression

# %%
start_time = time.time()
classifier_logreg = LogisticRegression(solver='liblinear', random_state=0)
classifier_logreg.fit(X_train, y_train)
end_time = time.time()

# %%
print("Time Taken to train: {}".format(end_time - start_time))
# Out:
# Time Taken to train: 0.7008540630340576

# %%
#Model Testing:
y_pred = classifier_logreg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print("Accuracy Score: {}".format(accuracy_score(y_test,y_pred)))
# Out:
# Accuracy Score: 0.8444933315000688

# %%
#Checking for Overfitting and Under Fitting:
print("Train Data Score: {}".format(classifier_logreg.score(X_train, y_train)))
print("Test Data Score: {}".format(classifier_logreg.score(X_test, y_test)))
# Out:
# Train Data Score: 0.8437714835693662
# Test Data Score: 0.8444933315000688

# %%
Accuracy Score of Training and Testing Data is comparable and almost equal. So, there is no question of Underfitting and Over Fitting. And model is generalizing well for new unseen data.

# %%
#confusion Matrix:
print("Confusion Matrix:")
print("\n",confusion_matrix(y_test,y_pred))
# Out:
# Confusion Matrix:
#
#  [[21536  1190]
#  [ 3334  3032]]

# %%
#Classification Report:
print("classification_report:")
print("\n",classification_report(y_test,y_pred))
# Out:
# classification_report:
#
#                precision    recall  f1-score   support
#
#            0       0.87      0.95      0.90     22726
#            1       0.72      0.48      0.57      6366
#
#     accuracy                           0.84     29092
#    macro avg       0.79      0.71      0.74     29092
# weighted avg       0.83      0.84      0.83     29092

# %%
#predicting probabilities:
y_pred_logreg_proba = classifier_logreg.predict_proba(X_test)

# %%
#Finding True Positive Rate(tpr), False Positive Rate(fpr), threshold values to plot ROC curve
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_logreg_proba[:,1])

# %%
#Plotting ROC curve:
plt.figure(figsize=(6,4))
plt.plot(fpr,tpr,'-g',linewidth=1)
plt.plot([0,1], [0,1], 'k--' )
plt.title('ROC curve for Logistic Regression Model')
plt.xlabel("False Positive Rate")
plt.ylabel('True Positive Rate')
plt.show()

# %%
#finding ROC-AUC score:
from sklearn.metrics import roc_auc_score
print('ROC AUC Scores: {}'.format(roc_auc_score(y_test, y_pred)))
# Out:
# ROC AUC Scores: 0.7119586532221237

# %%
Finding whether model performance can be improved using Cross Validation Score:

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(classifier_logreg, X_train, y_train, cv = 5, scoring='accuracy')
print('Cross-validation scores:{}'.format(scores))
# Out:
# Cross-validation scores:[0.84338747 0.84235628 0.84691072 0.84067374 0.84359558]

# %%
print('Average cross-validation score: {}'.format(scores.mean()))
# Out:
# Average cross-validation score: 0.8433847578355673

# %%
The mean accuracy score of cross validation is almost same like original model accuracy score which is 0.8445. So, accuracy of model may not be improved using Cross-validation.

# %%
#`(ii) Cat Boost`

from catboost import CatBoostClassifier

# %%
#Model Training:

start_time = time.time()
cat_classifier = CatBoostClassifier(iterations=2000, eval_metric = "AUC")
cat_classifier.fit(X_train, y_train)
end_time = time.time()
# Out:
# Learning rate set to 0.041591
# 0:	total: 157ms	remaining: 5m 13s
# 1:	total: 172ms	remaining: 2m 51s
# 2:	total: 191ms	remaining: 2m 7s
# 3:	total: 210ms	remaining: 1m 44s
# 4:	total: 228ms	remaining: 1m 31s
# 5:	total: 245ms	remaining: 1m 21s
# 6:	total: 258ms	remaining: 1m 13s
# 7:	total: 273ms	remaining: 1m 7s
# 8:	total: 288ms	remaining: 1m 3s
# 9:	total: 301ms	remaining: 59.9s
# 10:	total: 315ms	remaining: 57s
# 11:	total: 329ms	remaining: 54.6s
# 12:	total: 344ms	remaining: 52.7s
# 13:	total: 358ms	remaining: 50.8s
# 14:	total: 372ms	remaining: 49.3s
# 15:	total: 387ms	remaining: 47.9s
# 16:	total: 404ms	remaining: 47.1s
# 17:	total: 419ms	remaining: 46.1s
# 18:	total: 433ms	remaining: 45.2s
# 19:	total: 447ms	remaining: 44.2s
# 20:	total: 462ms	remaining: 43.5s
# 21:	total: 477ms	remaining: 42.9s
# 22:	total: 492ms	remaining: 42.3s
# 23:	total: 506ms	remaining: 41.6s
# 24:	total: 520ms	remaining: 41.1s
# 25:	total: 534ms	remaining: 40.6s
# 26:	total: 548ms	remaining: 40.1s
# 27:	total: 562ms	remaining: 39.6s
# 28:	total: 575ms	remaining: 39.1s
# 29:	total: 589ms	remaining: 38.7s
# 30:	total: 604ms	remaining: 38.4s
# 31:	total: 619ms	remaining: 38.1s
# 32:	total: 633ms	remaining: 37.7s
# 33:	total: 647ms	remaining: 37.4s
# 34:	total: 663ms	remaining: 37.2s
# 35:	total: 677ms	remaining: 36.9s
# 36:	total: 692ms	remaining: 36.7s
# 37:	total: 707ms	remaining: 36.5s
# 38:	total: 734ms	remaining: 36.9s
# 39:	total: 750ms	remaining: 36.8s
# 40:	total: 765ms	remaining: 36.5s
# 41:	total: 779ms	remaining: 36.3s
# 42:	total: 798ms	remaining: 36.3s
# 43:	total: 813ms	remaining: 36.1s
# 44:	total: 828ms	remaining: 36s
# 45:	total: 842ms	remaining: 35.8s
# 46:	total: 856ms	remaining: 35.6s
# 47:	total: 870ms	remaining: 35.4s
# 48:	total: 885ms	remaining: 35.2s
# 49:	total: 899ms	remaining: 35.1s
# 50:	total: 914ms	remaining: 34.9s
# 51:	total: 931ms	remaining: 34.9s
# 52:	total: 948ms	remaining: 34.8s
# 53:	total: 965ms	remaining: 34.8s
# 54:	total: 981ms	remaining: 34.7s
# 55:	total: 997ms	remaining: 34.6s
# 56:	total: 1.01s	remaining: 34.5s
# 57:	total: 1.02s	remaining: 34.3s
# 58:	total: 1.04s	remaining: 34.2s
# 59:	total: 1.05s	remaining: 34s
# 60:	total: 1.06s	remaining: 33.8s
# 61:	total: 1.08s	remaining: 33.7s
# 62:	total: 1.09s	remaining: 33.5s
# 63:	total: 1.1s	remaining: 33.4s
# 64:	total: 1.12s	remaining: 33.4s
# 65:	total: 1.13s	remaining: 33.2s
# 66:	total: 1.15s	remaining: 33.2s
# 67:	total: 1.16s	remaining: 33s
# 68:	total: 1.18s	remaining: 33s
# 69:	total: 1.2s	remaining: 33s
# 70:	total: 1.21s	remaining: 32.9s
# 71:	total: 1.22s	remaining: 32.8s
# 72:	total: 1.24s	remaining: 32.7s
# 73:	total: 1.25s	remaining: 32.6s
# 74:	total: 1.26s	remaining: 32.5s
# 75:	total: 1.28s	remaining: 32.3s
# 76:	total: 1.29s	remaining: 32.2s
# 77:	total: 1.3s	remaining: 32.1s
# 78:	total: 1.31s	remaining: 32s
# 79:	total: 1.33s	remaining: 31.9s
# 80:	total: 1.34s	remaining: 31.8s
# 81:	total: 1.36s	remaining: 31.8s
# 82:	total: 1.37s	remaining: 31.7s
# 83:	total: 1.39s	remaining: 31.7s
# 84:	total: 1.41s	remaining: 31.7s
# 85:	total: 1.42s	remaining: 31.6s
# 86:	total: 1.44s	remaining: 31.6s
# 87:	total: 1.45s	remaining: 31.5s
# 88:	total: 1.46s	remaining: 31.4s
# 89:	total: 1.48s	remaining: 31.3s
# 90:	total: 1.49s	remaining: 31.2s
# 91:	total: 1.5s	remaining: 31.1s
# 92:	total: 1.51s	remaining: 31.1s
# 93:	total: 1.53s	remaining: 31s
# 94:	total: 1.54s	remaining: 30.9s
# 95:	total: 1.55s	remaining: 30.8s
# 96:	total: 1.57s	remaining: 30.8s
# 97:	total: 1.58s	remaining: 30.7s
# 98:	total: 1.6s	remaining: 30.7s
# 99:	total: 1.61s	remaining: 30.7s
# 100:	total: 1.63s	remaining: 30.7s
# 101:	total: 1.65s	remaining: 30.6s
# 102:	total: 1.66s	remaining: 30.6s
# 103:	total: 1.67s	remaining: 30.5s
# 104:	total: 1.69s	remaining: 30.5s
# 105:	total: 1.7s	remaining: 30.5s
# 106:	total: 1.72s	remaining: 30.4s
# 107:	total: 1.73s	remaining: 30.4s
# 108:	total: 1.75s	remaining: 30.4s
# 109:	total: 1.77s	remaining: 30.4s
# 110:	total: 1.78s	remaining: 30.3s
# 111:	total: 1.8s	remaining: 30.4s
# 112:	total: 1.82s	remaining: 30.4s
# 113:	total: 1.83s	remaining: 30.3s
# 114:	total: 1.85s	remaining: 30.3s
# 115:	total: 1.86s	remaining: 30.2s
# 116:	total: 1.87s	remaining: 30.1s
# 117:	total: 1.89s	remaining: 30.1s
# 118:	total: 1.9s	remaining: 30.1s
# 119:	total: 1.92s	remaining: 30.1s
# 120:	total: 1.93s	remaining: 30s
# 121:	total: 1.95s	remaining: 30s
# 122:	total: 1.96s	remaining: 29.9s
# 123:	total: 1.97s	remaining: 29.8s
# 124:	total: 1.99s	remaining: 29.8s
# 125:	total: 2s	remaining: 29.8s
# 126:	total: 2.02s	remaining: 29.7s
# 127:	total: 2.03s	remaining: 29.7s
# 128:	total: 2.04s	remaining: 29.6s
# 129:	total: 2.06s	remaining: 29.6s
# 130:	total: 2.07s	remaining: 29.5s
# 131:	total: 2.08s	remaining: 29.5s
# 132:	total: 2.1s	remaining: 29.4s
# 133:	total: 2.11s	remaining: 29.4s
# 134:	total: 2.12s	remaining: 29.3s
# 135:	total: 2.13s	remaining: 29.3s
# 136:	total: 2.15s	remaining: 29.2s
# 137:	total: 2.16s	remaining: 29.2s
# 138:	total: 2.18s	remaining: 29.1s
# 139:	total: 2.19s	remaining: 29.1s
# 140:	total: 2.21s	remaining: 29.1s
# 141:	total: 2.23s	remaining: 29.1s
# 142:	total: 2.24s	remaining: 29.1s
# 143:	total: 2.26s	remaining: 29.1s
# 144:	total: 2.27s	remaining: 29.1s
# 145:	total: 2.29s	remaining: 29s
# 146:	total: 2.3s	remaining: 29s
# 147:	total: 2.32s	remaining: 29s
# 148:	total: 2.33s	remaining: 29s
# 149:	total: 2.35s	remaining: 29s
# 150:	total: 2.36s	remaining: 28.9s
# 151:	total: 2.38s	remaining: 28.9s
# 152:	total: 2.39s	remaining: 28.8s
# 153:	total: 2.4s	remaining: 28.8s
# 154:	total: 2.42s	remaining: 28.8s
# 155:	total: 2.43s	remaining: 28.8s
# 156:	total: 2.45s	remaining: 28.7s
# 157:	total: 2.46s	remaining: 28.7s
# 158:	total: 2.48s	remaining: 28.7s
# 159:	total: 2.49s	remaining: 28.6s
# 160:	total: 2.5s	remaining: 28.6s
# 161:	total: 2.52s	remaining: 28.6s
# 162:	total: 2.53s	remaining: 28.5s
# 163:	total: 2.54s	remaining: 28.5s
# 164:	total: 2.56s	remaining: 28.4s
# 165:	total: 2.57s	remaining: 28.4s
# 166:	total: 2.58s	remaining: 28.3s
# 167:	total: 2.59s	remaining: 28.3s
# 168:	total: 2.61s	remaining: 28.3s
# 169:	total: 2.63s	remaining: 28.3s
# 170:	total: 2.65s	remaining: 28.3s
# 171:	total: 2.67s	remaining: 28.3s
# 172:	total: 2.68s	remaining: 28.3s
# 173:	total: 2.7s	remaining: 28.3s
# 174:	total: 2.71s	remaining: 28.3s
# 175:	total: 2.73s	remaining: 28.3s
# 176:	total: 2.74s	remaining: 28.3s
# 177:	total: 2.76s	remaining: 28.2s
# 178:	total: 2.77s	remaining: 28.2s
# 179:	total: 2.79s	remaining: 28.2s
# 180:	total: 2.8s	remaining: 28.1s
# 181:	total: 2.81s	remaining: 28.1s
# 182:	total: 2.83s	remaining: 28.1s
# 183:	total: 2.84s	remaining: 28s
# 184:	total: 2.85s	remaining: 28s
# 185:	total: 2.87s	remaining: 28s
# 186:	total: 2.88s	remaining: 27.9s
# 187:	total: 2.89s	remaining: 27.9s
# 188:	total: 2.91s	remaining: 27.9s
# 189:	total: 2.93s	remaining: 27.9s
# 190:	total: 2.94s	remaining: 27.9s
# 191:	total: 2.96s	remaining: 27.9s
# 192:	total: 2.98s	remaining: 27.9s
# 193:	total: 3s	remaining: 27.9s
# 194:	total: 3.01s	remaining: 27.9s
# 195:	total: 3.03s	remaining: 27.9s
# 196:	total: 3.05s	remaining: 27.9s
# 197:	total: 3.06s	remaining: 27.9s
# 198:	total: 3.08s	remaining: 27.9s
# 199:	total: 3.09s	remaining: 27.9s
# 200:	total: 3.11s	remaining: 27.8s
# 201:	total: 3.12s	remaining: 27.8s
# 202:	total: 3.14s	remaining: 27.8s
# 203:	total: 3.15s	remaining: 27.7s
# 204:	total: 3.16s	remaining: 27.7s
# 205:	total: 3.18s	remaining: 27.7s
# 206:	total: 3.19s	remaining: 27.6s
# 207:	total: 3.21s	remaining: 27.6s
# 208:	total: 3.22s	remaining: 27.6s
# 209:	total: 3.24s	remaining: 27.6s
# 210:	total: 3.26s	remaining: 27.6s
# 211:	total: 3.27s	remaining: 27.6s
# 212:	total: 3.29s	remaining: 27.6s
# 213:	total: 3.3s	remaining: 27.6s
# 214:	total: 3.32s	remaining: 27.6s
# 215:	total: 3.33s	remaining: 27.5s
# 216:	total: 3.35s	remaining: 27.5s
# 217:	total: 3.36s	remaining: 27.5s
# 218:	total: 3.38s	remaining: 27.5s
# 219:	total: 3.39s	remaining: 27.4s
# 220:	total: 3.4s	remaining: 27.4s
# 221:	total: 3.42s	remaining: 27.4s
# 222:	total: 3.43s	remaining: 27.3s
# 223:	total: 3.44s	remaining: 27.3s
# 224:	total: 3.46s	remaining: 27.3s
# 225:	total: 3.47s	remaining: 27.3s
# 226:	total: 3.49s	remaining: 27.2s
# 227:	total: 3.5s	remaining: 27.2s
# 228:	total: 3.52s	remaining: 27.2s
# 229:	total: 3.53s	remaining: 27.2s
# 230:	total: 3.55s	remaining: 27.2s
# 231:	total: 3.57s	remaining: 27.2s
# 232:	total: 3.58s	remaining: 27.2s
# 233:	total: 3.6s	remaining: 27.2s
# 234:	total: 3.61s	remaining: 27.1s
# 235:	total: 3.63s	remaining: 27.1s
# 236:	total: 3.65s	remaining: 27.1s
# 237:	total: 3.66s	remaining: 27.1s
# 238:	total: 3.67s	remaining: 27.1s
# 239:	total: 3.69s	remaining: 27s
# 240:	total: 3.7s	remaining: 27s
# 241:	total: 3.71s	remaining: 27s
# 242:	total: 3.73s	remaining: 27s
# 243:	total: 3.74s	remaining: 26.9s
# 244:	total: 3.76s	remaining: 26.9s
# 245:	total: 3.77s	remaining: 26.9s
# 246:	total: 3.79s	remaining: 26.9s
# 247:	total: 3.81s	remaining: 26.9s
# 248:	total: 3.82s	remaining: 26.9s
# 249:	total: 3.84s	remaining: 26.9s
# 250:	total: 3.86s	remaining: 26.9s
# 251:	total: 3.87s	remaining: 26.9s
# 252:	total: 3.89s	remaining: 26.8s
# 253:	total: 3.9s	remaining: 26.8s
# 254:	total: 3.91s	remaining: 26.8s
# 255:	total: 3.93s	remaining: 26.8s
# 256:	total: 3.94s	remaining: 26.7s
# 257:	total: 3.96s	remaining: 26.7s
# 258:	total: 3.97s	remaining: 26.7s
# 259:	total: 3.98s	remaining: 26.7s
# 260:	total: 4s	remaining: 26.6s
# 261:	total: 4.01s	remaining: 26.6s
# 262:	total: 4.02s	remaining: 26.6s
# 263:	total: 4.04s	remaining: 26.6s
# 264:	total: 4.05s	remaining: 26.6s
# 265:	total: 4.07s	remaining: 26.5s
# 266:	total: 4.09s	remaining: 26.5s
# 267:	total: 4.1s	remaining: 26.5s
# 268:	total: 4.12s	remaining: 26.5s
# 269:	total: 4.14s	remaining: 26.5s
# 270:	total: 4.15s	remaining: 26.5s
# 271:	total: 4.17s	remaining: 26.5s
# 272:	total: 4.18s	remaining: 26.5s
# 273:	total: 4.2s	remaining: 26.5s
# 274:	total: 4.21s	remaining: 26.4s
# 275:	total: 4.23s	remaining: 26.4s
# 276:	total: 4.24s	remaining: 26.4s
# 277:	total: 4.26s	remaining: 26.4s
# 278:	total: 4.27s	remaining: 26.3s
# 279:	total: 4.28s	remaining: 26.3s
# 280:	total: 4.3s	remaining: 26.3s
# 281:	total: 4.31s	remaining: 26.3s
# 282:	total: 4.33s	remaining: 26.3s
# 283:	total: 4.34s	remaining: 26.2s
# 284:	total: 4.36s	remaining: 26.2s
# 285:	total: 4.38s	remaining: 26.2s
# 286:	total: 4.39s	remaining: 26.2s
# 287:	total: 4.41s	remaining: 26.2s
# 288:	total: 4.42s	remaining: 26.2s
# 289:	total: 4.44s	remaining: 26.2s
# 290:	total: 4.46s	remaining: 26.2s
# 291:	total: 4.47s	remaining: 26.1s
# 292:	total: 4.48s	remaining: 26.1s
# 293:	total: 4.5s	remaining: 26.1s
# 294:	total: 4.51s	remaining: 26.1s
# 295:	total: 4.52s	remaining: 26s
# 296:	total: 4.53s	remaining: 26s
# 297:	total: 4.55s	remaining: 26s
# 298:	total: 4.56s	remaining: 25.9s
# 299:	total: 4.58s	remaining: 25.9s
# 300:	total: 4.59s	remaining: 25.9s
# 301:	total: 4.61s	remaining: 25.9s
# 302:	total: 4.63s	remaining: 25.9s
# 303:	total: 4.64s	remaining: 25.9s
# 304:	total: 4.66s	remaining: 25.9s
# 305:	total: 4.67s	remaining: 25.9s
# 306:	total: 4.69s	remaining: 25.9s
# 307:	total: 4.71s	remaining: 25.9s
# 308:	total: 4.72s	remaining: 25.9s
# 309:	total: 4.74s	remaining: 25.8s
# 310:	total: 4.76s	remaining: 25.8s
# 311:	total: 4.77s	remaining: 25.8s
# 312:	total: 4.78s	remaining: 25.8s
# 313:	total: 4.8s	remaining: 25.8s
# 314:	total: 4.82s	remaining: 25.8s
# 315:	total: 4.83s	remaining: 25.7s
# 316:	total: 4.84s	remaining: 25.7s
# 317:	total: 4.86s	remaining: 25.7s
# 318:	total: 4.88s	remaining: 25.7s
# 319:	total: 4.89s	remaining: 25.7s
# 320:	total: 4.91s	remaining: 25.7s
# 321:	total: 4.92s	remaining: 25.7s
# 322:	total: 4.94s	remaining: 25.6s
# 323:	total: 4.95s	remaining: 25.6s
# 324:	total: 4.97s	remaining: 25.6s
# 325:	total: 4.99s	remaining: 25.6s
# 326:	total: 5s	remaining: 25.6s
# 327:	total: 5.02s	remaining: 25.6s
# 328:	total: 5.04s	remaining: 25.6s
# 329:	total: 5.05s	remaining: 25.5s
# 330:	total: 5.06s	remaining: 25.5s
# 331:	total: 5.08s	remaining: 25.5s
# 332:	total: 5.09s	remaining: 25.5s
# 333:	total: 5.1s	remaining: 25.5s
# 334:	total: 5.12s	remaining: 25.4s
# 335:	total: 5.13s	remaining: 25.4s
# 336:	total: 5.14s	remaining: 25.4s
# 337:	total: 5.16s	remaining: 25.4s
# 338:	total: 5.18s	remaining: 25.4s
# 339:	total: 5.2s	remaining: 25.4s
# 340:	total: 5.22s	remaining: 25.4s
# 341:	total: 5.25s	remaining: 25.4s
# 342:	total: 5.27s	remaining: 25.4s
# 343:	total: 5.29s	remaining: 25.4s
# 344:	total: 5.3s	remaining: 25.4s
# 345:	total: 5.32s	remaining: 25.4s
# 346:	total: 5.33s	remaining: 25.4s
# 347:	total: 5.35s	remaining: 25.4s
# 348:	total: 5.37s	remaining: 25.4s
# 349:	total: 5.38s	remaining: 25.4s
# 350:	total: 5.39s	remaining: 25.4s
# 351:	total: 5.41s	remaining: 25.3s
# 352:	total: 5.42s	remaining: 25.3s
# 353:	total: 5.45s	remaining: 25.3s
# 354:	total: 5.46s	remaining: 25.3s
# 355:	total: 5.48s	remaining: 25.3s
# 356:	total: 5.5s	remaining: 25.3s
# 357:	total: 5.51s	remaining: 25.3s
# 358:	total: 5.53s	remaining: 25.3s
# 359:	total: 5.55s	remaining: 25.3s
# 360:	total: 5.57s	remaining: 25.3s
# 361:	total: 5.59s	remaining: 25.3s
# 362:	total: 5.61s	remaining: 25.3s
# 363:	total: 5.62s	remaining: 25.3s
# 364:	total: 5.64s	remaining: 25.3s
# 365:	total: 5.65s	remaining: 25.2s
# 366:	total: 5.67s	remaining: 25.2s
# 367:	total: 5.68s	remaining: 25.2s
# 368:	total: 5.69s	remaining: 25.2s
# 369:	total: 5.71s	remaining: 25.1s
# 370:	total: 5.72s	remaining: 25.1s
# 371:	total: 5.73s	remaining: 25.1s
# 372:	total: 5.75s	remaining: 25.1s
# 373:	total: 5.76s	remaining: 25.1s
# 374:	total: 5.78s	remaining: 25s
# 375:	total: 5.79s	remaining: 25s
# 376:	total: 5.81s	remaining: 25s
# 377:	total: 5.83s	remaining: 25s
# 378:	total: 5.85s	remaining: 25s
# 379:	total: 5.86s	remaining: 25s
# 380:	total: 5.88s	remaining: 25s
# 381:	total: 5.89s	remaining: 25s
# 382:	total: 5.91s	remaining: 24.9s
# 383:	total: 5.92s	remaining: 24.9s
# 384:	total: 5.93s	remaining: 24.9s
# 385:	total: 5.94s	remaining: 24.9s
# 386:	total: 5.96s	remaining: 24.8s
# 387:	total: 5.97s	remaining: 24.8s
# 388:	total: 5.98s	remaining: 24.8s
# 389:	total: 6s	remaining: 24.7s
# 390:	total: 6.01s	remaining: 24.7s
# 391:	total: 6.02s	remaining: 24.7s
# 392:	total: 6.04s	remaining: 24.7s
# 393:	total: 6.06s	remaining: 24.7s
# 394:	total: 6.07s	remaining: 24.7s
# 395:	total: 6.09s	remaining: 24.7s
# 396:	total: 6.1s	remaining: 24.6s
# 397:	total: 6.12s	remaining: 24.6s
# 398:	total: 6.14s	remaining: 24.6s
# 399:	total: 6.15s	remaining: 24.6s
# 400:	total: 6.17s	remaining: 24.6s
# 401:	total: 6.18s	remaining: 24.6s
# 402:	total: 6.2s	remaining: 24.6s
# 403:	total: 6.21s	remaining: 24.5s
# 404:	total: 6.22s	remaining: 24.5s
# 405:	total: 6.24s	remaining: 24.5s
# 406:	total: 6.25s	remaining: 24.5s
# 407:	total: 6.26s	remaining: 24.4s
# 408:	total: 6.28s	remaining: 24.4s
# 409:	total: 6.29s	remaining: 24.4s
# 410:	total: 6.3s	remaining: 24.4s
# 411:	total: 6.32s	remaining: 24.3s
# 412:	total: 6.33s	remaining: 24.3s
# 413:	total: 6.35s	remaining: 24.3s
# 414:	total: 6.37s	remaining: 24.3s
# 415:	total: 6.38s	remaining: 24.3s
# 416:	total: 6.4s	remaining: 24.3s
# 417:	total: 6.41s	remaining: 24.3s
# 418:	total: 6.43s	remaining: 24.3s
# 419:	total: 6.45s	remaining: 24.3s
# 420:	total: 6.46s	remaining: 24.2s
# 421:	total: 6.48s	remaining: 24.2s
# 422:	total: 6.49s	remaining: 24.2s
# 423:	total: 6.51s	remaining: 24.2s
# 424:	total: 6.52s	remaining: 24.2s
# 425:	total: 6.53s	remaining: 24.1s
# 426:	total: 6.55s	remaining: 24.1s
# 427:	total: 6.56s	remaining: 24.1s
# 428:	total: 6.57s	remaining: 24.1s
# 429:	total: 6.59s	remaining: 24.1s
# 430:	total: 6.6s	remaining: 24s
# 431:	total: 6.61s	remaining: 24s
# 432:	total: 6.63s	remaining: 24s
# 433:	total: 6.65s	remaining: 24s
# 434:	total: 6.66s	remaining: 24s
# 435:	total: 6.68s	remaining: 24s
# 436:	total: 6.7s	remaining: 24s
# 437:	total: 6.71s	remaining: 23.9s
# 438:	total: 6.76s	remaining: 24s
# 439:	total: 6.78s	remaining: 24s
# 440:	total: 6.79s	remaining: 24s
# 441:	total: 6.81s	remaining: 24s
# 442:	total: 6.82s	remaining: 24s
# 443:	total: 6.83s	remaining: 23.9s
# 444:	total: 6.85s	remaining: 23.9s
# 445:	total: 6.86s	remaining: 23.9s
# 446:	total: 6.88s	remaining: 23.9s
# 447:	total: 6.89s	remaining: 23.9s
# 448:	total: 6.91s	remaining: 23.9s
# 449:	total: 6.92s	remaining: 23.8s
# 450:	total: 6.94s	remaining: 23.8s
# 451:	total: 6.95s	remaining: 23.8s
# 452:	total: 6.97s	remaining: 23.8s
# 453:	total: 6.98s	remaining: 23.8s
# 454:	total: 7s	remaining: 23.8s
# 455:	total: 7.02s	remaining: 23.8s
# 456:	total: 7.03s	remaining: 23.7s
# 457:	total: 7.05s	remaining: 23.7s
# 458:	total: 7.06s	remaining: 23.7s
# 459:	total: 7.08s	remaining: 23.7s
# 460:	total: 7.09s	remaining: 23.7s
# 461:	total: 7.11s	remaining: 23.7s
# 462:	total: 7.12s	remaining: 23.6s
# 463:	total: 7.13s	remaining: 23.6s
# 464:	total: 7.15s	remaining: 23.6s
# 465:	total: 7.16s	remaining: 23.6s
# 466:	total: 7.17s	remaining: 23.6s
# 467:	total: 7.19s	remaining: 23.5s
# 468:	total: 7.2s	remaining: 23.5s
# 469:	total: 7.22s	remaining: 23.5s
# 470:	total: 7.23s	remaining: 23.5s
# 471:	total: 7.25s	remaining: 23.5s
# 472:	total: 7.27s	remaining: 23.5s
# 473:	total: 7.31s	remaining: 23.5s
# 474:	total: 7.33s	remaining: 23.5s
# 475:	total: 7.34s	remaining: 23.5s
# 476:	total: 7.35s	remaining: 23.5s
# 477:	total: 7.37s	remaining: 23.5s
# 478:	total: 7.38s	remaining: 23.4s
# 479:	total: 7.4s	remaining: 23.4s
# 480:	total: 7.41s	remaining: 23.4s
# 481:	total: 7.42s	remaining: 23.4s
# 482:	total: 7.43s	remaining: 23.3s
# 483:	total: 7.45s	remaining: 23.3s
# 484:	total: 7.46s	remaining: 23.3s
# 485:	total: 7.48s	remaining: 23.3s
# 486:	total: 7.49s	remaining: 23.3s
# 487:	total: 7.5s	remaining: 23.2s
# 488:	total: 7.51s	remaining: 23.2s
# 489:	total: 7.53s	remaining: 23.2s
# 490:	total: 7.54s	remaining: 23.2s
# 491:	total: 7.56s	remaining: 23.2s
# 492:	total: 7.57s	remaining: 23.2s
# 493:	total: 7.59s	remaining: 23.1s
# 494:	total: 7.61s	remaining: 23.1s
# 495:	total: 7.63s	remaining: 23.1s
# 496:	total: 7.64s	remaining: 23.1s
# 497:	total: 7.67s	remaining: 23.1s
# 498:	total: 7.69s	remaining: 23.1s
# 499:	total: 7.71s	remaining: 23.1s
# 500:	total: 7.72s	remaining: 23.1s
# 501:	total: 7.74s	remaining: 23.1s
# 502:	total: 7.76s	remaining: 23.1s
# 503:	total: 7.78s	remaining: 23.1s
# 504:	total: 7.8s	remaining: 23.1s
# 505:	total: 7.83s	remaining: 23.1s
# 506:	total: 7.85s	remaining: 23.1s
# 507:	total: 7.88s	remaining: 23.2s
# 508:	total: 7.91s	remaining: 23.2s
# 509:	total: 7.94s	remaining: 23.2s
# 510:	total: 7.97s	remaining: 23.2s
# 511:	total: 8s	remaining: 23.2s
# 512:	total: 8.03s	remaining: 23.3s
# 513:	total: 8.05s	remaining: 23.3s
# 514:	total: 8.08s	remaining: 23.3s
# 515:	total: 8.11s	remaining: 23.3s
# 516:	total: 8.15s	remaining: 23.4s
# 517:	total: 8.18s	remaining: 23.4s
# 518:	total: 8.22s	remaining: 23.5s
# 519:	total: 8.25s	remaining: 23.5s
# 520:	total: 8.29s	remaining: 23.5s
# 521:	total: 8.33s	remaining: 23.6s
# 522:	total: 8.36s	remaining: 23.6s
# 523:	total: 8.4s	remaining: 23.6s
# 524:	total: 8.43s	remaining: 23.7s
# 525:	total: 8.47s	remaining: 23.7s
# 526:	total: 8.51s	remaining: 23.8s
# 527:	total: 8.56s	remaining: 23.9s
# 528:	total: 8.59s	remaining: 23.9s
# 529:	total: 8.63s	remaining: 23.9s
# 530:	total: 8.66s	remaining: 24s
# 531:	total: 8.7s	remaining: 24s
# 532:	total: 8.73s	remaining: 24s
# 533:	total: 8.78s	remaining: 24.1s
# 534:	total: 8.82s	remaining: 24.2s
# 535:	total: 8.87s	remaining: 24.2s
# 536:	total: 8.91s	remaining: 24.3s
# 537:	total: 8.95s	remaining: 24.3s
# 538:	total: 8.99s	remaining: 24.4s
# 539:	total: 9.03s	remaining: 24.4s
# 540:	total: 9.08s	remaining: 24.5s
# 541:	total: 9.12s	remaining: 24.5s
# 542:	total: 9.16s	remaining: 24.6s
# 543:	total: 9.21s	remaining: 24.6s
# 544:	total: 9.24s	remaining: 24.7s
# 545:	total: 9.29s	remaining: 24.7s
# 546:	total: 9.33s	remaining: 24.8s
# 547:	total: 9.37s	remaining: 24.8s
# 548:	total: 9.43s	remaining: 24.9s
# 549:	total: 9.47s	remaining: 25s
# 550:	total: 9.52s	remaining: 25s
# 551:	total: 9.56s	remaining: 25.1s
# 552:	total: 9.6s	remaining: 25.1s
# 553:	total: 9.63s	remaining: 25.1s
# 554:	total: 9.67s	remaining: 25.2s
# 555:	total: 9.71s	remaining: 25.2s
# 556:	total: 9.75s	remaining: 25.3s
# 557:	total: 9.78s	remaining: 25.3s
# 558:	total: 9.82s	remaining: 25.3s
# 559:	total: 9.86s	remaining: 25.4s
# 560:	total: 9.89s	remaining: 25.4s
# 561:	total: 9.93s	remaining: 25.4s
# 562:	total: 9.96s	remaining: 25.4s
# 563:	total: 9.99s	remaining: 25.4s
# 564:	total: 10s	remaining: 25.5s
# 565:	total: 10.1s	remaining: 25.5s
# 566:	total: 10.1s	remaining: 25.6s
# 567:	total: 10.2s	remaining: 25.6s
# 568:	total: 10.2s	remaining: 25.6s
# 569:	total: 10.2s	remaining: 25.6s
# 570:	total: 10.2s	remaining: 25.6s
# 571:	total: 10.3s	remaining: 25.7s
# 572:	total: 10.3s	remaining: 25.7s
# 573:	total: 10.4s	remaining: 25.7s
# 574:	total: 10.4s	remaining: 25.8s
# 575:	total: 10.4s	remaining: 25.8s
# 576:	total: 10.5s	remaining: 25.8s
# 577:	total: 10.5s	remaining: 25.8s
# 578:	total: 10.5s	remaining: 25.8s
# 579:	total: 10.6s	remaining: 25.8s
# 580:	total: 10.6s	remaining: 25.9s
# 581:	total: 10.6s	remaining: 25.9s
# 582:	total: 10.7s	remaining: 25.9s
# 583:	total: 10.7s	remaining: 25.9s
# 584:	total: 10.7s	remaining: 25.9s
# 585:	total: 10.8s	remaining: 26s
# 586:	total: 10.8s	remaining: 26s
# 587:	total: 10.8s	remaining: 26s
# 588:	total: 10.8s	remaining: 26s
# 589:	total: 10.9s	remaining: 26s
# 590:	total: 10.9s	remaining: 26s
# 591:	total: 10.9s	remaining: 26s
# 592:	total: 11s	remaining: 26s
# 593:	total: 11s	remaining: 26.1s
# 594:	total: 11s	remaining: 26.1s
# 595:	total: 11.1s	remaining: 26.1s
# 596:	total: 11.1s	remaining: 26.1s
# 597:	total: 11.1s	remaining: 26.1s
# 598:	total: 11.2s	remaining: 26.1s
# 599:	total: 11.2s	remaining: 26.1s
# 600:	total: 11.2s	remaining: 26.2s
# 601:	total: 11.3s	remaining: 26.2s
# 602:	total: 11.3s	remaining: 26.2s
# 603:	total: 11.3s	remaining: 26.2s
# 604:	total: 11.4s	remaining: 26.2s
# 605:	total: 11.4s	remaining: 26.2s
# 606:	total: 11.4s	remaining: 26.2s
# 607:	total: 11.5s	remaining: 26.3s
# 608:	total: 11.5s	remaining: 26.3s
# 609:	total: 11.5s	remaining: 26.3s
# 610:	total: 11.6s	remaining: 26.3s
# 611:	total: 11.6s	remaining: 26.3s
# 612:	total: 11.6s	remaining: 26.3s
# 613:	total: 11.7s	remaining: 26.3s
# 614:	total: 11.7s	remaining: 26.3s
# 615:	total: 11.7s	remaining: 26.3s
# 616:	total: 11.7s	remaining: 26.3s
# 617:	total: 11.8s	remaining: 26.3s
# 618:	total: 11.8s	remaining: 26.3s
# 619:	total: 11.8s	remaining: 26.3s
# 620:	total: 11.9s	remaining: 26.3s
# 621:	total: 11.9s	remaining: 26.3s
# 622:	total: 11.9s	remaining: 26.3s
# 623:	total: 11.9s	remaining: 26.4s
# 624:	total: 12s	remaining: 26.4s
# 625:	total: 12s	remaining: 26.4s
# 626:	total: 12s	remaining: 26.4s
# 627:	total: 12.1s	remaining: 26.3s
# 628:	total: 12.1s	remaining: 26.3s
# 629:	total: 12.1s	remaining: 26.3s
# 630:	total: 12.1s	remaining: 26.4s
# 631:	total: 12.2s	remaining: 26.4s
# 632:	total: 12.2s	remaining: 26.4s
# 633:	total: 12.2s	remaining: 26.4s
# 634:	total: 12.3s	remaining: 26.4s
# 635:	total: 12.3s	remaining: 26.4s
# 636:	total: 12.3s	remaining: 26.4s
# 637:	total: 12.4s	remaining: 26.4s
# 638:	total: 12.4s	remaining: 26.4s
# 639:	total: 12.4s	remaining: 26.4s
# 640:	total: 12.4s	remaining: 26.4s
# 641:	total: 12.5s	remaining: 26.4s
# 642:	total: 12.5s	remaining: 26.4s
# 643:	total: 12.5s	remaining: 26.4s
# 644:	total: 12.6s	remaining: 26.4s
# 645:	total: 12.6s	remaining: 26.4s
# 646:	total: 12.6s	remaining: 26.4s
# 647:	total: 12.7s	remaining: 26.4s
# 648:	total: 12.7s	remaining: 26.4s
# 649:	total: 12.7s	remaining: 26.4s
# 650:	total: 12.7s	remaining: 26.4s
# 651:	total: 12.8s	remaining: 26.4s
# 652:	total: 12.8s	remaining: 26.4s
# 653:	total: 12.8s	remaining: 26.3s
# 654:	total: 12.8s	remaining: 26.3s
# 655:	total: 12.9s	remaining: 26.3s
# 656:	total: 12.9s	remaining: 26.3s
# 657:	total: 12.9s	remaining: 26.3s
# 658:	total: 12.9s	remaining: 26.3s
# 659:	total: 12.9s	remaining: 26.3s
# 660:	total: 13s	remaining: 26.3s
# 661:	total: 13s	remaining: 26.3s
# 662:	total: 13s	remaining: 26.3s
# 663:	total: 13s	remaining: 26.2s
# 664:	total: 13.1s	remaining: 26.2s
# 665:	total: 13.1s	remaining: 26.2s
# 666:	total: 13.1s	remaining: 26.2s
# 667:	total: 13.1s	remaining: 26.2s
# 668:	total: 13.2s	remaining: 26.2s
# 669:	total: 13.2s	remaining: 26.2s
# 670:	total: 13.2s	remaining: 26.2s
# 671:	total: 13.2s	remaining: 26.1s
# 672:	total: 13.3s	remaining: 26.1s
# 673:	total: 13.3s	remaining: 26.1s
# 674:	total: 13.3s	remaining: 26.1s
# 675:	total: 13.3s	remaining: 26.1s
# 676:	total: 13.4s	remaining: 26.1s
# 677:	total: 13.4s	remaining: 26.1s
# 678:	total: 13.4s	remaining: 26.1s
# 679:	total: 13.4s	remaining: 26.1s
# 680:	total: 13.4s	remaining: 26s
# 681:	total: 13.5s	remaining: 26s
# 682:	total: 13.5s	remaining: 26s
# 683:	total: 13.5s	remaining: 26s
# 684:	total: 13.5s	remaining: 26s
# 685:	total: 13.6s	remaining: 26s
# 686:	total: 13.6s	remaining: 26s
# 687:	total: 13.6s	remaining: 25.9s
# 688:	total: 13.6s	remaining: 25.9s
# 689:	total: 13.6s	remaining: 25.9s
# 690:	total: 13.7s	remaining: 25.9s
# 691:	total: 13.7s	remaining: 25.9s
# 692:	total: 13.7s	remaining: 25.9s
# 693:	total: 13.8s	remaining: 25.9s
# 694:	total: 13.8s	remaining: 25.9s
# 695:	total: 13.8s	remaining: 25.8s
# 696:	total: 13.8s	remaining: 25.8s
# 697:	total: 13.9s	remaining: 25.9s
# 698:	total: 13.9s	remaining: 25.8s
# 699:	total: 13.9s	remaining: 25.8s
# 700:	total: 13.9s	remaining: 25.8s
# 701:	total: 14s	remaining: 25.8s
# 702:	total: 14s	remaining: 25.8s
# 703:	total: 14s	remaining: 25.8s
# 704:	total: 14s	remaining: 25.8s
# 705:	total: 14s	remaining: 25.7s
# 706:	total: 14.1s	remaining: 25.7s
# 707:	total: 14.1s	remaining: 25.7s
# 708:	total: 14.1s	remaining: 25.7s
# 709:	total: 14.1s	remaining: 25.7s
# 710:	total: 14.1s	remaining: 25.6s
# 711:	total: 14.2s	remaining: 25.6s
# 712:	total: 14.2s	remaining: 25.6s
# 713:	total: 14.2s	remaining: 25.6s
# 714:	total: 14.2s	remaining: 25.6s
# 715:	total: 14.3s	remaining: 25.6s
# 716:	total: 14.3s	remaining: 25.6s
# 717:	total: 14.3s	remaining: 25.6s
# 718:	total: 14.3s	remaining: 25.5s
# 719:	total: 14.4s	remaining: 25.5s
# 720:	total: 14.4s	remaining: 25.5s
# 721:	total: 14.4s	remaining: 25.5s
# 722:	total: 14.4s	remaining: 25.5s
# 723:	total: 14.4s	remaining: 25.4s
# 724:	total: 14.5s	remaining: 25.4s
# 725:	total: 14.5s	remaining: 25.4s
# 726:	total: 14.5s	remaining: 25.4s
# 727:	total: 14.5s	remaining: 25.4s
# 728:	total: 14.5s	remaining: 25.3s
# 729:	total: 14.6s	remaining: 25.3s
# 730:	total: 14.6s	remaining: 25.3s
# 731:	total: 14.6s	remaining: 25.3s
# 732:	total: 14.6s	remaining: 25.3s
# 733:	total: 14.7s	remaining: 25.3s
# 734:	total: 14.7s	remaining: 25.3s
# 735:	total: 14.7s	remaining: 25.3s
# 736:	total: 14.7s	remaining: 25.2s
# 737:	total: 14.8s	remaining: 25.2s
# 738:	total: 14.8s	remaining: 25.2s
# 739:	total: 14.8s	remaining: 25.2s
# 740:	total: 14.8s	remaining: 25.2s
# 741:	total: 14.8s	remaining: 25.2s
# 742:	total: 14.9s	remaining: 25.1s
# 743:	total: 14.9s	remaining: 25.1s
# 744:	total: 14.9s	remaining: 25.1s
# 745:	total: 14.9s	remaining: 25.1s
# 746:	total: 15s	remaining: 25.1s
# 747:	total: 15s	remaining: 25.1s
# 748:	total: 15s	remaining: 25.1s
# 749:	total: 15s	remaining: 25s
# 750:	total: 15s	remaining: 25s
# 751:	total: 15.1s	remaining: 25s
# 752:	total: 15.1s	remaining: 25s
# 753:	total: 15.1s	remaining: 25s
# 754:	total: 15.1s	remaining: 25s
# 755:	total: 15.2s	remaining: 24.9s
# 756:	total: 15.2s	remaining: 24.9s
# 757:	total: 15.2s	remaining: 24.9s
# 758:	total: 15.2s	remaining: 24.9s
# 759:	total: 15.3s	remaining: 24.9s
# 760:	total: 15.3s	remaining: 24.9s
# 761:	total: 15.3s	remaining: 24.9s
# 762:	total: 15.3s	remaining: 24.8s
# 763:	total: 15.3s	remaining: 24.8s
# 764:	total: 15.4s	remaining: 24.8s
# 765:	total: 15.4s	remaining: 24.8s
# 766:	total: 15.4s	remaining: 24.8s
# 767:	total: 15.4s	remaining: 24.8s
# 768:	total: 15.5s	remaining: 24.7s
# 769:	total: 15.5s	remaining: 24.7s
# 770:	total: 15.5s	remaining: 24.7s
# 771:	total: 15.5s	remaining: 24.7s
# 772:	total: 15.5s	remaining: 24.7s
# 773:	total: 15.6s	remaining: 24.7s
# 774:	total: 15.6s	remaining: 24.6s
# 775:	total: 15.6s	remaining: 24.6s
# 776:	total: 15.6s	remaining: 24.6s
# 777:	total: 15.7s	remaining: 24.6s
# 778:	total: 15.7s	remaining: 24.6s
# 779:	total: 15.7s	remaining: 24.6s
# 780:	total: 15.7s	remaining: 24.5s
# 781:	total: 15.7s	remaining: 24.5s
# 782:	total: 15.8s	remaining: 24.5s
# 783:	total: 15.8s	remaining: 24.5s
# 784:	total: 15.8s	remaining: 24.5s
# 785:	total: 15.8s	remaining: 24.4s
# 786:	total: 15.9s	remaining: 24.4s
# 787:	total: 15.9s	remaining: 24.4s
# 788:	total: 15.9s	remaining: 24.4s
# 789:	total: 15.9s	remaining: 24.4s
# 790:	total: 15.9s	remaining: 24.4s
# 791:	total: 16s	remaining: 24.3s
# 792:	total: 16s	remaining: 24.3s
# 793:	total: 16s	remaining: 24.3s
# 794:	total: 16s	remaining: 24.3s
# 795:	total: 16s	remaining: 24.3s
# 796:	total: 16.1s	remaining: 24.3s
# 797:	total: 16.1s	remaining: 24.2s
# 798:	total: 16.1s	remaining: 24.2s
# 799:	total: 16.1s	remaining: 24.2s
# 800:	total: 16.2s	remaining: 24.2s
# 801:	total: 16.2s	remaining: 24.2s
# 802:	total: 16.2s	remaining: 24.1s
# 803:	total: 16.2s	remaining: 24.1s
# 804:	total: 16.2s	remaining: 24.1s
# 805:	total: 16.3s	remaining: 24.1s
# 806:	total: 16.3s	remaining: 24.1s
# 807:	total: 16.3s	remaining: 24s
# 808:	total: 16.3s	remaining: 24s
# 809:	total: 16.3s	remaining: 24s
# 810:	total: 16.4s	remaining: 24s
# 811:	total: 16.4s	remaining: 24s
# 812:	total: 16.4s	remaining: 23.9s
# 813:	total: 16.4s	remaining: 23.9s
# 814:	total: 16.4s	remaining: 23.9s
# 815:	total: 16.4s	remaining: 23.9s
# 816:	total: 16.5s	remaining: 23.8s
# 817:	total: 16.5s	remaining: 23.8s
# 818:	total: 16.5s	remaining: 23.8s
# 819:	total: 16.5s	remaining: 23.8s
# 820:	total: 16.6s	remaining: 23.8s
# 821:	total: 16.6s	remaining: 23.8s
# 822:	total: 16.6s	remaining: 23.7s
# 823:	total: 16.6s	remaining: 23.7s
# 824:	total: 16.6s	remaining: 23.7s
# 825:	total: 16.6s	remaining: 23.7s
# 826:	total: 16.7s	remaining: 23.6s
# 827:	total: 16.7s	remaining: 23.6s
# 828:	total: 16.7s	remaining: 23.6s
# 829:	total: 16.7s	remaining: 23.6s
# 830:	total: 16.7s	remaining: 23.6s
# 831:	total: 16.8s	remaining: 23.5s
# 832:	total: 16.8s	remaining: 23.5s
# 833:	total: 16.8s	remaining: 23.5s
# 834:	total: 16.8s	remaining: 23.5s
# 835:	total: 16.8s	remaining: 23.4s
# 836:	total: 16.9s	remaining: 23.4s
# 837:	total: 16.9s	remaining: 23.4s
# 838:	total: 16.9s	remaining: 23.4s
# 839:	total: 16.9s	remaining: 23.4s
# 840:	total: 16.9s	remaining: 23.3s
# 841:	total: 17s	remaining: 23.3s
# 842:	total: 17s	remaining: 23.3s
# 843:	total: 17s	remaining: 23.3s
# 844:	total: 17s	remaining: 23.3s
# 845:	total: 17s	remaining: 23.2s
# 846:	total: 17.1s	remaining: 23.2s
# 847:	total: 17.1s	remaining: 23.2s
# 848:	total: 17.1s	remaining: 23.2s
# 849:	total: 17.1s	remaining: 23.2s
# 850:	total: 17.1s	remaining: 23.1s
# 851:	total: 17.2s	remaining: 23.1s
# 852:	total: 17.2s	remaining: 23.1s
# 853:	total: 17.2s	remaining: 23.1s
# 854:	total: 17.2s	remaining: 23s
# 855:	total: 17.2s	remaining: 23s
# 856:	total: 17.2s	remaining: 23s
# 857:	total: 17.3s	remaining: 23s
# 858:	total: 17.3s	remaining: 23s
# 859:	total: 17.3s	remaining: 22.9s
# 860:	total: 17.3s	remaining: 22.9s
# 861:	total: 17.3s	remaining: 22.9s
# 862:	total: 17.4s	remaining: 22.9s
# 863:	total: 17.4s	remaining: 22.9s
# 864:	total: 17.4s	remaining: 22.8s
# 865:	total: 17.4s	remaining: 22.8s
# 866:	total: 17.4s	remaining: 22.8s
# 867:	total: 17.5s	remaining: 22.8s
# 868:	total: 17.5s	remaining: 22.7s
# 869:	total: 17.5s	remaining: 22.7s
# 870:	total: 17.5s	remaining: 22.7s
# 871:	total: 17.5s	remaining: 22.7s
# 872:	total: 17.6s	remaining: 22.7s
# 873:	total: 17.6s	remaining: 22.6s
# 874:	total: 17.6s	remaining: 22.6s
# 875:	total: 17.6s	remaining: 22.6s
# 876:	total: 17.6s	remaining: 22.6s
# 877:	total: 17.6s	remaining: 22.6s
# 878:	total: 17.7s	remaining: 22.5s
# 879:	total: 17.7s	remaining: 22.5s
# 880:	total: 17.7s	remaining: 22.5s
# 881:	total: 17.7s	remaining: 22.5s
# 882:	total: 17.7s	remaining: 22.4s
# 883:	total: 17.8s	remaining: 22.4s
# 884:	total: 17.8s	remaining: 22.4s
# 885:	total: 17.8s	remaining: 22.4s
# 886:	total: 17.8s	remaining: 22.4s
# 887:	total: 17.8s	remaining: 22.3s
# 888:	total: 17.9s	remaining: 22.3s
# 889:	total: 17.9s	remaining: 22.3s
# 890:	total: 17.9s	remaining: 22.3s
# 891:	total: 17.9s	remaining: 22.3s
# 892:	total: 17.9s	remaining: 22.2s
# 893:	total: 18s	remaining: 22.2s
# 894:	total: 18s	remaining: 22.2s
# 895:	total: 18s	remaining: 22.2s
# 896:	total: 18s	remaining: 22.2s
# 897:	total: 18s	remaining: 22.1s
# 898:	total: 18.1s	remaining: 22.1s
# 899:	total: 18.1s	remaining: 22.1s
# 900:	total: 18.1s	remaining: 22.1s
# 901:	total: 18.1s	remaining: 22.1s
# 902:	total: 18.1s	remaining: 22s
# 903:	total: 18.2s	remaining: 22s
# 904:	total: 18.2s	remaining: 22s
# 905:	total: 18.2s	remaining: 22s
# 906:	total: 18.2s	remaining: 22s
# 907:	total: 18.3s	remaining: 22s
# 908:	total: 18.3s	remaining: 21.9s
# 909:	total: 18.3s	remaining: 21.9s
# 910:	total: 18.3s	remaining: 21.9s
# 911:	total: 18.3s	remaining: 21.9s
# 912:	total: 18.3s	remaining: 21.8s
# 913:	total: 18.4s	remaining: 21.8s
# 914:	total: 18.4s	remaining: 21.8s
# 915:	total: 18.4s	remaining: 21.8s
# 916:	total: 18.4s	remaining: 21.8s
# 917:	total: 18.4s	remaining: 21.7s
# 918:	total: 18.5s	remaining: 21.7s
# 919:	total: 18.5s	remaining: 21.7s
# 920:	total: 18.5s	remaining: 21.7s
# 921:	total: 18.5s	remaining: 21.6s
# 922:	total: 18.5s	remaining: 21.6s
# 923:	total: 18.6s	remaining: 21.6s
# 924:	total: 18.6s	remaining: 21.6s
# 925:	total: 18.6s	remaining: 21.6s
# 926:	total: 18.6s	remaining: 21.6s
# 927:	total: 18.6s	remaining: 21.5s
# 928:	total: 18.7s	remaining: 21.5s
# 929:	total: 18.7s	remaining: 21.5s
# 930:	total: 18.7s	remaining: 21.5s
# 931:	total: 18.7s	remaining: 21.5s
# 932:	total: 18.8s	remaining: 21.5s
# 933:	total: 18.8s	remaining: 21.4s
# 934:	total: 18.8s	remaining: 21.4s
# 935:	total: 18.8s	remaining: 21.4s
# 936:	total: 18.8s	remaining: 21.4s
# 937:	total: 18.9s	remaining: 21.4s
# 938:	total: 18.9s	remaining: 21.3s
# 939:	total: 18.9s	remaining: 21.3s
# 940:	total: 18.9s	remaining: 21.3s
# 941:	total: 18.9s	remaining: 21.3s
# 942:	total: 19s	remaining: 21.3s
# 943:	total: 19s	remaining: 21.2s
# 944:	total: 19s	remaining: 21.2s
# 945:	total: 19s	remaining: 21.2s
# 946:	total: 19s	remaining: 21.2s
# 947:	total: 19.1s	remaining: 21.2s
# 948:	total: 19.1s	remaining: 21.1s
# 949:	total: 19.1s	remaining: 21.1s
# 950:	total: 19.1s	remaining: 21.1s
# 951:	total: 19.1s	remaining: 21.1s
# 952:	total: 19.2s	remaining: 21s
# 953:	total: 19.2s	remaining: 21s
# 954:	total: 19.2s	remaining: 21s
# 955:	total: 19.2s	remaining: 21s
# 956:	total: 19.2s	remaining: 21s
# 957:	total: 19.3s	remaining: 20.9s
# 958:	total: 19.3s	remaining: 20.9s
# 959:	total: 19.3s	remaining: 20.9s
# 960:	total: 19.3s	remaining: 20.9s
# 961:	total: 19.3s	remaining: 20.9s
# 962:	total: 19.4s	remaining: 20.9s
# 963:	total: 19.4s	remaining: 20.8s
# 964:	total: 19.4s	remaining: 20.8s
# 965:	total: 19.4s	remaining: 20.8s
# 966:	total: 19.5s	remaining: 20.8s
# 967:	total: 19.5s	remaining: 20.8s
# 968:	total: 19.5s	remaining: 20.7s
# 969:	total: 19.5s	remaining: 20.7s
# 970:	total: 19.5s	remaining: 20.7s
# 971:	total: 19.6s	remaining: 20.7s
# 972:	total: 19.6s	remaining: 20.7s
# 973:	total: 19.6s	remaining: 20.6s
# 974:	total: 19.6s	remaining: 20.6s
# 975:	total: 19.6s	remaining: 20.6s
# 976:	total: 19.7s	remaining: 20.6s
# 977:	total: 19.7s	remaining: 20.6s
# 978:	total: 19.7s	remaining: 20.5s
# 979:	total: 19.7s	remaining: 20.5s
# 980:	total: 19.7s	remaining: 20.5s
# 981:	total: 19.7s	remaining: 20.5s
# 982:	total: 19.8s	remaining: 20.4s
# 983:	total: 19.8s	remaining: 20.4s
# 984:	total: 19.8s	remaining: 20.4s
# 985:	total: 19.8s	remaining: 20.4s
# 986:	total: 19.8s	remaining: 20.4s
# 987:	total: 19.9s	remaining: 20.3s
# 988:	total: 19.9s	remaining: 20.3s
# 989:	total: 19.9s	remaining: 20.3s
# 990:	total: 19.9s	remaining: 20.3s
# 991:	total: 19.9s	remaining: 20.3s
# 992:	total: 20s	remaining: 20.2s
# 993:	total: 20s	remaining: 20.2s
# 994:	total: 20s	remaining: 20.2s
# 995:	total: 20s	remaining: 20.2s
# 996:	total: 20s	remaining: 20.2s
# 997:	total: 20.1s	remaining: 20.1s
# 998:	total: 20.1s	remaining: 20.1s
# 999:	total: 20.1s	remaining: 20.1s
# 1000:	total: 20.1s	remaining: 20.1s
# 1001:	total: 20.1s	remaining: 20.1s
# 1002:	total: 20.2s	remaining: 20s
# 1003:	total: 20.2s	remaining: 20s
# 1004:	total: 20.2s	remaining: 20s
# 1005:	total: 20.2s	remaining: 20s
# 1006:	total: 20.2s	remaining: 20s
# 1007:	total: 20.3s	remaining: 19.9s
# 1008:	total: 20.3s	remaining: 19.9s
# 1009:	total: 20.3s	remaining: 19.9s
# 1010:	total: 20.3s	remaining: 19.9s
# 1011:	total: 20.4s	remaining: 19.9s
# 1012:	total: 20.4s	remaining: 19.8s
# 1013:	total: 20.4s	remaining: 19.8s
# 1014:	total: 20.4s	remaining: 19.8s
# 1015:	total: 20.4s	remaining: 19.8s
# 1016:	total: 20.5s	remaining: 19.8s
# 1017:	total: 20.5s	remaining: 19.8s
# 1018:	total: 20.5s	remaining: 19.7s
# 1019:	total: 20.5s	remaining: 19.7s
# 1020:	total: 20.6s	remaining: 19.7s
# 1021:	total: 20.6s	remaining: 19.7s
# 1022:	total: 20.6s	remaining: 19.7s
# 1023:	total: 20.6s	remaining: 19.7s
# 1024:	total: 20.6s	remaining: 19.6s
# 1025:	total: 20.7s	remaining: 19.6s
# 1026:	total: 20.7s	remaining: 19.6s
# 1027:	total: 20.7s	remaining: 19.6s
# 1028:	total: 20.7s	remaining: 19.6s
# 1029:	total: 20.7s	remaining: 19.5s
# 1030:	total: 20.8s	remaining: 19.5s
# 1031:	total: 20.8s	remaining: 19.5s
# 1032:	total: 20.8s	remaining: 19.5s
# 1033:	total: 20.8s	remaining: 19.4s
# 1034:	total: 20.8s	remaining: 19.4s
# 1035:	total: 20.8s	remaining: 19.4s
# 1036:	total: 20.9s	remaining: 19.4s
# 1037:	total: 20.9s	remaining: 19.4s
# 1038:	total: 20.9s	remaining: 19.3s
# 1039:	total: 20.9s	remaining: 19.3s
# 1040:	total: 20.9s	remaining: 19.3s
# 1041:	total: 21s	remaining: 19.3s
# 1042:	total: 21s	remaining: 19.3s
# 1043:	total: 21s	remaining: 19.2s
# 1044:	total: 21s	remaining: 19.2s
# 1045:	total: 21.1s	remaining: 19.2s
# 1046:	total: 21.1s	remaining: 19.2s
# 1047:	total: 21.1s	remaining: 19.2s
# 1048:	total: 21.1s	remaining: 19.1s
# 1049:	total: 21.1s	remaining: 19.1s
# 1050:	total: 21.2s	remaining: 19.1s
# 1051:	total: 21.2s	remaining: 19.1s
# 1052:	total: 21.2s	remaining: 19.1s
# 1053:	total: 21.2s	remaining: 19s
# 1054:	total: 21.2s	remaining: 19s
# 1055:	total: 21.3s	remaining: 19s
# 1056:	total: 21.3s	remaining: 19s
# 1057:	total: 21.3s	remaining: 19s
# 1058:	total: 21.3s	remaining: 19s
# 1059:	total: 21.4s	remaining: 18.9s
# 1060:	total: 21.4s	remaining: 18.9s
# 1061:	total: 21.4s	remaining: 18.9s
# 1062:	total: 21.4s	remaining: 18.9s
# 1063:	total: 21.4s	remaining: 18.9s
# 1064:	total: 21.5s	remaining: 18.8s
# 1065:	total: 21.5s	remaining: 18.8s
# 1066:	total: 21.5s	remaining: 18.8s
# 1067:	total: 21.5s	remaining: 18.8s
# 1068:	total: 21.6s	remaining: 18.8s
# 1069:	total: 21.6s	remaining: 18.8s
# 1070:	total: 21.6s	remaining: 18.7s
# 1071:	total: 21.6s	remaining: 18.7s
# 1072:	total: 21.6s	remaining: 18.7s
# 1073:	total: 21.7s	remaining: 18.7s
# 1074:	total: 21.7s	remaining: 18.7s
# 1075:	total: 21.7s	remaining: 18.6s
# 1076:	total: 21.7s	remaining: 18.6s
# 1077:	total: 21.8s	remaining: 18.6s
# 1078:	total: 21.8s	remaining: 18.6s
# 1079:	total: 21.8s	remaining: 18.6s
# 1080:	total: 21.8s	remaining: 18.6s
# 1081:	total: 21.9s	remaining: 18.6s
# 1082:	total: 21.9s	remaining: 18.5s
# 1083:	total: 21.9s	remaining: 18.5s
# 1084:	total: 21.9s	remaining: 18.5s
# 1085:	total: 22s	remaining: 18.5s
# 1086:	total: 22s	remaining: 18.5s
# 1087:	total: 22s	remaining: 18.4s
# 1088:	total: 22s	remaining: 18.4s
# 1089:	total: 22s	remaining: 18.4s
# 1090:	total: 22.1s	remaining: 18.4s
# 1091:	total: 22.1s	remaining: 18.4s
# 1092:	total: 22.1s	remaining: 18.3s
# 1093:	total: 22.1s	remaining: 18.3s
# 1094:	total: 22.1s	remaining: 18.3s
# 1095:	total: 22.2s	remaining: 18.3s
# 1096:	total: 22.2s	remaining: 18.3s
# 1097:	total: 22.2s	remaining: 18.2s
# 1098:	total: 22.2s	remaining: 18.2s
# 1099:	total: 22.3s	remaining: 18.2s
# 1100:	total: 22.3s	remaining: 18.2s
# 1101:	total: 22.3s	remaining: 18.2s
# 1102:	total: 22.3s	remaining: 18.2s
# 1103:	total: 22.3s	remaining: 18.1s
# 1104:	total: 22.4s	remaining: 18.1s
# 1105:	total: 22.4s	remaining: 18.1s
# 1106:	total: 22.4s	remaining: 18.1s
# 1107:	total: 22.4s	remaining: 18.1s
# 1108:	total: 22.4s	remaining: 18s
# 1109:	total: 22.5s	remaining: 18s
# 1110:	total: 22.5s	remaining: 18s
# 1111:	total: 22.5s	remaining: 18s
# 1112:	total: 22.5s	remaining: 18s
# 1113:	total: 22.5s	remaining: 17.9s
# 1114:	total: 22.6s	remaining: 17.9s
# 1115:	total: 22.6s	remaining: 17.9s
# 1116:	total: 22.6s	remaining: 17.9s
# 1117:	total: 22.6s	remaining: 17.9s
# 1118:	total: 22.7s	remaining: 17.9s
# 1119:	total: 22.7s	remaining: 17.8s
# 1120:	total: 22.7s	remaining: 17.8s
# 1121:	total: 22.7s	remaining: 17.8s
# 1122:	total: 22.8s	remaining: 17.8s
# 1123:	total: 22.8s	remaining: 17.8s
# 1124:	total: 22.8s	remaining: 17.7s
# 1125:	total: 22.8s	remaining: 17.7s
# 1126:	total: 22.9s	remaining: 17.7s
# 1127:	total: 22.9s	remaining: 17.7s
# 1128:	total: 22.9s	remaining: 17.7s
# 1129:	total: 22.9s	remaining: 17.7s
# 1130:	total: 23s	remaining: 17.6s
# 1131:	total: 23s	remaining: 17.6s
# 1132:	total: 23s	remaining: 17.6s
# 1133:	total: 23s	remaining: 17.6s
# 1134:	total: 23.1s	remaining: 17.6s
# 1135:	total: 23.1s	remaining: 17.6s
# 1136:	total: 23.1s	remaining: 17.5s
# 1137:	total: 23.1s	remaining: 17.5s
# 1138:	total: 23.2s	remaining: 17.5s
# 1139:	total: 23.2s	remaining: 17.5s
# 1140:	total: 23.2s	remaining: 17.5s
# 1141:	total: 23.2s	remaining: 17.4s
# 1142:	total: 23.2s	remaining: 17.4s
# 1143:	total: 23.3s	remaining: 17.4s
# 1144:	total: 23.3s	remaining: 17.4s
# 1145:	total: 23.3s	remaining: 17.4s
# 1146:	total: 23.3s	remaining: 17.3s
# 1147:	total: 23.3s	remaining: 17.3s
# 1148:	total: 23.4s	remaining: 17.3s
# 1149:	total: 23.4s	remaining: 17.3s
# 1150:	total: 23.4s	remaining: 17.3s
# 1151:	total: 23.4s	remaining: 17.2s
# 1152:	total: 23.4s	remaining: 17.2s
# 1153:	total: 23.5s	remaining: 17.2s
# 1154:	total: 23.5s	remaining: 17.2s
# 1155:	total: 23.5s	remaining: 17.2s
# 1156:	total: 23.5s	remaining: 17.1s
# 1157:	total: 23.6s	remaining: 17.1s
# 1158:	total: 23.6s	remaining: 17.1s
# 1159:	total: 23.6s	remaining: 17.1s
# 1160:	total: 23.6s	remaining: 17.1s
# 1161:	total: 23.6s	remaining: 17s
# 1162:	total: 23.7s	remaining: 17s
# 1163:	total: 23.7s	remaining: 17s
# 1164:	total: 23.7s	remaining: 17s
# 1165:	total: 23.7s	remaining: 17s
# 1166:	total: 23.8s	remaining: 17s
# 1167:	total: 23.8s	remaining: 16.9s
# 1168:	total: 23.8s	remaining: 16.9s
# 1169:	total: 23.8s	remaining: 16.9s
# 1170:	total: 23.8s	remaining: 16.9s
# 1171:	total: 23.9s	remaining: 16.9s
# 1172:	total: 23.9s	remaining: 16.8s
# 1173:	total: 23.9s	remaining: 16.8s
# 1174:	total: 23.9s	remaining: 16.8s
# 1175:	total: 23.9s	remaining: 16.8s
# 1176:	total: 24s	remaining: 16.8s
# 1177:	total: 24s	remaining: 16.7s
# 1178:	total: 24s	remaining: 16.7s
# 1179:	total: 24s	remaining: 16.7s
# 1180:	total: 24.1s	remaining: 16.7s
# 1181:	total: 24.1s	remaining: 16.7s
# 1182:	total: 24.1s	remaining: 16.7s
# 1183:	total: 24.2s	remaining: 16.6s
# 1184:	total: 24.2s	remaining: 16.6s
# 1185:	total: 24.2s	remaining: 16.6s
# 1186:	total: 24.2s	remaining: 16.6s
# 1187:	total: 24.2s	remaining: 16.6s
# 1188:	total: 24.3s	remaining: 16.5s
# 1189:	total: 24.3s	remaining: 16.5s
# 1190:	total: 24.3s	remaining: 16.5s
# 1191:	total: 24.3s	remaining: 16.5s
# 1192:	total: 24.4s	remaining: 16.5s
# 1193:	total: 24.4s	remaining: 16.5s
# 1194:	total: 24.4s	remaining: 16.4s
# 1195:	total: 24.4s	remaining: 16.4s
# 1196:	total: 24.4s	remaining: 16.4s
# 1197:	total: 24.5s	remaining: 16.4s
# 1198:	total: 24.5s	remaining: 16.4s
# 1199:	total: 24.5s	remaining: 16.3s
# 1200:	total: 24.5s	remaining: 16.3s
# 1201:	total: 24.5s	remaining: 16.3s
# 1202:	total: 24.6s	remaining: 16.3s
# 1203:	total: 24.6s	remaining: 16.3s
# 1204:	total: 24.6s	remaining: 16.2s
# 1205:	total: 24.6s	remaining: 16.2s
# 1206:	total: 24.7s	remaining: 16.2s
# 1207:	total: 24.7s	remaining: 16.2s
# 1208:	total: 24.7s	remaining: 16.2s
# 1209:	total: 24.7s	remaining: 16.1s
# 1210:	total: 24.8s	remaining: 16.1s
# 1211:	total: 24.8s	remaining: 16.1s
# 1212:	total: 24.8s	remaining: 16.1s
# 1213:	total: 24.8s	remaining: 16.1s
# 1214:	total: 24.9s	remaining: 16.1s
# 1215:	total: 24.9s	remaining: 16s
# 1216:	total: 24.9s	remaining: 16s
# 1217:	total: 24.9s	remaining: 16s
# 1218:	total: 24.9s	remaining: 16s
# 1219:	total: 25s	remaining: 16s
# 1220:	total: 25s	remaining: 15.9s
# 1221:	total: 25s	remaining: 15.9s
# 1222:	total: 25s	remaining: 15.9s
# 1223:	total: 25s	remaining: 15.9s
# 1224:	total: 25.1s	remaining: 15.9s
# 1225:	total: 25.1s	remaining: 15.8s
# 1226:	total: 25.1s	remaining: 15.8s
# 1227:	total: 25.1s	remaining: 15.8s
# 1228:	total: 25.1s	remaining: 15.8s
# 1229:	total: 25.2s	remaining: 15.8s
# 1230:	total: 25.2s	remaining: 15.7s
# 1231:	total: 25.2s	remaining: 15.7s
# 1232:	total: 25.2s	remaining: 15.7s
# 1233:	total: 25.2s	remaining: 15.7s
# 1234:	total: 25.3s	remaining: 15.7s
# 1235:	total: 25.3s	remaining: 15.6s
# 1236:	total: 25.3s	remaining: 15.6s
# 1237:	total: 25.3s	remaining: 15.6s
# 1238:	total: 25.3s	remaining: 15.6s
# 1239:	total: 25.4s	remaining: 15.5s
# 1240:	total: 25.4s	remaining: 15.5s
# 1241:	total: 25.4s	remaining: 15.5s
# 1242:	total: 25.4s	remaining: 15.5s
# 1243:	total: 25.4s	remaining: 15.5s
# 1244:	total: 25.5s	remaining: 15.4s
# 1245:	total: 25.5s	remaining: 15.4s
# 1246:	total: 25.5s	remaining: 15.4s
# 1247:	total: 25.5s	remaining: 15.4s
# 1248:	total: 25.5s	remaining: 15.4s
# 1249:	total: 25.6s	remaining: 15.3s
# 1250:	total: 25.6s	remaining: 15.3s
# 1251:	total: 25.6s	remaining: 15.3s
# 1252:	total: 25.6s	remaining: 15.3s
# 1253:	total: 25.7s	remaining: 15.3s
# 1254:	total: 25.7s	remaining: 15.2s
# 1255:	total: 25.7s	remaining: 15.2s
# 1256:	total: 25.7s	remaining: 15.2s
# 1257:	total: 25.7s	remaining: 15.2s
# 1258:	total: 25.7s	remaining: 15.2s
# 1259:	total: 25.8s	remaining: 15.1s
# 1260:	total: 25.8s	remaining: 15.1s
# 1261:	total: 25.8s	remaining: 15.1s
# 1262:	total: 25.8s	remaining: 15.1s
# 1263:	total: 25.9s	remaining: 15.1s
# 1264:	total: 25.9s	remaining: 15s
# 1265:	total: 25.9s	remaining: 15s
# 1266:	total: 25.9s	remaining: 15s
# 1267:	total: 26s	remaining: 15s
# 1268:	total: 26s	remaining: 15s
# 1269:	total: 26.1s	remaining: 15s
# 1270:	total: 26.1s	remaining: 15s
# 1271:	total: 26.1s	remaining: 15s
# 1272:	total: 26.2s	remaining: 14.9s
# 1273:	total: 26.2s	remaining: 14.9s
# 1274:	total: 26.2s	remaining: 14.9s
# 1275:	total: 26.2s	remaining: 14.9s
# 1276:	total: 26.3s	remaining: 14.9s
# 1277:	total: 26.3s	remaining: 14.8s
# 1278:	total: 26.3s	remaining: 14.8s
# 1279:	total: 26.3s	remaining: 14.8s
# 1280:	total: 26.3s	remaining: 14.8s
# 1281:	total: 26.4s	remaining: 14.8s
# 1282:	total: 26.4s	remaining: 14.8s
# 1283:	total: 26.4s	remaining: 14.7s
# 1284:	total: 26.4s	remaining: 14.7s
# 1285:	total: 26.5s	remaining: 14.7s
# 1286:	total: 26.5s	remaining: 14.7s
# 1287:	total: 26.5s	remaining: 14.7s
# 1288:	total: 26.5s	remaining: 14.6s
# 1289:	total: 26.6s	remaining: 14.6s
# 1290:	total: 26.6s	remaining: 14.6s
# 1291:	total: 26.6s	remaining: 14.6s
# 1292:	total: 26.6s	remaining: 14.6s
# 1293:	total: 26.6s	remaining: 14.5s
# 1294:	total: 26.7s	remaining: 14.5s
# 1295:	total: 26.7s	remaining: 14.5s
# 1296:	total: 26.7s	remaining: 14.5s
# 1297:	total: 26.7s	remaining: 14.5s
# 1298:	total: 26.8s	remaining: 14.4s
# 1299:	total: 26.8s	remaining: 14.4s
# 1300:	total: 26.8s	remaining: 14.4s
# 1301:	total: 26.8s	remaining: 14.4s
# 1302:	total: 26.8s	remaining: 14.4s
# 1303:	total: 26.9s	remaining: 14.3s
# 1304:	total: 26.9s	remaining: 14.3s
# 1305:	total: 26.9s	remaining: 14.3s
# 1306:	total: 26.9s	remaining: 14.3s
# 1307:	total: 26.9s	remaining: 14.3s
# 1308:	total: 27s	remaining: 14.2s
# 1309:	total: 27s	remaining: 14.2s
# 1310:	total: 27s	remaining: 14.2s
# 1311:	total: 27s	remaining: 14.2s
# 1312:	total: 27.1s	remaining: 14.2s
# 1313:	total: 27.1s	remaining: 14.1s
# 1314:	total: 27.1s	remaining: 14.1s
# 1315:	total: 27.1s	remaining: 14.1s
# 1316:	total: 27.1s	remaining: 14.1s
# 1317:	total: 27.2s	remaining: 14.1s
# 1318:	total: 27.2s	remaining: 14s
# 1319:	total: 27.2s	remaining: 14s
# 1320:	total: 27.2s	remaining: 14s
# 1321:	total: 27.2s	remaining: 14s
# 1322:	total: 27.3s	remaining: 14s
# 1323:	total: 27.3s	remaining: 13.9s
# 1324:	total: 27.3s	remaining: 13.9s
# 1325:	total: 27.3s	remaining: 13.9s
# 1326:	total: 27.4s	remaining: 13.9s
# 1327:	total: 27.4s	remaining: 13.9s
# 1328:	total: 27.4s	remaining: 13.8s
# 1329:	total: 27.4s	remaining: 13.8s
# 1330:	total: 27.4s	remaining: 13.8s
# 1331:	total: 27.5s	remaining: 13.8s
# 1332:	total: 27.5s	remaining: 13.7s
# 1333:	total: 27.5s	remaining: 13.7s
# 1334:	total: 27.5s	remaining: 13.7s
# 1335:	total: 27.5s	remaining: 13.7s
# 1336:	total: 27.6s	remaining: 13.7s
# 1337:	total: 27.6s	remaining: 13.6s
# 1338:	total: 27.6s	remaining: 13.6s
# 1339:	total: 27.6s	remaining: 13.6s
# 1340:	total: 27.6s	remaining: 13.6s
# 1341:	total: 27.7s	remaining: 13.6s
# 1342:	total: 27.7s	remaining: 13.5s
# 1343:	total: 27.7s	remaining: 13.5s
# 1344:	total: 27.7s	remaining: 13.5s
# 1345:	total: 27.7s	remaining: 13.5s
# 1346:	total: 27.8s	remaining: 13.5s
# 1347:	total: 27.8s	remaining: 13.4s
# 1348:	total: 27.8s	remaining: 13.4s
# 1349:	total: 27.8s	remaining: 13.4s
# 1350:	total: 27.8s	remaining: 13.4s
# 1351:	total: 27.9s	remaining: 13.4s
# 1352:	total: 27.9s	remaining: 13.3s
# 1353:	total: 27.9s	remaining: 13.3s
# 1354:	total: 27.9s	remaining: 13.3s
# 1355:	total: 27.9s	remaining: 13.3s
# 1356:	total: 28s	remaining: 13.2s
# 1357:	total: 28s	remaining: 13.2s
# 1358:	total: 28s	remaining: 13.2s
# 1359:	total: 28s	remaining: 13.2s
# 1360:	total: 28s	remaining: 13.2s
# 1361:	total: 28.1s	remaining: 13.1s
# 1362:	total: 28.1s	remaining: 13.1s
# 1363:	total: 28.1s	remaining: 13.1s
# 1364:	total: 28.1s	remaining: 13.1s
# 1365:	total: 28.1s	remaining: 13.1s
# 1366:	total: 28.2s	remaining: 13s
# 1367:	total: 28.2s	remaining: 13s
# 1368:	total: 28.2s	remaining: 13s
# 1369:	total: 28.2s	remaining: 13s
# 1370:	total: 28.2s	remaining: 12.9s
# 1371:	total: 28.2s	remaining: 12.9s
# 1372:	total: 28.3s	remaining: 12.9s
# 1373:	total: 28.3s	remaining: 12.9s
# 1374:	total: 28.3s	remaining: 12.9s
# 1375:	total: 28.3s	remaining: 12.8s
# ...
# 1552:	total: 31.8s	remaining: 9.16s
# 1553:	total: 31.9s	remaining: 9.14s
# 1554:	total: 31.9s	remaining: 9.12s
# 1555:	total: 31.9s	remaining: 9.1s
# 1556:	total: 31.9s	remaining: 9.08s
# 1557:	total: 31.9s	remaining: 9.06s
# 1558:	total: 32s	remaining: 9.04s
# 1559:	total: 32s	remaining: 9.02s
# 1560:	total: 32s	remaining: 9s
# 1561:	total: 32s	remaining: 8.98s
# 1562:	total: 32s	remaining: 8.96s
# 1563:	total: 32.1s	remaining: 8.94s
# 1564:	total: 32.1s	remaining: 8.92s
# 1565:	total: 32.1s	remaining: 8.9s
# 1566:	total: 32.1s	remaining: 8.88s
# 1567:	total: 32.1s	remaining: 8.86s
# 1568:	total: 32.2s	remaining: 8.84s
# 1569:	total: 32.2s	remaining: 8.82s
# 1570:	total: 32.2s	remaining: 8.79s
# 1571:	total: 32.2s	remaining: 8.77s
# 1572:	total: 32.2s	remaining: 8.75s
# 1573:	total: 32.3s	remaining: 8.73s
# 1574:	total: 32.3s	remaining: 8.71s
# 1575:	total: 32.3s	remaining: 8.69s
# 1576:	total: 32.3s	remaining: 8.67s
# 1577:	total: 32.3s	remaining: 8.65s
# 1578:	total: 32.4s	remaining: 8.63s
# 1579:	total: 32.4s	remaining: 8.61s
# 1580:	total: 32.4s	remaining: 8.59s
# 1581:	total: 32.4s	remaining: 8.56s
# 1582:	total: 32.4s	remaining: 8.54s
# 1583:	total: 32.5s	remaining: 8.52s
# 1584:	total: 32.5s	remaining: 8.5s
# 1585:	total: 32.5s	remaining: 8.48s
# 1586:	total: 32.5s	remaining: 8.46s
# 1587:	total: 32.5s	remaining: 8.44s
# 1588:	total: 32.6s	remaining: 8.42s
# 1589:	total: 32.6s	remaining: 8.4s
# 1590:	total: 32.6s	remaining: 8.38s
# 1591:	total: 32.6s	remaining: 8.36s
# 1592:	total: 32.6s	remaining: 8.34s
# 1593:	total: 32.7s	remaining: 8.32s
# 1594:	total: 32.7s	remaining: 8.3s
# 1595:	total: 32.7s	remaining: 8.28s
# 1596:	total: 32.7s	remaining: 8.26s
# 1597:	total: 32.7s	remaining: 8.23s
# 1598:	total: 32.8s	remaining: 8.21s
# 1599:	total: 32.8s	remaining: 8.19s
# 1600:	total: 32.8s	remaining: 8.17s
# 1601:	total: 32.8s	remaining: 8.15s
# 1602:	total: 32.8s	remaining: 8.13s
# 1603:	total: 32.9s	remaining: 8.11s
# 1604:	total: 32.9s	remaining: 8.09s
# 1605:	total: 32.9s	remaining: 8.07s
# 1606:	total: 32.9s	remaining: 8.05s
# 1607:	total: 32.9s	remaining: 8.03s
# 1608:	total: 33s	remaining: 8.01s
# 1609:	total: 33s	remaining: 7.99s
# 1610:	total: 33s	remaining: 7.96s
# 1611:	total: 33s	remaining: 7.95s
# 1612:	total: 33s	remaining: 7.92s
# 1613:	total: 33s	remaining: 7.9s
# 1614:	total: 33.1s	remaining: 7.88s
# 1615:	total: 33.1s	remaining: 7.86s
# 1616:	total: 33.1s	remaining: 7.84s
# 1617:	total: 33.1s	remaining: 7.82s
# 1618:	total: 33.1s	remaining: 7.8s
# 1619:	total: 33.2s	remaining: 7.78s
# 1620:	total: 33.2s	remaining: 7.76s
# 1621:	total: 33.2s	remaining: 7.74s
# 1622:	total: 33.2s	remaining: 7.72s
# 1623:	total: 33.2s	remaining: 7.7s
# 1624:	total: 33.3s	remaining: 7.67s
# 1625:	total: 33.3s	remaining: 7.65s
# 1626:	total: 33.3s	remaining: 7.63s
# 1627:	total: 33.3s	remaining: 7.61s
# 1628:	total: 33.3s	remaining: 7.59s
# 1629:	total: 33.3s	remaining: 7.57s
# 1630:	total: 33.4s	remaining: 7.55s
# 1631:	total: 33.4s	remaining: 7.53s
# 1632:	total: 33.4s	remaining: 7.51s
# 1633:	total: 33.4s	remaining: 7.49s
# 1634:	total: 33.4s	remaining: 7.46s
# 1635:	total: 33.5s	remaining: 7.45s
# 1636:	total: 33.5s	remaining: 7.42s
# 1637:	total: 33.5s	remaining: 7.4s
# 1638:	total: 33.5s	remaining: 7.38s
# 1639:	total: 33.5s	remaining: 7.36s
# 1640:	total: 33.6s	remaining: 7.34s
# 1641:	total: 33.6s	remaining: 7.32s
# 1642:	total: 33.6s	remaining: 7.3s
# 1643:	total: 33.6s	remaining: 7.28s
# 1644:	total: 33.6s	remaining: 7.26s
# 1645:	total: 33.7s	remaining: 7.24s
# 1646:	total: 33.7s	remaining: 7.22s
# 1647:	total: 33.7s	remaining: 7.2s
# 1648:	total: 33.7s	remaining: 7.18s
# 1649:	total: 33.8s	remaining: 7.16s
# 1650:	total: 33.8s	remaining: 7.14s
# 1651:	total: 33.8s	remaining: 7.12s
# 1652:	total: 33.8s	remaining: 7.1s
# 1653:	total: 33.8s	remaining: 7.08s
# 1654:	total: 33.9s	remaining: 7.06s
# 1655:	total: 33.9s	remaining: 7.04s
# 1656:	total: 33.9s	remaining: 7.01s
# 1657:	total: 33.9s	remaining: 6.99s
# 1658:	total: 33.9s	remaining: 6.97s
# 1659:	total: 33.9s	remaining: 6.95s
# 1660:	total: 34s	remaining: 6.93s
# 1661:	total: 34s	remaining: 6.91s
# 1662:	total: 34s	remaining: 6.89s
# 1663:	total: 34s	remaining: 6.87s
# 1664:	total: 34s	remaining: 6.85s
# 1665:	total: 34.1s	remaining: 6.83s
# 1666:	total: 34.1s	remaining: 6.81s
# 1667:	total: 34.1s	remaining: 6.79s
# 1668:	total: 34.1s	remaining: 6.76s
# 1669:	total: 34.1s	remaining: 6.75s
# 1670:	total: 34.2s	remaining: 6.72s
# 1671:	total: 34.2s	remaining: 6.7s
# 1672:	total: 34.2s	remaining: 6.68s
# 1673:	total: 34.2s	remaining: 6.66s
# 1674:	total: 34.2s	remaining: 6.64s
# 1675:	total: 34.2s	remaining: 6.62s
# 1676:	total: 34.3s	remaining: 6.6s
# 1677:	total: 34.3s	remaining: 6.58s
# 1678:	total: 34.3s	remaining: 6.56s
# 1679:	total: 34.3s	remaining: 6.54s
# 1680:	total: 34.3s	remaining: 6.52s
# 1681:	total: 34.4s	remaining: 6.5s
# 1682:	total: 34.4s	remaining: 6.47s
# 1683:	total: 34.4s	remaining: 6.45s
# 1684:	total: 34.4s	remaining: 6.43s
# 1685:	total: 34.4s	remaining: 6.41s
# 1686:	total: 34.4s	remaining: 6.39s
# 1687:	total: 34.5s	remaining: 6.37s
# 1688:	total: 34.5s	remaining: 6.35s
# 1689:	total: 34.5s	remaining: 6.33s
# 1690:	total: 34.5s	remaining: 6.31s
# 1691:	total: 34.5s	remaining: 6.29s
# 1692:	total: 34.6s	remaining: 6.27s
# 1693:	total: 34.6s	remaining: 6.25s
# 1694:	total: 34.6s	remaining: 6.23s
# 1695:	total: 34.6s	remaining: 6.21s
# 1696:	total: 34.6s	remaining: 6.18s
# 1697:	total: 34.7s	remaining: 6.17s
# 1698:	total: 34.7s	remaining: 6.14s
# 1699:	total: 34.7s	remaining: 6.12s
# 1700:	total: 34.7s	remaining: 6.1s
# 1701:	total: 34.7s	remaining: 6.08s
# 1702:	total: 34.8s	remaining: 6.06s
# 1703:	total: 34.8s	remaining: 6.04s
# 1704:	total: 34.8s	remaining: 6.02s
# 1705:	total: 34.8s	remaining: 6s
# 1706:	total: 34.8s	remaining: 5.98s
# 1707:	total: 34.9s	remaining: 5.96s
# 1708:	total: 34.9s	remaining: 5.94s
# 1709:	total: 34.9s	remaining: 5.92s
# 1710:	total: 34.9s	remaining: 5.9s
# 1711:	total: 34.9s	remaining: 5.88s
# 1712:	total: 35s	remaining: 5.86s
# 1713:	total: 35s	remaining: 5.83s
# 1714:	total: 35s	remaining: 5.81s
# 1715:	total: 35s	remaining: 5.79s
# 1716:	total: 35s	remaining: 5.77s
# 1717:	total: 35s	remaining: 5.75s
# 1718:	total: 35.1s	remaining: 5.73s
# 1719:	total: 35.1s	remaining: 5.71s
# 1720:	total: 35.1s	remaining: 5.69s
# 1721:	total: 35.1s	remaining: 5.67s
# 1722:	total: 35.1s	remaining: 5.65s
# 1723:	total: 35.2s	remaining: 5.63s
# 1724:	total: 35.2s	remaining: 5.61s
# 1725:	total: 35.2s	remaining: 5.59s
# 1726:	total: 35.2s	remaining: 5.57s
# 1727:	total: 35.2s	remaining: 5.54s
# 1728:	total: 35.3s	remaining: 5.53s
# 1729:	total: 35.3s	remaining: 5.5s
# 1730:	total: 35.3s	remaining: 5.48s
# 1731:	total: 35.3s	remaining: 5.46s
# 1732:	total: 35.3s	remaining: 5.44s
# 1733:	total: 35.3s	remaining: 5.42s
# 1734:	total: 35.4s	remaining: 5.4s
# 1735:	total: 35.4s	remaining: 5.38s
# 1736:	total: 35.4s	remaining: 5.36s
# 1737:	total: 35.4s	remaining: 5.34s
# 1738:	total: 35.4s	remaining: 5.32s
# 1739:	total: 35.4s	remaining: 5.3s
# 1740:	total: 35.5s	remaining: 5.28s
# 1741:	total: 35.5s	remaining: 5.26s
# 1742:	total: 35.5s	remaining: 5.24s
# 1743:	total: 35.5s	remaining: 5.21s
# 1744:	total: 35.5s	remaining: 5.19s
# 1745:	total: 35.6s	remaining: 5.17s
# 1746:	total: 35.6s	remaining: 5.15s
# 1747:	total: 35.6s	remaining: 5.13s
# 1748:	total: 35.6s	remaining: 5.11s
# 1749:	total: 35.6s	remaining: 5.09s
# 1750:	total: 35.7s	remaining: 5.07s
# 1751:	total: 35.7s	remaining: 5.05s
# 1752:	total: 35.7s	remaining: 5.03s
# 1753:	total: 35.7s	remaining: 5.01s
# 1754:	total: 35.7s	remaining: 4.99s
# 1755:	total: 35.7s	remaining: 4.97s
# 1756:	total: 35.8s	remaining: 4.95s
# 1757:	total: 35.8s	remaining: 4.93s
# 1758:	total: 35.8s	remaining: 4.91s
# 1759:	total: 35.8s	remaining: 4.88s
# 1760:	total: 35.8s	remaining: 4.86s
# 1761:	total: 35.9s	remaining: 4.84s
# 1762:	total: 35.9s	remaining: 4.82s
# 1763:	total: 35.9s	remaining: 4.8s
# 1764:	total: 35.9s	remaining: 4.78s
# 1765:	total: 35.9s	remaining: 4.76s
# 1766:	total: 36s	remaining: 4.74s
# 1767:	total: 36s	remaining: 4.72s
# 1768:	total: 36s	remaining: 4.7s
# 1769:	total: 36s	remaining: 4.68s
# 1770:	total: 36s	remaining: 4.66s
# 1771:	total: 36.1s	remaining: 4.64s
# 1772:	total: 36.1s	remaining: 4.62s
# 1773:	total: 36.1s	remaining: 4.6s
# 1774:	total: 36.1s	remaining: 4.58s
# 1775:	total: 36.1s	remaining: 4.56s
# 1776:	total: 36.1s	remaining: 4.54s
# 1777:	total: 36.2s	remaining: 4.52s
# 1778:	total: 36.2s	remaining: 4.5s
# 1779:	total: 36.2s	remaining: 4.47s
# 1780:	total: 36.2s	remaining: 4.45s
# 1781:	total: 36.2s	remaining: 4.43s
# 1782:	total: 36.3s	remaining: 4.41s
# 1783:	total: 36.3s	remaining: 4.39s
# 1784:	total: 36.3s	remaining: 4.37s
# 1785:	total: 36.3s	remaining: 4.35s
# 1786:	total: 36.3s	remaining: 4.33s
# 1787:	total: 36.4s	remaining: 4.31s
# 1788:	total: 36.4s	remaining: 4.29s
# 1789:	total: 36.4s	remaining: 4.27s
# 1790:	total: 36.4s	remaining: 4.25s
# 1791:	total: 36.4s	remaining: 4.23s
# 1792:	total: 36.4s	remaining: 4.21s
# 1793:	total: 36.5s	remaining: 4.19s
# 1794:	total: 36.5s	remaining: 4.17s
# 1795:	total: 36.5s	remaining: 4.14s
# 1796:	total: 36.5s	remaining: 4.13s
# 1797:	total: 36.5s	remaining: 4.11s
# 1798:	total: 36.6s	remaining: 4.08s
# 1799:	total: 36.6s	remaining: 4.06s
# 1800:	total: 36.6s	remaining: 4.04s
# 1801:	total: 36.6s	remaining: 4.02s
# 1802:	total: 36.6s	remaining: 4s
# 1803:	total: 36.7s	remaining: 3.98s
# 1804:	total: 36.7s	remaining: 3.96s
# 1805:	total: 36.7s	remaining: 3.94s
# 1806:	total: 36.7s	remaining: 3.92s
# 1807:	total: 36.7s	remaining: 3.9s
# 1808:	total: 36.8s	remaining: 3.88s
# 1809:	total: 36.8s	remaining: 3.86s
# 1810:	total: 36.8s	remaining: 3.84s
# 1811:	total: 36.8s	remaining: 3.82s
# 1812:	total: 36.8s	remaining: 3.8s
# 1813:	total: 36.9s	remaining: 3.78s
# 1814:	total: 36.9s	remaining: 3.76s
# 1815:	total: 36.9s	remaining: 3.74s
# 1816:	total: 36.9s	remaining: 3.72s
# 1817:	total: 36.9s	remaining: 3.7s
# 1818:	total: 37s	remaining: 3.68s
# 1819:	total: 37s	remaining: 3.66s
# 1820:	total: 37s	remaining: 3.64s
# 1821:	total: 37s	remaining: 3.62s
# 1822:	total: 37s	remaining: 3.6s
# 1823:	total: 37.1s	remaining: 3.58s
# 1824:	total: 37.1s	remaining: 3.56s
# 1825:	total: 37.1s	remaining: 3.53s
# 1826:	total: 37.1s	remaining: 3.51s
# 1827:	total: 37.1s	remaining: 3.49s
# 1828:	total: 37.2s	remaining: 3.47s
# 1829:	total: 37.2s	remaining: 3.45s
# 1830:	total: 37.2s	remaining: 3.43s
# 1831:	total: 37.2s	remaining: 3.41s
# 1832:	total: 37.2s	remaining: 3.39s
# 1833:	total: 37.3s	remaining: 3.37s
# 1834:	total: 37.3s	remaining: 3.35s
# 1835:	total: 37.3s	remaining: 3.33s
# 1836:	total: 37.3s	remaining: 3.31s
# 1837:	total: 37.3s	remaining: 3.29s
# 1838:	total: 37.3s	remaining: 3.27s
# 1839:	total: 37.4s	remaining: 3.25s
# 1840:	total: 37.4s	remaining: 3.23s
# 1841:	total: 37.4s	remaining: 3.21s
# 1842:	total: 37.4s	remaining: 3.19s
# 1843:	total: 37.4s	remaining: 3.17s
# 1844:	total: 37.5s	remaining: 3.15s
# 1845:	total: 37.5s	remaining: 3.13s
# 1846:	total: 37.5s	remaining: 3.11s
# 1847:	total: 37.5s	remaining: 3.09s
# 1848:	total: 37.5s	remaining: 3.07s
# 1849:	total: 37.6s	remaining: 3.05s
# 1850:	total: 37.6s	remaining: 3.02s
# 1851:	total: 37.6s	remaining: 3s
# 1852:	total: 37.6s	remaining: 2.98s
# 1853:	total: 37.6s	remaining: 2.96s
# 1854:	total: 37.7s	remaining: 2.94s
# 1855:	total: 37.7s	remaining: 2.92s
# 1856:	total: 37.7s	remaining: 2.9s
# 1857:	total: 37.7s	remaining: 2.88s
# 1858:	total: 37.7s	remaining: 2.86s
# 1859:	total: 37.8s	remaining: 2.84s
# 1860:	total: 37.8s	remaining: 2.82s
# 1861:	total: 37.8s	remaining: 2.8s
# 1862:	total: 37.8s	remaining: 2.78s
# 1863:	total: 37.8s	remaining: 2.76s
# 1864:	total: 37.9s	remaining: 2.74s
# 1865:	total: 37.9s	remaining: 2.72s
# 1866:	total: 37.9s	remaining: 2.7s
# 1867:	total: 37.9s	remaining: 2.68s
# 1868:	total: 37.9s	remaining: 2.66s
# 1869:	total: 38s	remaining: 2.64s
# 1870:	total: 38s	remaining: 2.62s
# 1871:	total: 38s	remaining: 2.6s
# 1872:	total: 38s	remaining: 2.58s
# 1873:	total: 38s	remaining: 2.56s
# 1874:	total: 38s	remaining: 2.54s
# 1875:	total: 38.1s	remaining: 2.52s
# 1876:	total: 38.1s	remaining: 2.5s
# 1877:	total: 38.1s	remaining: 2.48s
# 1878:	total: 38.1s	remaining: 2.46s
# 1879:	total: 38.1s	remaining: 2.43s
# 1880:	total: 38.2s	remaining: 2.41s
# 1881:	total: 38.2s	remaining: 2.39s
# 1882:	total: 38.2s	remaining: 2.37s
# 1883:	total: 38.2s	remaining: 2.35s
# 1884:	total: 38.2s	remaining: 2.33s
# 1885:	total: 38.3s	remaining: 2.31s
# 1886:	total: 38.3s	remaining: 2.29s
# 1887:	total: 38.3s	remaining: 2.27s
# 1888:	total: 38.3s	remaining: 2.25s
# 1889:	total: 38.3s	remaining: 2.23s
# 1890:	total: 38.3s	remaining: 2.21s
# 1891:	total: 38.4s	remaining: 2.19s
# 1892:	total: 38.4s	remaining: 2.17s
# 1893:	total: 38.4s	remaining: 2.15s
# 1894:	total: 38.4s	remaining: 2.13s
# 1895:	total: 38.4s	remaining: 2.11s
# 1896:	total: 38.5s	remaining: 2.09s
# 1897:	total: 38.5s	remaining: 2.07s
# 1898:	total: 38.5s	remaining: 2.05s
# 1899:	total: 38.5s	remaining: 2.03s
# 1900:	total: 38.5s	remaining: 2.01s
# 1901:	total: 38.6s	remaining: 1.99s
# 1902:	total: 38.6s	remaining: 1.97s
# 1903:	total: 38.6s	remaining: 1.95s
# 1904:	total: 38.6s	remaining: 1.93s
# 1905:	total: 38.6s	remaining: 1.91s
# 1906:	total: 38.6s	remaining: 1.88s
# 1907:	total: 38.7s	remaining: 1.86s
# 1908:	total: 38.7s	remaining: 1.84s
# 1909:	total: 38.7s	remaining: 1.82s
# 1910:	total: 38.7s	remaining: 1.8s
# 1911:	total: 38.7s	remaining: 1.78s
# 1912:	total: 38.8s	remaining: 1.76s
# 1913:	total: 38.8s	remaining: 1.74s
# 1914:	total: 38.8s	remaining: 1.72s
# 1915:	total: 38.8s	remaining: 1.7s
# 1916:	total: 38.8s	remaining: 1.68s
# 1917:	total: 38.9s	remaining: 1.66s
# 1918:	total: 38.9s	remaining: 1.64s
# 1919:	total: 38.9s	remaining: 1.62s
# 1920:	total: 38.9s	remaining: 1.6s
# 1921:	total: 38.9s	remaining: 1.58s
# 1922:	total: 39s	remaining: 1.56s
# 1923:	total: 39s	remaining: 1.54s
# 1924:	total: 39s	remaining: 1.52s
# 1925:	total: 39s	remaining: 1.5s
# 1926:	total: 39s	remaining: 1.48s
# 1927:	total: 39.1s	remaining: 1.46s
# 1928:	total: 39.1s	remaining: 1.44s
# 1929:	total: 39.1s	remaining: 1.42s
# 1930:	total: 39.1s	remaining: 1.4s
# 1931:	total: 39.1s	remaining: 1.38s
# 1932:	total: 39.1s	remaining: 1.36s
# 1933:	total: 39.2s	remaining: 1.34s
# 1934:	total: 39.2s	remaining: 1.32s
# 1935:	total: 39.2s	remaining: 1.29s
# 1936:	total: 39.2s	remaining: 1.27s
# 1937:	total: 39.2s	remaining: 1.25s
# 1938:	total: 39.3s	remaining: 1.23s
# 1939:	total: 39.3s	remaining: 1.21s
# 1940:	total: 39.3s	remaining: 1.19s
# 1941:	total: 39.3s	remaining: 1.17s
# 1942:	total: 39.3s	remaining: 1.15s
# 1943:	total: 39.4s	remaining: 1.13s
# 1944:	total: 39.4s	remaining: 1.11s
# 1945:	total: 39.4s	remaining: 1.09s
# 1946:	total: 39.4s	remaining: 1.07s
# 1947:	total: 39.4s	remaining: 1.05s
# 1948:	total: 39.5s	remaining: 1.03s
# 1949:	total: 39.5s	remaining: 1.01s
# 1950:	total: 39.5s	remaining: 992ms
# 1951:	total: 39.5s	remaining: 972ms
# 1952:	total: 39.5s	remaining: 951ms
# 1953:	total: 39.6s	remaining: 931ms
# 1954:	total: 39.6s	remaining: 911ms
# 1955:	total: 39.6s	remaining: 891ms
# 1956:	total: 39.6s	remaining: 871ms
# 1957:	total: 39.6s	remaining: 850ms
# 1958:	total: 39.7s	remaining: 830ms
# 1959:	total: 39.7s	remaining: 810ms
# 1960:	total: 39.7s	remaining: 790ms
# 1961:	total: 39.7s	remaining: 769ms
# 1962:	total: 39.7s	remaining: 749ms
# 1963:	total: 39.8s	remaining: 729ms
# 1964:	total: 39.8s	remaining: 709ms
# 1965:	total: 39.8s	remaining: 688ms
# 1966:	total: 39.8s	remaining: 668ms
# 1967:	total: 39.8s	remaining: 648ms
# 1968:	total: 39.9s	remaining: 628ms
# 1969:	total: 39.9s	remaining: 607ms
# 1970:	total: 39.9s	remaining: 587ms
# 1971:	total: 39.9s	remaining: 567ms
# 1972:	total: 39.9s	remaining: 547ms
# 1973:	total: 40s	remaining: 526ms
# 1974:	total: 40s	remaining: 506ms
# 1975:	total: 40s	remaining: 486ms
# 1976:	total: 40s	remaining: 466ms
# 1977:	total: 40s	remaining: 445ms
# 1978:	total: 40.1s	remaining: 425ms
# 1979:	total: 40.1s	remaining: 405ms
# 1980:	total: 40.1s	remaining: 385ms
# 1981:	total: 40.1s	remaining: 364ms
# 1982:	total: 40.1s	remaining: 344ms
# 1983:	total: 40.2s	remaining: 324ms
# 1984:	total: 40.2s	remaining: 304ms
# 1985:	total: 40.2s	remaining: 283ms
# 1986:	total: 40.2s	remaining: 263ms
# 1987:	total: 40.2s	remaining: 243ms
# 1988:	total: 40.3s	remaining: 223ms
# 1989:	total: 40.3s	remaining: 202ms
# 1990:	total: 40.3s	remaining: 182ms
# 1991:	total: 40.3s	remaining: 162ms
# 1992:	total: 40.3s	remaining: 142ms
# 1993:	total: 40.4s	remaining: 121ms
# 1994:	total: 40.4s	remaining: 101ms
# 1995:	total: 40.4s	remaining: 81ms
# 1996:	total: 40.4s	remaining: 60.7ms
# 1997:	total: 40.5s	remaining: 40.5ms
# 1998:	total: 40.5s	remaining: 20.2ms
# 1999:	total: 40.5s	remaining: 0us

# %%
print("Time Taken to train: {}".format(end_time - start_time))
# Out:
# Time Taken to train: 41.32528042793274

# %%
#Model Testing:

y_pred_cat = cat_classifier.predict(X_test)

# %%
print("Accuracy Score: {}".format(accuracy_score(y_test,y_pred_cat)))
# Out:
# Accuracy Score: 0.8644300838718548

# %%
#Checking for Overfitting and Under Fitting:
print("Train Data Score: {}".format(cat_classifier.score(X_train, y_train)))
print("Test Data Score: {}".format(cat_classifier.score(X_test, y_test)))
# Out:
# Train Data Score: 0.891963426371511
# Test Data Score: 0.8644300838718548

# %%
Accuracy Score of Training and Testing Data is comparable and almost equal. So, there is no question of Underfitting and Over Fitting. And model is generalizing well for new unseen data.

# %%
#Confusion Matrix:
print("Confusion Matrix:")
print("\n",confusion_matrix(y_test,y_pred_cat))
# Out:
# Confusion Matrix:
#
#  [[21633  1093]
#  [ 2851  3515]]

# %%
#classification Report:
print("classification_report:")
print("\n",classification_report(y_test,y_pred_cat))
# Out:
# classification_report:
#
#                precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92     22726
#            1       0.76      0.55      0.64      6366
#
#     accuracy                           0.86     29092
#    macro avg       0.82      0.75      0.78     29092
# weighted avg       0.86      0.86      0.86     29092

# %%
#predicting the probabilities:
y_pred_cat_proba = cat_classifier.predict_proba(X_test)

# %%
#Finding True Positive Rate(tpr), False Positive Rate(fpr), threshold values to plot ROC curve  
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_cat_proba[:,1])

# %%
#plotting ROC Curve:
plt.figure(figsize=(6,4))
plt.plot(fpr,tpr,'-g',linewidth=1)
plt.plot([0,1], [0,1], 'k--' )
plt.title('ROC curve for Cat Boost Model')
plt.xlabel("False Positive Rate")
plt.ylabel('True Positive Rate')
plt.show()

# %%
#finding ROC AUC Scores:
from sklearn.metrics import roc_auc_score
print('ROC AUC Scores: {}'.format(roc_auc_score(y_test, y_pred_cat)))
# Out:
# ROC AUC Scores: 0.7520286822521376

# %%
#Finding whether model performance can be improved using Cross Validation Score:
from sklearn.model_selection import cross_val_score
scores = cross_val_score(cat_classifier, X_train, y_train, cv = 5, scoring='accuracy')
print('Cross-validation scores:{}'.format(scores))
# Out:
# Learning rate set to 0.037811
# 0:	total: 12.1ms	remaining: 24.1s
# 1:	total: 23.3ms	remaining: 23.3s
# 2:	total: 34.7ms	remaining: 23.1s
# 3:	total: 46.4ms	remaining: 23.1s
# 4:	total: 58.4ms	remaining: 23.3s
# 5:	total: 70.6ms	remaining: 23.5s
# 6:	total: 84.7ms	remaining: 24.1s
# 7:	total: 97ms	remaining: 24.2s
# 8:	total: 110ms	remaining: 24.4s
# 9:	total: 127ms	remaining: 25.3s
# 10:	total: 142ms	remaining: 25.6s
# 11:	total: 158ms	remaining: 26.1s
# 12:	total: 174ms	remaining: 26.6s
# 13:	total: 194ms	remaining: 27.6s
# 14:	total: 212ms	remaining: 28s
# 15:	total: 226ms	remaining: 28s
# 16:	total: 239ms	remaining: 27.9s
# 17:	total: 254ms	remaining: 28s
# 18:	total: 268ms	remaining: 28s
# 19:	total: 282ms	remaining: 27.9s
# 20:	total: 296ms	remaining: 27.9s
# 21:	total: 309ms	remaining: 27.8s
# 22:	total: 322ms	remaining: 27.7s
# 23:	total: 336ms	remaining: 27.6s
# 24:	total: 349ms	remaining: 27.6s
# 25:	total: 362ms	remaining: 27.5s
# 26:	total: 378ms	remaining: 27.6s
# 27:	total: 395ms	remaining: 27.8s
# 28:	total: 411ms	remaining: 28s
# 29:	total: 428ms	remaining: 28.1s
# 30:	total: 445ms	remaining: 28.2s
# 31:	total: 462ms	remaining: 28.4s
# 32:	total: 480ms	remaining: 28.6s
# 33:	total: 496ms	remaining: 28.7s
# 34:	total: 512ms	remaining: 28.7s
# 35:	total: 528ms	remaining: 28.8s
# 36:	total: 542ms	remaining: 28.8s
# 37:	total: 556ms	remaining: 28.7s
# 38:	total: 572ms	remaining: 28.7s
# 39:	total: 587ms	remaining: 28.7s
# 40:	total: 599ms	remaining: 28.6s
# 41:	total: 612ms	remaining: 28.5s
# 42:	total: 623ms	remaining: 28.4s
# 43:	total: 635ms	remaining: 28.2s
# 44:	total: 646ms	remaining: 28s
# 45:	total: 657ms	remaining: 27.9s
# 46:	total: 668ms	remaining: 27.8s
# 47:	total: 679ms	remaining: 27.6s
# 48:	total: 691ms	remaining: 27.5s
# 49:	total: 703ms	remaining: 27.4s
# 50:	total: 715ms	remaining: 27.3s
# 51:	total: 727ms	remaining: 27.2s
# 52:	total: 739ms	remaining: 27.1s
# 53:	total: 751ms	remaining: 27.1s
# 54:	total: 762ms	remaining: 26.9s
# 55:	total: 774ms	remaining: 26.9s
# 56:	total: 787ms	remaining: 26.8s
# 57:	total: 800ms	remaining: 26.8s
# 58:	total: 811ms	remaining: 26.7s
# 59:	total: 824ms	remaining: 26.6s
# 60:	total: 838ms	remaining: 26.6s
# 61:	total: 853ms	remaining: 26.7s
# 62:	total: 866ms	remaining: 26.6s
# 63:	total: 879ms	remaining: 26.6s
# 64:	total: 893ms	remaining: 26.6s
# 65:	total: 907ms	remaining: 26.6s
# 66:	total: 922ms	remaining: 26.6s
# 67:	total: 938ms	remaining: 26.6s
# 68:	total: 953ms	remaining: 26.7s
# 69:	total: 969ms	remaining: 26.7s
# 70:	total: 987ms	remaining: 26.8s
# 71:	total: 1s	remaining: 26.9s
# 72:	total: 1.02s	remaining: 26.8s
# 73:	total: 1.03s	remaining: 26.8s
# 74:	total: 1.04s	remaining: 26.7s
# 75:	total: 1.05s	remaining: 26.7s
# 76:	total: 1.07s	remaining: 26.6s
# 77:	total: 1.08s	remaining: 26.6s
# 78:	total: 1.09s	remaining: 26.5s
# 79:	total: 1.1s	remaining: 26.4s
# 80:	total: 1.11s	remaining: 26.3s
# 81:	total: 1.12s	remaining: 26.3s
# 82:	total: 1.14s	remaining: 26.2s
# 83:	total: 1.15s	remaining: 26.3s
# 84:	total: 1.17s	remaining: 26.3s
# 85:	total: 1.18s	remaining: 26.3s
# 86:	total: 1.2s	remaining: 26.3s
# 87:	total: 1.21s	remaining: 26.3s
# 88:	total: 1.23s	remaining: 26.3s
# 89:	total: 1.24s	remaining: 26.2s
# 90:	total: 1.25s	remaining: 26.2s
# 91:	total: 1.26s	remaining: 26.2s
# 92:	total: 1.28s	remaining: 26.2s
# 93:	total: 1.29s	remaining: 26.1s
# 94:	total: 1.3s	remaining: 26.1s
# 95:	total: 1.31s	remaining: 26s
# 96:	total: 1.32s	remaining: 26s
# 97:	total: 1.33s	remaining: 25.9s
# 98:	total: 1.35s	remaining: 25.9s
# 99:	total: 1.36s	remaining: 25.8s
# 100:	total: 1.37s	remaining: 25.8s
# 101:	total: 1.38s	remaining: 25.7s
# 102:	total: 1.4s	remaining: 25.7s
# 103:	total: 1.41s	remaining: 25.7s
# 104:	total: 1.42s	remaining: 25.7s
# 105:	total: 1.44s	remaining: 25.7s
# 106:	total: 1.45s	remaining: 25.6s
# 107:	total: 1.46s	remaining: 25.6s
# 108:	total: 1.48s	remaining: 25.6s
# 109:	total: 1.49s	remaining: 25.6s
# 110:	total: 1.5s	remaining: 25.6s
# 111:	total: 1.51s	remaining: 25.5s
# 112:	total: 1.53s	remaining: 25.5s
# 113:	total: 1.54s	remaining: 25.5s
# 114:	total: 1.55s	remaining: 25.5s
# 115:	total: 1.57s	remaining: 25.5s
# 116:	total: 1.58s	remaining: 25.5s
# 117:	total: 1.6s	remaining: 25.5s
# 118:	total: 1.61s	remaining: 25.5s
# 119:	total: 1.63s	remaining: 25.5s
# 120:	total: 1.64s	remaining: 25.5s
# 121:	total: 1.65s	remaining: 25.4s
# 122:	total: 1.66s	remaining: 25.4s
# 123:	total: 1.67s	remaining: 25.3s
# 124:	total: 1.69s	remaining: 25.3s
# 125:	total: 1.7s	remaining: 25.3s
# 126:	total: 1.71s	remaining: 25.3s
# 127:	total: 1.73s	remaining: 25.3s
# 128:	total: 1.74s	remaining: 25.3s
# 129:	total: 1.75s	remaining: 25.2s
# 130:	total: 1.77s	remaining: 25.2s
# 131:	total: 1.79s	remaining: 25.3s
# 132:	total: 1.8s	remaining: 25.3s
# 133:	total: 1.82s	remaining: 25.3s
# 134:	total: 1.83s	remaining: 25.3s
# 135:	total: 1.85s	remaining: 25.3s
# 136:	total: 1.86s	remaining: 25.3s
# 137:	total: 1.87s	remaining: 25.3s
# 138:	total: 1.89s	remaining: 25.2s
# 139:	total: 1.9s	remaining: 25.2s
# 140:	total: 1.91s	remaining: 25.2s
# 141:	total: 1.92s	remaining: 25.1s
# 142:	total: 1.93s	remaining: 25.1s
# 143:	total: 1.95s	remaining: 25.1s
# 144:	total: 1.96s	remaining: 25.1s
# 145:	total: 1.97s	remaining: 25s
# 146:	total: 1.99s	remaining: 25s
# 147:	total: 2s	remaining: 25s
# 148:	total: 2.01s	remaining: 25s
# 149:	total: 2.02s	remaining: 25s
# 150:	total: 2.04s	remaining: 24.9s
# 151:	total: 2.05s	remaining: 24.9s
# 152:	total: 2.06s	remaining: 24.9s
# 153:	total: 2.07s	remaining: 24.9s
# 154:	total: 2.08s	remaining: 24.8s
# 155:	total: 2.1s	remaining: 24.8s
# 156:	total: 2.11s	remaining: 24.8s
# 157:	total: 2.12s	remaining: 24.8s
# 158:	total: 2.13s	remaining: 24.7s
# 159:	total: 2.15s	remaining: 24.7s
# 160:	total: 2.16s	remaining: 24.7s
# 161:	total: 2.17s	remaining: 24.6s
# 162:	total: 2.19s	remaining: 24.6s
# 163:	total: 2.2s	remaining: 24.6s
# 164:	total: 2.21s	remaining: 24.6s
# 165:	total: 2.22s	remaining: 24.6s
# 166:	total: 2.24s	remaining: 24.6s
# 167:	total: 2.25s	remaining: 24.5s
# 168:	total: 2.26s	remaining: 24.5s
# 169:	total: 2.27s	remaining: 24.5s
# 170:	total: 2.28s	remaining: 24.4s
# 171:	total: 2.29s	remaining: 24.4s
# 172:	total: 2.31s	remaining: 24.4s
# 173:	total: 2.32s	remaining: 24.3s
# 174:	total: 2.33s	remaining: 24.3s
# 175:	total: 2.34s	remaining: 24.3s
# 176:	total: 2.35s	remaining: 24.2s
# 177:	total: 2.36s	remaining: 24.2s
# 178:	total: 2.38s	remaining: 24.2s
# 179:	total: 2.39s	remaining: 24.2s
# 180:	total: 2.4s	remaining: 24.2s
# 181:	total: 2.42s	remaining: 24.1s
# 182:	total: 2.43s	remaining: 24.1s
# 183:	total: 2.44s	remaining: 24.1s
# 184:	total: 2.45s	remaining: 24.1s
# 185:	total: 2.47s	remaining: 24.1s
# 186:	total: 2.48s	remaining: 24s
# 187:	total: 2.49s	remaining: 24s
# 188:	total: 2.5s	remaining: 24s
# 189:	total: 2.52s	remaining: 24s
# 190:	total: 2.53s	remaining: 24s
# 191:	total: 2.54s	remaining: 23.9s
# 192:	total: 2.55s	remaining: 23.9s
# 193:	total: 2.57s	remaining: 23.9s
# 194:	total: 2.58s	remaining: 23.9s
# 195:	total: 2.59s	remaining: 23.9s
# 196:	total: 2.6s	remaining: 23.8s
# 197:	total: 2.62s	remaining: 23.8s
# 198:	total: 2.63s	remaining: 23.8s
# 199:	total: 2.64s	remaining: 23.8s
# 200:	total: 2.65s	remaining: 23.7s
# 201:	total: 2.66s	remaining: 23.7s
# 202:	total: 2.67s	remaining: 23.7s
# 203:	total: 2.69s	remaining: 23.6s
# 204:	total: 2.7s	remaining: 23.6s
# 205:	total: 2.71s	remaining: 23.6s
# 206:	total: 2.72s	remaining: 23.6s
# 207:	total: 2.73s	remaining: 23.6s
# 208:	total: 2.75s	remaining: 23.5s
# 209:	total: 2.76s	remaining: 23.5s
# 210:	total: 2.77s	remaining: 23.5s
# 211:	total: 2.78s	remaining: 23.5s
# 212:	total: 2.8s	remaining: 23.5s
# 213:	total: 2.81s	remaining: 23.5s
# 214:	total: 2.82s	remaining: 23.4s
# 215:	total: 2.84s	remaining: 23.4s
# 216:	total: 2.85s	remaining: 23.4s
# 217:	total: 2.86s	remaining: 23.4s
# 218:	total: 2.87s	remaining: 23.4s
# 219:	total: 2.88s	remaining: 23.3s
# 220:	total: 2.9s	remaining: 23.3s
# 221:	total: 2.91s	remaining: 23.3s
# 222:	total: 2.92s	remaining: 23.3s
# 223:	total: 2.93s	remaining: 23.3s
# 224:	total: 2.94s	remaining: 23.2s
# 225:	total: 2.96s	remaining: 23.2s
# 226:	total: 2.97s	remaining: 23.2s
# 227:	total: 2.98s	remaining: 23.2s
# 228:	total: 3s	remaining: 23.2s
# 229:	total: 3.01s	remaining: 23.1s
# 230:	total: 3.02s	remaining: 23.1s
# 231:	total: 3.03s	remaining: 23.1s
# 232:	total: 3.04s	remaining: 23.1s
# 233:	total: 3.05s	remaining: 23s
# 234:	total: 3.06s	remaining: 23s
# 235:	total: 3.08s	remaining: 23s
# 236:	total: 3.09s	remaining: 23s
# 237:	total: 3.1s	remaining: 22.9s
# 238:	total: 3.11s	remaining: 22.9s
# 239:	total: 3.12s	remaining: 22.9s
# 240:	total: 3.13s	remaining: 22.9s
# 241:	total: 3.14s	remaining: 22.8s
# 242:	total: 3.15s	remaining: 22.8s
# 243:	total: 3.17s	remaining: 22.8s
# 244:	total: 3.18s	remaining: 22.8s
# 245:	total: 3.19s	remaining: 22.8s
# 246:	total: 3.21s	remaining: 22.8s
# 247:	total: 3.22s	remaining: 22.7s
# 248:	total: 3.23s	remaining: 22.7s
# 249:	total: 3.24s	remaining: 22.7s
# 250:	total: 3.25s	remaining: 22.7s
# 251:	total: 3.27s	remaining: 22.7s
# 252:	total: 3.28s	remaining: 22.6s
# 253:	total: 3.29s	remaining: 22.6s
# 254:	total: 3.3s	remaining: 22.6s
# 255:	total: 3.31s	remaining: 22.6s
# 256:	total: 3.33s	remaining: 22.6s
# 257:	total: 3.34s	remaining: 22.6s
# 258:	total: 3.35s	remaining: 22.5s
# 259:	total: 3.36s	remaining: 22.5s
# 260:	total: 3.38s	remaining: 22.5s
# 261:	total: 3.39s	remaining: 22.5s
# 262:	total: 3.4s	remaining: 22.5s
# 263:	total: 3.41s	remaining: 22.4s
# 264:	total: 3.42s	remaining: 22.4s
# 265:	total: 3.44s	remaining: 22.4s
# 266:	total: 3.45s	remaining: 22.4s
# 267:	total: 3.46s	remaining: 22.4s
# 268:	total: 3.47s	remaining: 22.3s
# 269:	total: 3.48s	remaining: 22.3s
# 270:	total: 3.49s	remaining: 22.3s
# 271:	total: 3.5s	remaining: 22.2s
# 272:	total: 3.51s	remaining: 22.2s
# 273:	total: 3.52s	remaining: 22.2s
# 274:	total: 3.54s	remaining: 22.2s
# 275:	total: 3.54s	remaining: 22.1s
# 276:	total: 3.56s	remaining: 22.1s
# 277:	total: 3.57s	remaining: 22.1s
# 278:	total: 3.58s	remaining: 22.1s
# 279:	total: 3.59s	remaining: 22.1s
# 280:	total: 3.6s	remaining: 22s
# 281:	total: 3.61s	remaining: 22s
# 282:	total: 3.62s	remaining: 22s
# 283:	total: 3.64s	remaining: 22s
# 284:	total: 3.65s	remaining: 22s
# 285:	total: 3.66s	remaining: 21.9s
# 286:	total: 3.67s	remaining: 21.9s
# 287:	total: 3.68s	remaining: 21.9s
# 288:	total: 3.69s	remaining: 21.9s
# 289:	total: 3.71s	remaining: 21.9s
# 290:	total: 3.72s	remaining: 21.8s
# 291:	total: 3.73s	remaining: 21.8s
# 292:	total: 3.74s	remaining: 21.8s
# 293:	total: 3.75s	remaining: 21.8s
# 294:	total: 3.77s	remaining: 21.8s
# 295:	total: 3.78s	remaining: 21.8s
# 296:	total: 3.79s	remaining: 21.7s
# 297:	total: 3.8s	remaining: 21.7s
# 298:	total: 3.83s	remaining: 21.8s
# 299:	total: 3.85s	remaining: 21.8s
# 300:	total: 3.86s	remaining: 21.8s
# 301:	total: 3.87s	remaining: 21.8s
# 302:	total: 3.89s	remaining: 21.8s
# 303:	total: 3.9s	remaining: 21.8s
# 304:	total: 3.91s	remaining: 21.7s
# 305:	total: 3.92s	remaining: 21.7s
# 306:	total: 3.93s	remaining: 21.7s
# 307:	total: 3.94s	remaining: 21.7s
# 308:	total: 3.96s	remaining: 21.7s
# 309:	total: 3.97s	remaining: 21.7s
# 310:	total: 3.99s	remaining: 21.7s
# 311:	total: 4s	remaining: 21.7s
# 312:	total: 4.02s	remaining: 21.7s
# 313:	total: 4.03s	remaining: 21.6s
# 314:	total: 4.04s	remaining: 21.6s
# 315:	total: 4.06s	remaining: 21.6s
# 316:	total: 4.07s	remaining: 21.6s
# 317:	total: 4.08s	remaining: 21.6s
# 318:	total: 4.09s	remaining: 21.6s
# 319:	total: 4.11s	remaining: 21.6s
# 320:	total: 4.12s	remaining: 21.5s
# 321:	total: 4.13s	remaining: 21.5s
# 322:	total: 4.14s	remaining: 21.5s
# 323:	total: 4.16s	remaining: 21.5s
# 324:	total: 4.17s	remaining: 21.5s
# 325:	total: 4.18s	remaining: 21.5s
# 326:	total: 4.19s	remaining: 21.5s
# 327:	total: 4.2s	remaining: 21.4s
# 328:	total: 4.21s	remaining: 21.4s
# 329:	total: 4.23s	remaining: 21.4s
# 330:	total: 4.24s	remaining: 21.4s
# 331:	total: 4.25s	remaining: 21.4s
# 332:	total: 4.26s	remaining: 21.3s
# 333:	total: 4.27s	remaining: 21.3s
# 334:	total: 4.29s	remaining: 21.3s
# 335:	total: 4.3s	remaining: 21.3s
# 336:	total: 4.31s	remaining: 21.3s
# 337:	total: 4.33s	remaining: 21.3s
# 338:	total: 4.34s	remaining: 21.3s
# 339:	total: 4.35s	remaining: 21.3s
# 340:	total: 4.37s	remaining: 21.2s
# 341:	total: 4.38s	remaining: 21.2s
# 342:	total: 4.39s	remaining: 21.2s
# 343:	total: 4.4s	remaining: 21.2s
# 344:	total: 4.41s	remaining: 21.2s
# 345:	total: 4.42s	remaining: 21.1s
# 346:	total: 4.43s	remaining: 21.1s
# 347:	total: 4.45s	remaining: 21.1s
# 348:	total: 4.46s	remaining: 21.1s
# 349:	total: 4.47s	remaining: 21.1s
# 350:	total: 4.48s	remaining: 21.1s
# 351:	total: 4.49s	remaining: 21s
# 352:	total: 4.5s	remaining: 21s
# 353:	total: 4.51s	remaining: 21s
# 354:	total: 4.53s	remaining: 21s
# 355:	total: 4.54s	remaining: 21s
# 356:	total: 4.55s	remaining: 21s
# 357:	total: 4.57s	remaining: 21s
# 358:	total: 4.58s	remaining: 20.9s
# 359:	total: 4.59s	remaining: 20.9s
# 360:	total: 4.6s	remaining: 20.9s
# 361:	total: 4.62s	remaining: 20.9s
# 362:	total: 4.63s	remaining: 20.9s
# 363:	total: 4.64s	remaining: 20.8s
# 364:	total: 4.65s	remaining: 20.8s
# 365:	total: 4.66s	remaining: 20.8s
# 366:	total: 4.67s	remaining: 20.8s
# 367:	total: 4.68s	remaining: 20.8s
# 368:	total: 4.69s	remaining: 20.7s
# 369:	total: 4.71s	remaining: 20.7s
# 370:	total: 4.72s	remaining: 20.7s
# 371:	total: 4.73s	remaining: 20.7s
# 372:	total: 4.75s	remaining: 20.7s
# 373:	total: 4.76s	remaining: 20.7s
# 374:	total: 4.78s	remaining: 20.7s
# 375:	total: 4.79s	remaining: 20.7s
# 376:	total: 4.8s	remaining: 20.7s
# 377:	total: 4.82s	remaining: 20.7s
# 378:	total: 4.83s	remaining: 20.7s
# 379:	total: 4.84s	remaining: 20.6s
# 380:	total: 4.85s	remaining: 20.6s
# 381:	total: 4.86s	remaining: 20.6s
# 382:	total: 4.87s	remaining: 20.6s
# 383:	total: 4.88s	remaining: 20.6s
# 384:	total: 4.9s	remaining: 20.5s
# 385:	total: 4.91s	remaining: 20.5s
# 386:	total: 4.92s	remaining: 20.5s
# 387:	total: 4.94s	remaining: 20.5s
# 388:	total: 4.95s	remaining: 20.5s
# 389:	total: 4.97s	remaining: 20.5s
# 390:	total: 4.98s	remaining: 20.5s
# 391:	total: 4.99s	remaining: 20.5s
# 392:	total: 5s	remaining: 20.5s
# 393:	total: 5.02s	remaining: 20.5s
# 394:	total: 5.03s	remaining: 20.4s
# 395:	total: 5.04s	remaining: 20.4s
# 396:	total: 5.05s	remaining: 20.4s
# 397:	total: 5.06s	remaining: 20.4s
# 398:	total: 5.07s	remaining: 20.4s
# 399:	total: 5.08s	remaining: 20.3s
# 400:	total: 5.1s	remaining: 20.3s
# 401:	total: 5.11s	remaining: 20.3s
# 402:	total: 5.12s	remaining: 20.3s
# 403:	total: 5.13s	remaining: 20.3s
# 404:	total: 5.15s	remaining: 20.3s
# 405:	total: 5.16s	remaining: 20.3s
# 406:	total: 5.18s	remaining: 20.3s
# 407:	total: 5.2s	remaining: 20.3s
# 408:	total: 5.21s	remaining: 20.3s
# 409:	total: 5.22s	remaining: 20.2s
# 410:	total: 5.23s	remaining: 20.2s
# 411:	total: 5.25s	remaining: 20.2s
# 412:	total: 5.26s	remaining: 20.2s
# 413:	total: 5.27s	remaining: 20.2s
# 414:	total: 5.28s	remaining: 20.2s
# 415:	total: 5.3s	remaining: 20.2s
# 416:	total: 5.31s	remaining: 20.2s
# 417:	total: 5.32s	remaining: 20.2s
# 418:	total: 5.34s	remaining: 20.1s
# 419:	total: 5.36s	remaining: 20.1s
# 420:	total: 5.37s	remaining: 20.1s
# 421:	total: 5.38s	remaining: 20.1s
# 422:	total: 5.39s	remaining: 20.1s
# 423:	total: 5.41s	remaining: 20.1s
# 424:	total: 5.42s	remaining: 20.1s
# 425:	total: 5.43s	remaining: 20.1s
# 426:	total: 5.45s	remaining: 20.1s
# 427:	total: 5.46s	remaining: 20.1s
# 428:	total: 5.47s	remaining: 20s
# 429:	total: 5.49s	remaining: 20s
# 430:	total: 5.5s	remaining: 20s
# 431:	total: 5.51s	remaining: 20s
# 432:	total: 5.53s	remaining: 20s
# 433:	total: 5.54s	remaining: 20s
# 434:	total: 5.55s	remaining: 20s
# 435:	total: 5.57s	remaining: 20s
# 436:	total: 5.58s	remaining: 20s
# 437:	total: 5.59s	remaining: 20s
# 438:	total: 5.61s	remaining: 19.9s
# 439:	total: 5.62s	remaining: 19.9s
# 440:	total: 5.63s	remaining: 19.9s
# 441:	total: 5.65s	remaining: 19.9s
# 442:	total: 5.66s	remaining: 19.9s
# 443:	total: 5.67s	remaining: 19.9s
# 444:	total: 5.68s	remaining: 19.9s
# 445:	total: 5.7s	remaining: 19.9s
# 446:	total: 5.71s	remaining: 19.8s
# 447:	total: 5.72s	remaining: 19.8s
# 448:	total: 5.74s	remaining: 19.8s
# 449:	total: 5.75s	remaining: 19.8s
# 450:	total: 5.77s	remaining: 19.8s
# 451:	total: 5.78s	remaining: 19.8s
# 452:	total: 5.8s	remaining: 19.8s
# 453:	total: 5.81s	remaining: 19.8s
# 454:	total: 5.82s	remaining: 19.8s
# 455:	total: 5.84s	remaining: 19.8s
# 456:	total: 5.85s	remaining: 19.8s
# 457:	total: 5.86s	remaining: 19.7s
# 458:	total: 5.88s	remaining: 19.7s
# 459:	total: 5.88s	remaining: 19.7s
# 460:	total: 5.9s	remaining: 19.7s
# 461:	total: 5.91s	remaining: 19.7s
# 462:	total: 5.92s	remaining: 19.6s
# 463:	total: 5.93s	remaining: 19.6s
# 464:	total: 5.94s	remaining: 19.6s
# 465:	total: 5.95s	remaining: 19.6s
# 466:	total: 5.96s	remaining: 19.6s
# 467:	total: 5.98s	remaining: 19.6s
# 468:	total: 5.99s	remaining: 19.6s
# 469:	total: 6s	remaining: 19.5s
# 470:	total: 6.01s	remaining: 19.5s
# 471:	total: 6.03s	remaining: 19.5s
# 472:	total: 6.04s	remaining: 19.5s
# 473:	total: 6.05s	remaining: 19.5s
# 474:	total: 6.07s	remaining: 19.5s
# 475:	total: 6.08s	remaining: 19.5s
# 476:	total: 6.09s	remaining: 19.4s
# 477:	total: 6.1s	remaining: 19.4s
# 478:	total: 6.11s	remaining: 19.4s
# 479:	total: 6.12s	remaining: 19.4s
# 480:	total: 6.14s	remaining: 19.4s
# 481:	total: 6.16s	remaining: 19.4s
# 482:	total: 6.17s	remaining: 19.4s
# 483:	total: 6.18s	remaining: 19.4s
# 484:	total: 6.2s	remaining: 19.4s
# 485:	total: 6.21s	remaining: 19.3s
# 486:	total: 6.22s	remaining: 19.3s
# 487:	total: 6.24s	remaining: 19.3s
# 488:	total: 6.25s	remaining: 19.3s
# 489:	total: 6.26s	remaining: 19.3s
# 490:	total: 6.28s	remaining: 19.3s
# 491:	total: 6.29s	remaining: 19.3s
# 492:	total: 6.3s	remaining: 19.3s
# 493:	total: 6.31s	remaining: 19.2s
# 494:	total: 6.33s	remaining: 19.2s
# 495:	total: 6.34s	remaining: 19.2s
# 496:	total: 6.36s	remaining: 19.2s
# 497:	total: 6.37s	remaining: 19.2s
# 498:	total: 6.39s	remaining: 19.2s
# 499:	total: 6.4s	remaining: 19.2s
# 500:	total: 6.41s	remaining: 19.2s
# 501:	total: 6.43s	remaining: 19.2s
# 502:	total: 6.44s	remaining: 19.2s
# 503:	total: 6.45s	remaining: 19.2s
# 504:	total: 6.46s	remaining: 19.1s
# 505:	total: 6.48s	remaining: 19.1s
# 506:	total: 6.49s	remaining: 19.1s
# 507:	total: 6.5s	remaining: 19.1s
# 508:	total: 6.51s	remaining: 19.1s
# 509:	total: 6.53s	remaining: 19.1s
# 510:	total: 6.54s	remaining: 19.1s
# 511:	total: 6.55s	remaining: 19s
# 512:	total: 6.57s	remaining: 19s
# 513:	total: 6.58s	remaining: 19s
# 514:	total: 6.59s	remaining: 19s
# 515:	total: 6.61s	remaining: 19s
# 516:	total: 6.62s	remaining: 19s
# 517:	total: 6.63s	remaining: 19s
# 518:	total: 6.65s	remaining: 19s
# 519:	total: 6.66s	remaining: 19s
# 520:	total: 6.67s	remaining: 18.9s
# 521:	total: 6.7s	remaining: 19s
# 522:	total: 6.71s	remaining: 19s
# 523:	total: 6.73s	remaining: 19s
# 524:	total: 6.75s	remaining: 19s
# 525:	total: 6.76s	remaining: 18.9s
# 526:	total: 6.78s	remaining: 18.9s
# 527:	total: 6.79s	remaining: 18.9s
# 528:	total: 6.8s	remaining: 18.9s
# 529:	total: 6.82s	remaining: 18.9s
# 530:	total: 6.83s	remaining: 18.9s
# 531:	total: 6.85s	remaining: 18.9s
# 532:	total: 6.86s	remaining: 18.9s
# 533:	total: 6.88s	remaining: 18.9s
# 534:	total: 6.89s	remaining: 18.9s
# 535:	total: 6.91s	remaining: 18.9s
# 536:	total: 6.93s	remaining: 18.9s
# 537:	total: 6.96s	remaining: 18.9s
# 538:	total: 6.98s	remaining: 18.9s
# 539:	total: 7s	remaining: 18.9s
# 540:	total: 7.02s	remaining: 18.9s
# 541:	total: 7.04s	remaining: 18.9s
# 542:	total: 7.06s	remaining: 18.9s
# 543:	total: 7.08s	remaining: 18.9s
# 544:	total: 7.11s	remaining: 19s
# 545:	total: 7.13s	remaining: 19s
# 546:	total: 7.16s	remaining: 19s
# 547:	total: 7.19s	remaining: 19s
# 548:	total: 7.21s	remaining: 19.1s
# 549:	total: 7.24s	remaining: 19.1s
# 550:	total: 7.27s	remaining: 19.1s
# 551:	total: 7.29s	remaining: 19.1s
# 552:	total: 7.32s	remaining: 19.2s
# 553:	total: 7.35s	remaining: 19.2s
# 554:	total: 7.37s	remaining: 19.2s
# 555:	total: 7.4s	remaining: 19.2s
# 556:	total: 7.43s	remaining: 19.2s
# 557:	total: 7.45s	remaining: 19.3s
# 558:	total: 7.48s	remaining: 19.3s
# 559:	total: 7.5s	remaining: 19.3s
# 560:	total: 7.54s	remaining: 19.3s
# 561:	total: 7.57s	remaining: 19.4s
# 562:	total: 7.6s	remaining: 19.4s
# 563:	total: 7.64s	remaining: 19.5s
# 564:	total: 7.67s	remaining: 19.5s
# 565:	total: 7.71s	remaining: 19.5s
# 566:	total: 7.74s	remaining: 19.6s
# 567:	total: 7.78s	remaining: 19.6s
# 568:	total: 7.82s	remaining: 19.7s
# 569:	total: 7.85s	remaining: 19.7s
# 570:	total: 7.89s	remaining: 19.7s
# 571:	total: 7.92s	remaining: 19.8s
# 572:	total: 7.95s	remaining: 19.8s
# 573:	total: 7.98s	remaining: 19.8s
# 574:	total: 8.01s	remaining: 19.9s
# 575:	total: 8.05s	remaining: 19.9s
# 576:	total: 8.09s	remaining: 20s
# 577:	total: 8.13s	remaining: 20s
# 578:	total: 8.17s	remaining: 20.1s
# 579:	total: 8.21s	remaining: 20.1s
# 580:	total: 8.24s	remaining: 20.1s
# 581:	total: 8.29s	remaining: 20.2s
# 582:	total: 8.32s	remaining: 20.2s
# 583:	total: 8.36s	remaining: 20.3s
# 584:	total: 8.39s	remaining: 20.3s
# 585:	total: 8.42s	remaining: 20.3s
# 586:	total: 8.46s	remaining: 20.4s
# 587:	total: 8.5s	remaining: 20.4s
# 588:	total: 8.55s	remaining: 20.5s
# 589:	total: 8.59s	remaining: 20.5s
# 590:	total: 8.63s	remaining: 20.6s
# 591:	total: 8.67s	remaining: 20.6s
# 592:	total: 8.71s	remaining: 20.7s
# 593:	total: 8.75s	remaining: 20.7s
# 594:	total: 8.79s	remaining: 20.8s
# 595:	total: 8.82s	remaining: 20.8s
# 596:	total: 8.86s	remaining: 20.8s
# 597:	total: 8.89s	remaining: 20.9s
# 598:	total: 8.93s	remaining: 20.9s
# 599:	total: 8.97s	remaining: 20.9s
# 600:	total: 9.01s	remaining: 21s
# 601:	total: 9.04s	remaining: 21s
# 602:	total: 9.07s	remaining: 21s
# 603:	total: 9.1s	remaining: 21s
# 604:	total: 9.14s	remaining: 21.1s
# 605:	total: 9.17s	remaining: 21.1s
# 606:	total: 9.21s	remaining: 21.1s
# 607:	total: 9.24s	remaining: 21.2s
# 608:	total: 9.27s	remaining: 21.2s
# 609:	total: 9.3s	remaining: 21.2s
# 610:	total: 9.33s	remaining: 21.2s
# 611:	total: 9.37s	remaining: 21.2s
# 612:	total: 9.4s	remaining: 21.3s
# 613:	total: 9.44s	remaining: 21.3s
# 614:	total: 9.47s	remaining: 21.3s
# 615:	total: 9.5s	remaining: 21.4s
# 616:	total: 9.54s	remaining: 21.4s
# 617:	total: 9.56s	remaining: 21.4s
# 618:	total: 9.6s	remaining: 21.4s
# 619:	total: 9.63s	remaining: 21.4s
# 620:	total: 9.67s	remaining: 21.5s
# 621:	total: 9.7s	remaining: 21.5s
# 622:	total: 9.72s	remaining: 21.5s
# 623:	total: 9.75s	remaining: 21.5s
# 624:	total: 9.78s	remaining: 21.5s
# 625:	total: 9.8s	remaining: 21.5s
# 626:	total: 9.84s	remaining: 21.5s
# 627:	total: 9.87s	remaining: 21.6s
# 628:	total: 9.9s	remaining: 21.6s
# 629:	total: 9.93s	remaining: 21.6s
# 630:	total: 9.96s	remaining: 21.6s
# 631:	total: 9.99s	remaining: 21.6s
# 632:	total: 10s	remaining: 21.6s
# 633:	total: 10.1s	remaining: 21.7s
# 634:	total: 10.1s	remaining: 21.7s
# 635:	total: 10.1s	remaining: 21.7s
# 636:	total: 10.1s	remaining: 21.7s
# 637:	total: 10.2s	remaining: 21.7s
# 638:	total: 10.2s	remaining: 21.7s
# 639:	total: 10.2s	remaining: 21.7s
# 640:	total: 10.3s	remaining: 21.8s
# 641:	total: 10.3s	remaining: 21.8s
# 642:	total: 10.3s	remaining: 21.8s
# 643:	total: 10.4s	remaining: 21.8s
# 644:	total: 10.4s	remaining: 21.8s
# 645:	total: 10.4s	remaining: 21.8s
# 646:	total: 10.4s	remaining: 21.8s
# 647:	total: 10.5s	remaining: 21.8s
# 648:	total: 10.5s	remaining: 21.9s
# 649:	total: 10.5s	remaining: 21.9s
# 650:	total: 10.6s	remaining: 21.9s
# 651:	total: 10.6s	remaining: 21.9s
# 652:	total: 10.6s	remaining: 21.9s
# 653:	total: 10.6s	remaining: 21.9s
# 654:	total: 10.7s	remaining: 21.9s
# 655:	total: 10.7s	remaining: 21.9s
# 656:	total: 10.7s	remaining: 21.9s
# 657:	total: 10.7s	remaining: 21.9s
# 658:	total: 10.7s	remaining: 21.9s
# 659:	total: 10.8s	remaining: 21.9s
# 660:	total: 10.8s	remaining: 21.9s
# 661:	total: 10.8s	remaining: 21.9s
# 662:	total: 10.8s	remaining: 21.9s
# 663:	total: 10.9s	remaining: 21.9s
# 664:	total: 10.9s	remaining: 21.9s
# 665:	total: 10.9s	remaining: 21.9s
# 666:	total: 10.9s	remaining: 21.8s
# 667:	total: 11s	remaining: 21.8s
# 668:	total: 11s	remaining: 21.8s
# 669:	total: 11s	remaining: 21.8s
# 670:	total: 11s	remaining: 21.8s
# 671:	total: 11s	remaining: 21.8s
# 672:	total: 11.1s	remaining: 21.8s
# 673:	total: 11.1s	remaining: 21.8s
# 674:	total: 11.1s	remaining: 21.8s
# 675:	total: 11.1s	remaining: 21.8s
# 676:	total: 11.2s	remaining: 21.8s
# 677:	total: 11.2s	remaining: 21.8s
# 678:	total: 11.2s	remaining: 21.8s
# 679:	total: 11.2s	remaining: 21.8s
# 680:	total: 11.2s	remaining: 21.8s
# 681:	total: 11.3s	remaining: 21.8s
# 682:	total: 11.3s	remaining: 21.8s
# 683:	total: 11.3s	remaining: 21.7s
# 684:	total: 11.3s	remaining: 21.7s
# 685:	total: 11.3s	remaining: 21.7s
# 686:	total: 11.4s	remaining: 21.7s
# 687:	total: 11.4s	remaining: 21.7s
# 688:	total: 11.4s	remaining: 21.7s
# 689:	total: 11.4s	remaining: 21.7s
# 690:	total: 11.4s	remaining: 21.7s
# 691:	total: 11.5s	remaining: 21.7s
# 692:	total: 11.5s	remaining: 21.7s
# 693:	total: 11.5s	remaining: 21.7s
# 694:	total: 11.5s	remaining: 21.7s
# 695:	total: 11.6s	remaining: 21.6s
# 696:	total: 11.6s	remaining: 21.6s
# 697:	total: 11.6s	remaining: 21.6s
# 698:	total: 11.6s	remaining: 21.6s
# 699:	total: 11.6s	remaining: 21.6s
# 700:	total: 11.7s	remaining: 21.6s
# 701:	total: 11.7s	remaining: 21.6s
# 702:	total: 11.7s	remaining: 21.6s
# 703:	total: 11.7s	remaining: 21.6s
# 704:	total: 11.7s	remaining: 21.6s
# 705:	total: 11.8s	remaining: 21.5s
# 706:	total: 11.8s	remaining: 21.5s
# 707:	total: 11.8s	remaining: 21.5s
# 708:	total: 11.8s	remaining: 21.5s
# 709:	total: 11.8s	remaining: 21.5s
# 710:	total: 11.9s	remaining: 21.5s
# 711:	total: 11.9s	remaining: 21.5s
# 712:	total: 11.9s	remaining: 21.5s
# 713:	total: 11.9s	remaining: 21.5s
# 714:	total: 11.9s	remaining: 21.5s
# 715:	total: 12s	remaining: 21.4s
# 716:	total: 12s	remaining: 21.4s
# 717:	total: 12s	remaining: 21.4s
# 718:	total: 12s	remaining: 21.4s
# 719:	total: 12s	remaining: 21.4s
# 720:	total: 12.1s	remaining: 21.4s
# 721:	total: 12.1s	remaining: 21.4s
# 722:	total: 12.1s	remaining: 21.3s
# 723:	total: 12.1s	remaining: 21.3s
# 724:	total: 12.1s	remaining: 21.3s
# 725:	total: 12.1s	remaining: 21.3s
# 726:	total: 12.2s	remaining: 21.3s
# 727:	total: 12.2s	remaining: 21.3s
# 728:	total: 12.2s	remaining: 21.3s
# 729:	total: 12.2s	remaining: 21.3s
# 730:	total: 12.2s	remaining: 21.2s
# 731:	total: 12.3s	remaining: 21.2s
# 732:	total: 12.3s	remaining: 21.2s
# 733:	total: 12.3s	remaining: 21.2s
# 734:	total: 12.3s	remaining: 21.2s
# 735:	total: 12.3s	remaining: 21.2s
# 736:	total: 12.3s	remaining: 21.2s
# 737:	total: 12.4s	remaining: 21.1s
# 738:	total: 12.4s	remaining: 21.1s
# 739:	total: 12.4s	remaining: 21.1s
# 740:	total: 12.4s	remaining: 21.1s
# 741:	total: 12.4s	remaining: 21.1s
# 742:	total: 12.5s	remaining: 21.1s
# 743:	total: 12.5s	remaining: 21.1s
# 744:	total: 12.5s	remaining: 21s
# 745:	total: 12.5s	remaining: 21s
# 746:	total: 12.5s	remaining: 21s
# 747:	total: 12.6s	remaining: 21s
# 748:	total: 12.6s	remaining: 21s
# 749:	total: 12.6s	remaining: 21s
# 750:	total: 12.6s	remaining: 21s
# 751:	total: 12.6s	remaining: 21s
# 752:	total: 12.7s	remaining: 21s
# 753:	total: 12.7s	remaining: 20.9s
# 754:	total: 12.7s	remaining: 20.9s
# 755:	total: 12.7s	remaining: 20.9s
# 756:	total: 12.7s	remaining: 20.9s
# 757:	total: 12.8s	remaining: 20.9s
# 758:	total: 12.8s	remaining: 20.9s
# 759:	total: 12.8s	remaining: 20.9s
# 760:	total: 12.8s	remaining: 20.9s
# 761:	total: 12.9s	remaining: 20.9s
# 762:	total: 12.9s	remaining: 20.9s
# 763:	total: 12.9s	remaining: 20.9s
# 764:	total: 12.9s	remaining: 20.9s
# 765:	total: 12.9s	remaining: 20.9s
# 766:	total: 13s	remaining: 20.8s
# 767:	total: 13s	remaining: 20.8s
# 768:	total: 13s	remaining: 20.8s
# 769:	total: 13s	remaining: 20.8s
# 770:	total: 13.1s	remaining: 20.8s
# 771:	total: 13.1s	remaining: 20.8s
# 772:	total: 13.1s	remaining: 20.8s
# 773:	total: 13.1s	remaining: 20.8s
# 774:	total: 13.1s	remaining: 20.8s
# 775:	total: 13.2s	remaining: 20.8s
# 776:	total: 13.2s	remaining: 20.8s
# 777:	total: 13.2s	remaining: 20.7s
# 778:	total: 13.2s	remaining: 20.7s
# 779:	total: 13.3s	remaining: 20.7s
# 780:	total: 13.3s	remaining: 20.7s
# 781:	total: 13.3s	remaining: 20.7s
# 782:	total: 13.3s	remaining: 20.7s
# 783:	total: 13.3s	remaining: 20.7s
# 784:	total: 13.3s	remaining: 20.7s
# 785:	total: 13.4s	remaining: 20.6s
# 786:	total: 13.4s	remaining: 20.6s
# 787:	total: 13.4s	remaining: 20.6s
# 788:	total: 13.4s	remaining: 20.6s
# 789:	total: 13.4s	remaining: 20.6s
# 790:	total: 13.4s	remaining: 20.6s
# 791:	total: 13.5s	remaining: 20.5s
# 792:	total: 13.5s	remaining: 20.5s
# 793:	total: 13.5s	remaining: 20.5s
# 794:	total: 13.5s	remaining: 20.5s
# 795:	total: 13.5s	remaining: 20.5s
# 796:	total: 13.6s	remaining: 20.5s
# 797:	total: 13.6s	remaining: 20.4s
# 798:	total: 13.6s	remaining: 20.4s
# 799:	total: 13.6s	remaining: 20.4s
# 800:	total: 13.6s	remaining: 20.4s
# 801:	total: 13.6s	remaining: 20.4s
# 802:	total: 13.7s	remaining: 20.4s
# 803:	total: 13.7s	remaining: 20.4s
# 804:	total: 13.7s	remaining: 20.3s
# 805:	total: 13.7s	remaining: 20.3s
# 806:	total: 13.7s	remaining: 20.3s
# 807:	total: 13.8s	remaining: 20.3s
# 808:	total: 13.8s	remaining: 20.3s
# 809:	total: 13.8s	remaining: 20.3s
# 810:	total: 13.8s	remaining: 20.2s
# 811:	total: 13.8s	remaining: 20.2s
# 812:	total: 13.8s	remaining: 20.2s
# 813:	total: 13.9s	remaining: 20.2s
# 814:	total: 13.9s	remaining: 20.2s
# 815:	total: 13.9s	remaining: 20.2s
# 816:	total: 13.9s	remaining: 20.1s
# 817:	total: 13.9s	remaining: 20.1s
# 818:	total: 13.9s	remaining: 20.1s
# 819:	total: 14s	remaining: 20.1s
# 820:	total: 14s	remaining: 20.1s
# 821:	total: 14s	remaining: 20.1s
# 822:	total: 14s	remaining: 20.1s
# 823:	total: 14s	remaining: 20s
# 824:	total: 14.1s	remaining: 20s
# 825:	total: 14.1s	remaining: 20s
# 826:	total: 14.1s	remaining: 20s
# 827:	total: 14.1s	remaining: 20s
# 828:	total: 14.1s	remaining: 20s
# 829:	total: 14.1s	remaining: 19.9s
# 830:	total: 14.2s	remaining: 19.9s
# 831:	total: 14.2s	remaining: 19.9s
# 832:	total: 14.2s	remaining: 19.9s
# 833:	total: 14.2s	remaining: 19.9s
# 834:	total: 14.2s	remaining: 19.9s
# 835:	total: 14.3s	remaining: 19.8s
# 836:	total: 14.3s	remaining: 19.8s
# 837:	total: 14.3s	remaining: 19.8s
# 838:	total: 14.3s	remaining: 19.8s
# 839:	total: 14.3s	remaining: 19.8s
# 840:	total: 14.3s	remaining: 19.8s
# 841:	total: 14.4s	remaining: 19.7s
# 842:	total: 14.4s	remaining: 19.7s
# 843:	total: 14.4s	remaining: 19.7s
# 844:	total: 14.4s	remaining: 19.7s
# 845:	total: 14.4s	remaining: 19.7s
# 846:	total: 14.4s	remaining: 19.7s
# 847:	total: 14.5s	remaining: 19.6s
# 848:	total: 14.5s	remaining: 19.6s
# 849:	total: 14.5s	remaining: 19.6s
# 850:	total: 14.5s	remaining: 19.6s
# 851:	total: 14.5s	remaining: 19.6s
# 852:	total: 14.5s	remaining: 19.6s
# 853:	total: 14.6s	remaining: 19.5s
# 854:	total: 14.6s	remaining: 19.5s
# 855:	total: 14.6s	remaining: 19.5s
# 856:	total: 14.6s	remaining: 19.5s
# 857:	total: 14.6s	remaining: 19.5s
# 858:	total: 14.7s	remaining: 19.5s
# 859:	total: 14.7s	remaining: 19.4s
# 860:	total: 14.7s	remaining: 19.4s
# 861:	total: 14.7s	remaining: 19.4s
# 862:	total: 14.7s	remaining: 19.4s
# 863:	total: 14.7s	remaining: 19.4s
# 864:	total: 14.8s	remaining: 19.4s
# 865:	total: 14.8s	remaining: 19.3s
# 866:	total: 14.8s	remaining: 19.3s
# 867:	total: 14.8s	remaining: 19.3s
# 868:	total: 14.8s	remaining: 19.3s
# 869:	total: 14.8s	remaining: 19.3s
# 870:	total: 14.9s	remaining: 19.3s
# 871:	total: 14.9s	remaining: 19.2s
# 872:	total: 14.9s	remaining: 19.2s
# 873:	total: 14.9s	remaining: 19.2s
# 874:	total: 14.9s	remaining: 19.2s
# 875:	total: 14.9s	remaining: 19.2s
# 876:	total: 15s	remaining: 19.1s
# 877:	total: 15s	remaining: 19.1s
# 878:	total: 15s	remaining: 19.1s
# 879:	total: 15s	remaining: 19.1s
# 880:	total: 15s	remaining: 19.1s
# 881:	total: 15s	remaining: 19.1s
# 882:	total: 15.1s	remaining: 19s
# 883:	total: 15.1s	remaining: 19s
# 884:	total: 15.1s	remaining: 19s
# 885:	total: 15.1s	remaining: 19s
# 886:	total: 15.1s	remaining: 19s
# 887:	total: 15.1s	remaining: 18.9s
# 888:	total: 15.2s	remaining: 18.9s
# 889:	total: 15.2s	remaining: 18.9s
# 890:	total: 15.2s	remaining: 18.9s
# 891:	total: 15.2s	remaining: 18.9s
# 892:	total: 15.2s	remaining: 18.9s
# 893:	total: 15.2s	remaining: 18.9s
# 894:	total: 15.3s	remaining: 18.8s
# 895:	total: 15.3s	remaining: 18.8s
# 896:	total: 15.3s	remaining: 18.8s
# 897:	total: 15.3s	remaining: 18.8s
# 898:	total: 15.3s	remaining: 18.8s
# 899:	total: 15.3s	remaining: 18.7s
# 900:	total: 15.3s	remaining: 18.7s
# 901:	total: 15.4s	remaining: 18.7s
# 902:	total: 15.4s	remaining: 18.7s
# 903:	total: 15.4s	remaining: 18.7s
# 904:	total: 15.4s	remaining: 18.6s
# 905:	total: 15.4s	remaining: 18.6s
# 906:	total: 15.4s	remaining: 18.6s
# 907:	total: 15.5s	remaining: 18.6s
# 908:	total: 15.5s	remaining: 18.6s
# 909:	total: 15.5s	remaining: 18.6s
# 910:	total: 15.5s	remaining: 18.5s
# 911:	total: 15.5s	remaining: 18.5s
# 912:	total: 15.5s	remaining: 18.5s
# 913:	total: 15.6s	remaining: 18.5s
# 914:	total: 15.6s	remaining: 18.5s
# 915:	total: 15.6s	remaining: 18.5s
# 916:	total: 15.6s	remaining: 18.4s
# 917:	total: 15.6s	remaining: 18.4s
# 918:	total: 15.6s	remaining: 18.4s
# 919:	total: 15.7s	remaining: 18.4s
# 920:	total: 15.7s	remaining: 18.4s
# 921:	total: 15.7s	remaining: 18.3s
# 922:	total: 15.7s	remaining: 18.3s
# 923:	total: 15.7s	remaining: 18.3s
# 924:	total: 15.7s	remaining: 18.3s
# 925:	total: 15.8s	remaining: 18.3s
# 926:	total: 15.8s	remaining: 18.3s
# 927:	total: 15.8s	remaining: 18.2s
# 928:	total: 15.8s	remaining: 18.2s
# 929:	total: 15.8s	remaining: 18.2s
# 930:	total: 15.8s	remaining: 18.2s
# 931:	total: 15.8s	remaining: 18.2s
# 932:	total: 15.9s	remaining: 18.1s
# 933:	total: 15.9s	remaining: 18.1s
# 934:	total: 15.9s	remaining: 18.1s
# 935:	total: 15.9s	remaining: 18.1s
# 936:	total: 15.9s	remaining: 18.1s
# 937:	total: 15.9s	remaining: 18.1s
# 938:	total: 16s	remaining: 18s
# 939:	total: 16s	remaining: 18s
# 940:	total: 16s	remaining: 18s
# 941:	total: 16s	remaining: 18s
# 942:	total: 16s	remaining: 18s
# 943:	total: 16.1s	remaining: 18s
# 944:	total: 16.1s	remaining: 17.9s
# 945:	total: 16.1s	remaining: 17.9s
# 946:	total: 16.1s	remaining: 17.9s
# 947:	total: 16.1s	remaining: 17.9s
# 948:	total: 16.1s	remaining: 17.9s
# 949:	total: 16.1s	remaining: 17.8s
# 950:	total: 16.2s	remaining: 17.8s
# 951:	total: 16.2s	remaining: 17.8s
# 952:	total: 16.2s	remaining: 17.8s
# 953:	total: 16.2s	remaining: 17.8s
# 954:	total: 16.2s	remaining: 17.8s
# 955:	total: 16.3s	remaining: 17.7s
# 956:	total: 16.3s	remaining: 17.7s
# 957:	total: 16.3s	remaining: 17.7s
# 958:	total: 16.3s	remaining: 17.7s
# 959:	total: 16.3s	remaining: 17.7s
# 960:	total: 16.3s	remaining: 17.7s
# 961:	total: 16.4s	remaining: 17.7s
# 962:	total: 16.4s	remaining: 17.6s
# 963:	total: 16.4s	remaining: 17.6s
# 964:	total: 16.4s	remaining: 17.6s
# 965:	total: 16.4s	remaining: 17.6s
# 966:	total: 16.4s	remaining: 17.6s
# 967:	total: 16.5s	remaining: 17.6s
# 968:	total: 16.5s	remaining: 17.5s
# 969:	total: 16.5s	remaining: 17.5s
# 970:	total: 16.5s	remaining: 17.5s
# 971:	total: 16.5s	remaining: 17.5s
# 972:	total: 16.6s	remaining: 17.5s
# 973:	total: 16.6s	remaining: 17.5s
# 974:	total: 16.6s	remaining: 17.4s
# 975:	total: 16.6s	remaining: 17.4s
# 976:	total: 16.6s	remaining: 17.4s
# 977:	total: 16.6s	remaining: 17.4s
# 978:	total: 16.7s	remaining: 17.4s
# 979:	total: 16.7s	remaining: 17.4s
# 980:	total: 16.7s	remaining: 17.3s
# 981:	total: 16.7s	remaining: 17.3s
# 982:	total: 16.7s	remaining: 17.3s
# 983:	total: 16.8s	remaining: 17.3s
# 984:	total: 16.8s	remaining: 17.3s
# 985:	total: 16.8s	remaining: 17.3s
# 986:	total: 16.8s	remaining: 17.3s
# 987:	total: 16.8s	remaining: 17.2s
# 988:	total: 16.8s	remaining: 17.2s
# 989:	total: 16.9s	remaining: 17.2s
# 990:	total: 16.9s	remaining: 17.2s
# 991:	total: 16.9s	remaining: 17.2s
# 992:	total: 16.9s	remaining: 17.2s
# 993:	total: 16.9s	remaining: 17.1s
# 994:	total: 17s	remaining: 17.1s
# 995:	total: 17s	remaining: 17.1s
# 996:	total: 17s	remaining: 17.1s
# 997:	total: 17s	remaining: 17.1s
# 998:	total: 17s	remaining: 17s
# 999:	total: 17s	remaining: 17s
# 1000:	total: 17.1s	remaining: 17s
# 1001:	total: 17.1s	remaining: 17s
# 1002:	total: 17.1s	remaining: 17s
# 1003:	total: 17.1s	remaining: 17s
# 1004:	total: 17.1s	remaining: 17s
# 1005:	total: 17.1s	remaining: 16.9s
# 1006:	total: 17.2s	remaining: 16.9s
# 1007:	total: 17.2s	remaining: 16.9s
# 1008:	total: 17.2s	remaining: 16.9s
# 1009:	total: 17.2s	remaining: 16.9s
# 1010:	total: 17.2s	remaining: 16.9s
# 1011:	total: 17.3s	remaining: 16.8s
# 1012:	total: 17.3s	remaining: 16.8s
# 1013:	total: 17.3s	remaining: 16.8s
# 1014:	total: 17.3s	remaining: 16.8s
# 1015:	total: 17.3s	remaining: 16.8s
# 1016:	total: 17.3s	remaining: 16.8s
# 1017:	total: 17.4s	remaining: 16.8s
# 1018:	total: 17.4s	remaining: 16.7s
# 1019:	total: 17.4s	remaining: 16.7s
# 1020:	total: 17.4s	remaining: 16.7s
# 1021:	total: 17.5s	remaining: 16.7s
# 1022:	total: 17.5s	remaining: 16.7s
# 1023:	total: 17.5s	remaining: 16.7s
# 1024:	total: 17.5s	remaining: 16.7s
# 1025:	total: 17.5s	remaining: 16.6s
# 1026:	total: 17.6s	remaining: 16.6s
# 1027:	total: 17.6s	remaining: 16.6s
# 1028:	total: 17.6s	remaining: 16.6s
# 1029:	total: 17.6s	remaining: 16.6s
# 1030:	total: 17.6s	remaining: 16.6s
# 1031:	total: 17.7s	remaining: 16.6s
# 1032:	total: 17.7s	remaining: 16.5s
# 1033:	total: 17.7s	remaining: 16.5s
# 1034:	total: 17.7s	remaining: 16.5s
# 1035:	total: 17.7s	remaining: 16.5s
# 1036:	total: 17.8s	remaining: 16.5s
# 1037:	total: 17.8s	remaining: 16.5s
# 1038:	total: 17.8s	remaining: 16.5s
# 1039:	total: 17.8s	remaining: 16.4s
# 1040:	total: 17.8s	remaining: 16.4s
# 1041:	total: 17.9s	remaining: 16.4s
# 1042:	total: 17.9s	remaining: 16.4s
# 1043:	total: 17.9s	remaining: 16.4s
# 1044:	total: 17.9s	remaining: 16.4s
# 1045:	total: 17.9s	remaining: 16.4s
# 1046:	total: 18s	remaining: 16.3s
# 1047:	total: 18s	remaining: 16.3s
# 1048:	total: 18s	remaining: 16.3s
# 1049:	total: 18s	remaining: 16.3s
# 1050:	total: 18s	remaining: 16.3s
# 1051:	total: 18.1s	remaining: 16.3s
# 1052:	total: 18.1s	remaining: 16.3s
# 1053:	total: 18.1s	remaining: 16.2s
# 1054:	total: 18.1s	remaining: 16.2s
# 1055:	total: 18.1s	remaining: 16.2s
# 1056:	total: 18.1s	remaining: 16.2s
# 1057:	total: 18.2s	remaining: 16.2s
# 1058:	total: 18.2s	remaining: 16.2s
# 1059:	total: 18.2s	remaining: 16.1s
# 1060:	total: 18.2s	remaining: 16.1s
# 1061:	total: 18.2s	remaining: 16.1s
# 1062:	total: 18.3s	remaining: 16.1s
# 1063:	total: 18.3s	remaining: 16.1s
# 1064:	total: 18.3s	remaining: 16.1s
# 1065:	total: 18.3s	remaining: 16s
# 1066:	total: 18.3s	remaining: 16s
# 1067:	total: 18.3s	remaining: 16s
# 1068:	total: 18.4s	remaining: 16s
# 1069:	total: 18.4s	remaining: 16s
# 1070:	total: 18.4s	remaining: 16s
# 1071:	total: 18.4s	remaining: 15.9s
# 1072:	total: 18.4s	remaining: 15.9s
# 1073:	total: 18.4s	remaining: 15.9s
# 1074:	total: 18.5s	remaining: 15.9s
# 1075:	total: 18.5s	remaining: 15.9s
# 1076:	total: 18.5s	remaining: 15.9s
# 1077:	total: 18.5s	remaining: 15.8s
# 1078:	total: 18.5s	remaining: 15.8s
# 1079:	total: 18.6s	remaining: 15.8s
# 1080:	total: 18.6s	remaining: 15.8s
# 1081:	total: 18.6s	remaining: 15.8s
# 1082:	total: 18.6s	remaining: 15.8s
# 1083:	total: 18.6s	remaining: 15.7s
# 1084:	total: 18.7s	remaining: 15.7s
# 1085:	total: 18.7s	remaining: 15.7s
# 1086:	total: 18.7s	remaining: 15.7s
# 1087:	total: 18.7s	remaining: 15.7s
# 1088:	total: 18.7s	remaining: 15.7s
# 1089:	total: 18.7s	remaining: 15.7s
# 1090:	total: 18.8s	remaining: 15.6s
# 1091:	total: 18.8s	remaining: 15.6s
# 1092:	total: 18.8s	remaining: 15.6s
# 1093:	total: 18.8s	remaining: 15.6s
# 1094:	total: 18.8s	remaining: 15.6s
# 1095:	total: 18.8s	remaining: 15.5s
# 1096:	total: 18.9s	remaining: 15.5s
# 1097:	total: 18.9s	remaining: 15.5s
# 1098:	total: 18.9s	remaining: 15.5s
# 1099:	total: 18.9s	remaining: 15.5s
# 1100:	total: 18.9s	remaining: 15.5s
# 1101:	total: 19s	remaining: 15.5s
# 1102:	total: 19s	remaining: 15.4s
# 1103:	total: 19s	remaining: 15.4s
# 1104:	total: 19s	remaining: 15.4s
# 1105:	total: 19s	remaining: 15.4s
# 1106:	total: 19.1s	remaining: 15.4s
# 1107:	total: 19.1s	remaining: 15.4s
# 1108:	total: 19.1s	remaining: 15.3s
# 1109:	total: 19.1s	remaining: 15.3s
# 1110:	total: 19.1s	remaining: 15.3s
# 1111:	total: 19.2s	remaining: 15.3s
# 1112:	total: 19.2s	remaining: 15.3s
# 1113:	total: 19.2s	remaining: 15.3s
# 1114:	total: 19.2s	remaining: 15.3s
# 1115:	total: 19.2s	remaining: 15.2s
# 1116:	total: 19.3s	remaining: 15.2s
# 1117:	total: 19.3s	remaining: 15.2s
# 1118:	total: 19.3s	remaining: 15.2s
# 1119:	total: 19.3s	remaining: 15.2s
# 1120:	total: 19.4s	remaining: 15.2s
# 1121:	total: 19.4s	remaining: 15.2s
# 1122:	total: 19.4s	remaining: 15.2s
# 1123:	total: 19.4s	remaining: 15.1s
# 1124:	total: 19.4s	remaining: 15.1s
# 1125:	total: 19.5s	remaining: 15.1s
# 1126:	total: 19.5s	remaining: 15.1s
# 1127:	total: 19.5s	remaining: 15.1s
# 1128:	total: 19.5s	remaining: 15.1s
# 1129:	total: 19.5s	remaining: 15s
# 1130:	total: 19.6s	remaining: 15s
# 1131:	total: 19.6s	remaining: 15s
# 1132:	total: 19.6s	remaining: 15s
# 1133:	total: 19.6s	remaining: 15s
# 1134:	total: 19.6s	remaining: 15s
# 1135:	total: 19.7s	remaining: 14.9s
# 1136:	total: 19.7s	remaining: 14.9s
# 1137:	total: 19.7s	remaining: 14.9s
# 1138:	total: 19.7s	remaining: 14.9s
# 1139:	total: 19.7s	remaining: 14.9s
# 1140:	total: 19.8s	remaining: 14.9s
# 1141:	total: 19.8s	remaining: 14.9s
# 1142:	total: 19.8s	remaining: 14.8s
# 1143:	total: 19.8s	remaining: 14.8s
# 1144:	total: 19.8s	remaining: 14.8s
# 1145:	total: 19.9s	remaining: 14.8s
# 1146:	total: 19.9s	remaining: 14.8s
# 1147:	total: 19.9s	remaining: 14.8s
# 1148:	total: 19.9s	remaining: 14.8s
# 1149:	total: 19.9s	remaining: 14.7s
# 1150:	total: 20s	remaining: 14.7s
# 1151:	total: 20s	remaining: 14.7s
# 1152:	total: 20s	remaining: 14.7s
# 1153:	total: 20s	remaining: 14.7s
# 1154:	total: 20s	remaining: 14.7s
# 1155:	total: 20.1s	remaining: 14.6s
# 1156:	total: 20.1s	remaining: 14.6s
# 1157:	total: 20.1s	remaining: 14.6s
# 1158:	total: 20.1s	remaining: 14.6s
# 1159:	total: 20.2s	remaining: 14.6s
# 1160:	total: 20.2s	remaining: 14.6s
# 1161:	total: 20.2s	remaining: 14.6s
# 1162:	total: 20.2s	remaining: 14.5s
# 1163:	total: 20.2s	remaining: 14.5s
# 1164:	total: 20.3s	remaining: 14.5s
# 1165:	total: 20.3s	remaining: 14.5s
# 1166:	total: 20.3s	remaining: 14.5s
# 1167:	total: 20.3s	remaining: 14.5s
# 1168:	total: 20.3s	remaining: 14.5s
# 1169:	total: 20.3s	remaining: 14.4s
# 1170:	total: 20.4s	remaining: 14.4s
# 1171:	total: 20.4s	remaining: 14.4s
# 1172:	total: 20.4s	remaining: 14.4s
# 1173:	total: 20.4s	remaining: 14.4s
# 1174:	total: 20.4s	remaining: 14.4s
# 1175:	total: 20.5s	remaining: 14.3s
# 1176:	total: 20.5s	remaining: 14.3s
# 1177:	total: 20.5s	remaining: 14.3s
# 1178:	total: 20.5s	remaining: 14.3s
# 1179:	total: 20.5s	remaining: 14.3s
# 1180:	total: 20.6s	remaining: 14.3s
# 1181:	total: 20.6s	remaining: 14.2s
# 1182:	total: 20.6s	remaining: 14.2s
# 1183:	total: 20.6s	remaining: 14.2s
# 1184:	total: 20.6s	remaining: 14.2s
# 1185:	total: 20.6s	remaining: 14.2s
# 1186:	total: 20.7s	remaining: 14.2s
# 1187:	total: 20.7s	remaining: 14.1s
# 1188:	total: 20.7s	remaining: 14.1s
# 1189:	total: 20.7s	remaining: 14.1s
# 1190:	total: 20.7s	remaining: 14.1s
# 1191:	total: 20.8s	remaining: 14.1s
# 1192:	total: 20.8s	remaining: 14.1s
# 1193:	total: 20.8s	remaining: 14s
# 1194:	total: 20.8s	remaining: 14s
# 1195:	total: 20.8s	remaining: 14s
# 1196:	total: 20.9s	remaining: 14s
# 1197:	total: 20.9s	remaining: 14s
# 1198:	total: 20.9s	remaining: 14s
# 1199:	total: 20.9s	remaining: 13.9s
# 1200:	total: 20.9s	remaining: 13.9s
# 1201:	total: 21s	remaining: 13.9s
# 1202:	total: 21s	remaining: 13.9s
# 1203:	total: 21s	remaining: 13.9s
# 1204:	total: 21s	remaining: 13.9s
# 1205:	total: 21s	remaining: 13.8s
# 1206:	total: 21.1s	remaining: 13.8s
# 1207:	total: 21.1s	remaining: 13.8s
# 1208:	total: 21.1s	remaining: 13.8s
# 1209:	total: 21.1s	remaining: 13.8s
# 1210:	total: 21.1s	remaining: 13.8s
# 1211:	total: 21.1s	remaining: 13.7s
# 1212:	total: 21.1s	remaining: 13.7s
# 1213:	total: 21.2s	remaining: 13.7s
# 1214:	total: 21.2s	remaining: 13.7s
# 1215:	total: 21.2s	remaining: 13.7s
# 1216:	total: 21.2s	remaining: 13.7s
# 1217:	total: 21.3s	remaining: 13.6s
# 1218:	total: 21.3s	remaining: 13.6s
# 1219:	total: 21.3s	remaining: 13.6s
# 1220:	total: 21.3s	remaining: 13.6s
# 1221:	total: 21.3s	remaining: 13.6s
# 1222:	total: 21.3s	remaining: 13.6s
# 1223:	total: 21.4s	remaining: 13.5s
# 1224:	total: 21.4s	remaining: 13.5s
# 1225:	total: 21.4s	remaining: 13.5s
# 1226:	total: 21.4s	remaining: 13.5s
# 1227:	total: 21.4s	remaining: 13.5s
# 1228:	total: 21.5s	remaining: 13.5s
# 1229:	total: 21.5s	remaining: 13.4s
# 1230:	total: 21.5s	remaining: 13.4s
# 1231:	total: 21.5s	remaining: 13.4s
# 1232:	total: 21.5s	remaining: 13.4s
# 1233:	total: 21.6s	remaining: 13.4s
# 1234:	total: 21.6s	remaining: 13.4s
# 1235:	total: 21.6s	remaining: 13.3s
# 1236:	total: 21.6s	remaining: 13.3s
# 1237:	total: 21.6s	remaining: 13.3s
# 1238:	total: 21.6s	remaining: 13.3s
# 1239:	total: 21.7s	remaining: 13.3s
# 1240:	total: 21.7s	remaining: 13.3s
# 1241:	total: 21.7s	remaining: 13.3s
# 1242:	total: 21.7s	remaining: 13.2s
# 1243:	total: 21.7s	remaining: 13.2s
# 1244:	total: 21.8s	remaining: 13.2s
# 1245:	total: 21.8s	remaining: 13.2s
# 1246:	total: 21.8s	remaining: 13.2s
# 1247:	total: 21.8s	remaining: 13.2s
# 1248:	total: 21.8s	remaining: 13.1s
# 1249:	total: 21.9s	remaining: 13.1s
# 1250:	total: 21.9s	remaining: 13.1s
# 1251:	total: 21.9s	remaining: 13.1s
# 1252:	total: 21.9s	remaining: 13.1s
# 1253:	total: 21.9s	remaining: 13.1s
# 1254:	total: 22s	remaining: 13s
# 1255:	total: 22s	remaining: 13s
# 1256:	total: 22s	remaining: 13s
# 1257:	total: 22s	remaining: 13s
# 1258:	total: 22s	remaining: 13s
# 1259:	total: 22s	remaining: 12.9s
# 1260:	total: 22.1s	remaining: 12.9s
# 1261:	total: 22.1s	remaining: 12.9s
# 1262:	total: 22.1s	remaining: 12.9s
# 1263:	total: 22.1s	remaining: 12.9s
# 1264:	total: 22.1s	remaining: 12.9s
# 1265:	total: 22.2s	remaining: 12.8s
# 1266:	total: 22.2s	remaining: 12.8s
# 1267:	total: 22.2s	remaining: 12.8s
# 1268:	total: 22.2s	remaining: 12.8s
# 1269:	total: 22.2s	remaining: 12.8s
# 1270:	total: 22.2s	remaining: 12.8s
# 1271:	total: 22.3s	remaining: 12.7s
# 1272:	total: 22.3s	remaining: 12.7s
# 1273:	total: 22.3s	remaining: 12.7s
# 1274:	total: 22.3s	remaining: 12.7s
# 1275:	total: 22.3s	remaining: 12.7s
# 1276:	total: 22.4s	remaining: 12.7s
# 1277:	total: 22.4s	remaining: 12.6s
# 1278:	total: 22.4s	remaining: 12.6s
# 1279:	total: 22.4s	remaining: 12.6s
# 1280:	total: 22.4s	remaining: 12.6s
# 1281:	total: 22.5s	remaining: 12.6s
# 1282:	total: 22.5s	remaining: 12.6s
# 1283:	total: 22.5s	remaining: 12.5s
# 1284:	total: 22.5s	remaining: 12.5s
# 1285:	total: 22.5s	remaining: 12.5s
# 1286:	total: 22.6s	remaining: 12.5s
# 1287:	total: 22.6s	remaining: 12.5s
# 1288:	total: 22.6s	remaining: 12.5s
# 1289:	total: 22.6s	remaining: 12.4s
# 1290:	total: 22.6s	remaining: 12.4s
# 1291:	total: 22.6s	remaining: 12.4s
# 1292:	total: 22.7s	remaining: 12.4s
# 1293:	total: 22.7s	remaining: 12.4s
# 1294:	total: 22.7s	remaining: 12.4s
# 1295:	total: 22.7s	remaining: 12.3s
# 1296:	total: 22.7s	remaining: 12.3s
# 1297:	total: 22.8s	remaining: 12.3s
# 1298:	total: 22.8s	remaining: 12.3s
# 1299:	total: 22.8s	remaining: 12.3s
# 1300:	total: 22.8s	remaining: 12.3s
# 1301:	total: 22.8s	remaining: 12.2s
# 1302:	total: 22.9s	remaining: 12.2s
# 1303:	total: 22.9s	remaining: 12.2s
# 1304:	total: 22.9s	remaining: 12.2s
# 1305:	total: 22.9s	remaining: 12.2s
# 1306:	total: 23s	remaining: 12.2s
# 1307:	total: 23s	remaining: 12.2s
# 1308:	total: 23s	remaining: 12.1s
# 1309:	total: 23s	remaining: 12.1s
# 1310:	total: 23s	remaining: 12.1s
# 1311:	total: 23s	remaining: 12.1s
# 1312:	total: 23.1s	remaining: 12.1s
# 1313:	total: 23.1s	remaining: 12.1s
# 1314:	total: 23.1s	remaining: 12s
# 1315:	total: 23.1s	remaining: 12s
# 1316:	total: 23.1s	remaining: 12s
# 1317:	total: 23.1s	remaining: 12s
# 1318:	total: 23.2s	remaining: 12s
# 1319:	total: 23.2s	remaining: 11.9s
# 1320:	total: 23.2s	remaining: 11.9s
# 1321:	total: 23.2s	remaining: 11.9s
# 1322:	total: 23.2s	remaining: 11.9s
# 1323:	total: 23.2s	remaining: 11.9s
# 1324:	total: 23.3s	remaining: 11.9s
# 1325:	total: 23.3s	remaining: 11.8s
# 1326:	total: 23.3s	remaining: 11.8s
# 1327:	total: 23.3s	remaining: 11.8s
# 1328:	total: 23.3s	remaining: 11.8s
# 1329:	total: 23.3s	remaining: 11.8s
# 1330:	total: 23.4s	remaining: 11.7s
# 1331:	total: 23.4s	remaining: 11.7s
# 1332:	total: 23.4s	remaining: 11.7s
# 1333:	total: 23.4s	remaining: 11.7s
# 1334:	total: 23.4s	remaining: 11.7s
# 1335:	total: 23.4s	remaining: 11.7s
# 1336:	total: 23.5s	remaining: 11.6s
# 1337:	total: 23.5s	remaining: 11.6s
# 1338:	total: 23.5s	remaining: 11.6s
# 1339:	total: 23.5s	remaining: 11.6s
# 1340:	total: 23.5s	remaining: 11.6s
# 1341:	total: 23.5s	remaining: 11.5s
# 1342:	total: 23.6s	remaining: 11.5s
# 1343:	total: 23.6s	remaining: 11.5s
# 1344:	total: 23.6s	remaining: 11.5s
# 1345:	total: 23.6s	remaining: 11.5s
# 1346:	total: 23.6s	remaining: 11.5s
# 1347:	total: 23.6s	remaining: 11.4s
# 1348:	total: 23.7s	remaining: 11.4s
# 1349:	total: 23.7s	remaining: 11.4s
# 1350:	total: 23.7s	remaining: 11.4s
# 1351:	total: 23.7s	remaining: 11.4s
# 1352:	total: 23.7s	remaining: 11.3s
# 1353:	total: 23.7s	remaining: 11.3s
# 1354:	total: 23.8s	remaining: 11.3s
# 1355:	total: 23.8s	remaining: 11.3s
# 1356:	total: 23.8s	remaining: 11.3s
# 1357:	total: 23.8s	remaining: 11.3s
# 1358:	total: 23.8s	remaining: 11.2s
# 1359:	total: 23.8s	remaining: 11.2s
# 1360:	total: 23.9s	remaining: 11.2s
# 1361:	total: 23.9s	remaining: 11.2s
# 1362:	total: 23.9s	remaining: 11.2s
# 1363:	total: 23.9s	remaining: 11.1s
# 1364:	total: 23.9s	remaining: 11.1s
# 1365:	total: 23.9s	remaining: 11.1s
# 1366:	total: 24s	remaining: 11.1s
# 1367:	total: 24s	remaining: 11.1s
# 1368:	total: 24s	remaining: 11.1s
# 1369:	total: 24s	remaining: 11s
# 1370:	total: 24s	remaining: 11s
# 1371:	total: 24s	remaining: 11s
# 1372:	total: 24.1s	remaining: 11s
# 1373:	total: 24.1s	remaining: 11s
# 1374:	total: 24.1s	remaining: 11s
# 1375:	total: 24.1s	remaining: 10.9s
# ...
# 1555:	total: 26.3s	remaining: 7.5s
# 1556:	total: 26.3s	remaining: 7.48s
# 1557:	total: 26.3s	remaining: 7.46s
# 1558:	total: 26.3s	remaining: 7.44s
# 1559:	total: 26.3s	remaining: 7.43s
# 1560:	total: 26.4s	remaining: 7.41s
# 1561:	total: 26.4s	remaining: 7.4s
# 1562:	total: 26.4s	remaining: 7.38s
# 1563:	total: 26.4s	remaining: 7.36s
# 1564:	total: 26.4s	remaining: 7.35s
# 1565:	total: 26.4s	remaining: 7.33s
# 1566:	total: 26.5s	remaining: 7.31s
# 1567:	total: 26.5s	remaining: 7.3s
# 1568:	total: 26.5s	remaining: 7.28s
# 1569:	total: 26.5s	remaining: 7.26s
# 1570:	total: 26.5s	remaining: 7.25s
# 1571:	total: 26.6s	remaining: 7.23s
# 1572:	total: 26.6s	remaining: 7.21s
# 1573:	total: 26.6s	remaining: 7.2s
# 1574:	total: 26.6s	remaining: 7.18s
# 1575:	total: 26.6s	remaining: 7.16s
# 1576:	total: 26.6s	remaining: 7.15s
# 1577:	total: 26.7s	remaining: 7.13s
# 1578:	total: 26.7s	remaining: 7.12s
# 1579:	total: 26.7s	remaining: 7.1s
# 1580:	total: 26.7s	remaining: 7.08s
# 1581:	total: 26.7s	remaining: 7.07s
# 1582:	total: 26.8s	remaining: 7.05s
# 1583:	total: 26.8s	remaining: 7.03s
# 1584:	total: 26.8s	remaining: 7.02s
# 1585:	total: 26.8s	remaining: 7s
# 1586:	total: 26.8s	remaining: 6.98s
# 1587:	total: 26.9s	remaining: 6.97s
# 1588:	total: 26.9s	remaining: 6.95s
# 1589:	total: 26.9s	remaining: 6.93s
# 1590:	total: 26.9s	remaining: 6.92s
# 1591:	total: 26.9s	remaining: 6.9s
# 1592:	total: 26.9s	remaining: 6.88s
# 1593:	total: 27s	remaining: 6.87s
# 1594:	total: 27s	remaining: 6.85s
# 1595:	total: 27s	remaining: 6.83s
# 1596:	total: 27s	remaining: 6.82s
# 1597:	total: 27s	remaining: 6.8s
# 1598:	total: 27.1s	remaining: 6.78s
# 1599:	total: 27.1s	remaining: 6.77s
# 1600:	total: 27.1s	remaining: 6.75s
# 1601:	total: 27.1s	remaining: 6.73s
# 1602:	total: 27.1s	remaining: 6.72s
# 1603:	total: 27.1s	remaining: 6.7s
# 1604:	total: 27.2s	remaining: 6.68s
# 1605:	total: 27.2s	remaining: 6.67s
# 1606:	total: 27.2s	remaining: 6.65s
# 1607:	total: 27.2s	remaining: 6.63s
# 1608:	total: 27.2s	remaining: 6.62s
# 1609:	total: 27.2s	remaining: 6.6s
# 1610:	total: 27.3s	remaining: 6.58s
# 1611:	total: 27.3s	remaining: 6.57s
# 1612:	total: 27.3s	remaining: 6.55s
# 1613:	total: 27.3s	remaining: 6.53s
# 1614:	total: 27.3s	remaining: 6.51s
# 1615:	total: 27.3s	remaining: 6.5s
# 1616:	total: 27.4s	remaining: 6.48s
# 1617:	total: 27.4s	remaining: 6.46s
# 1618:	total: 27.4s	remaining: 6.45s
# 1619:	total: 27.4s	remaining: 6.43s
# 1620:	total: 27.4s	remaining: 6.41s
# 1621:	total: 27.5s	remaining: 6.4s
# 1622:	total: 27.5s	remaining: 6.38s
# 1623:	total: 27.5s	remaining: 6.36s
# 1624:	total: 27.5s	remaining: 6.35s
# 1625:	total: 27.5s	remaining: 6.33s
# 1626:	total: 27.5s	remaining: 6.31s
# 1627:	total: 27.6s	remaining: 6.3s
# 1628:	total: 27.6s	remaining: 6.28s
# 1629:	total: 27.6s	remaining: 6.26s
# 1630:	total: 27.6s	remaining: 6.25s
# 1631:	total: 27.6s	remaining: 6.23s
# 1632:	total: 27.6s	remaining: 6.21s
# 1633:	total: 27.7s	remaining: 6.2s
# 1634:	total: 27.7s	remaining: 6.18s
# 1635:	total: 27.7s	remaining: 6.16s
# 1636:	total: 27.7s	remaining: 6.15s
# 1637:	total: 27.7s	remaining: 6.13s
# 1638:	total: 27.8s	remaining: 6.11s
# 1639:	total: 27.8s	remaining: 6.1s
# 1640:	total: 27.8s	remaining: 6.08s
# 1641:	total: 27.8s	remaining: 6.06s
# 1642:	total: 27.8s	remaining: 6.04s
# 1643:	total: 27.8s	remaining: 6.03s
# 1644:	total: 27.9s	remaining: 6.01s
# 1645:	total: 27.9s	remaining: 6s
# 1646:	total: 27.9s	remaining: 5.98s
# 1647:	total: 27.9s	remaining: 5.96s
# 1648:	total: 27.9s	remaining: 5.95s
# 1649:	total: 27.9s	remaining: 5.93s
# 1650:	total: 28s	remaining: 5.91s
# 1651:	total: 28s	remaining: 5.89s
# 1652:	total: 28s	remaining: 5.88s
# 1653:	total: 28s	remaining: 5.86s
# 1654:	total: 28s	remaining: 5.84s
# 1655:	total: 28.1s	remaining: 5.83s
# 1656:	total: 28.1s	remaining: 5.81s
# 1657:	total: 28.1s	remaining: 5.79s
# 1658:	total: 28.1s	remaining: 5.78s
# 1659:	total: 28.1s	remaining: 5.76s
# 1660:	total: 28.1s	remaining: 5.74s
# 1661:	total: 28.1s	remaining: 5.72s
# 1662:	total: 28.2s	remaining: 5.71s
# 1663:	total: 28.2s	remaining: 5.69s
# 1664:	total: 28.2s	remaining: 5.67s
# 1665:	total: 28.2s	remaining: 5.66s
# 1666:	total: 28.2s	remaining: 5.64s
# 1667:	total: 28.3s	remaining: 5.62s
# 1668:	total: 28.3s	remaining: 5.61s
# 1669:	total: 28.3s	remaining: 5.59s
# 1670:	total: 28.3s	remaining: 5.57s
# 1671:	total: 28.3s	remaining: 5.55s
# 1672:	total: 28.3s	remaining: 5.54s
# 1673:	total: 28.3s	remaining: 5.52s
# 1674:	total: 28.4s	remaining: 5.5s
# 1675:	total: 28.4s	remaining: 5.49s
# 1676:	total: 28.4s	remaining: 5.47s
# 1677:	total: 28.4s	remaining: 5.45s
# 1678:	total: 28.4s	remaining: 5.43s
# 1679:	total: 28.4s	remaining: 5.42s
# 1680:	total: 28.5s	remaining: 5.4s
# 1681:	total: 28.5s	remaining: 5.38s
# 1682:	total: 28.5s	remaining: 5.37s
# 1683:	total: 28.5s	remaining: 5.35s
# 1684:	total: 28.5s	remaining: 5.33s
# 1685:	total: 28.5s	remaining: 5.32s
# 1686:	total: 28.6s	remaining: 5.3s
# 1687:	total: 28.6s	remaining: 5.28s
# 1688:	total: 28.6s	remaining: 5.26s
# 1689:	total: 28.6s	remaining: 5.25s
# 1690:	total: 28.6s	remaining: 5.23s
# 1691:	total: 28.6s	remaining: 5.21s
# 1692:	total: 28.7s	remaining: 5.2s
# 1693:	total: 28.7s	remaining: 5.18s
# 1694:	total: 28.7s	remaining: 5.16s
# 1695:	total: 28.7s	remaining: 5.15s
# 1696:	total: 28.7s	remaining: 5.13s
# 1697:	total: 28.7s	remaining: 5.11s
# 1698:	total: 28.8s	remaining: 5.09s
# 1699:	total: 28.8s	remaining: 5.08s
# 1700:	total: 28.8s	remaining: 5.06s
# 1701:	total: 28.8s	remaining: 5.04s
# 1702:	total: 28.8s	remaining: 5.03s
# 1703:	total: 28.8s	remaining: 5.01s
# 1704:	total: 28.9s	remaining: 4.99s
# 1705:	total: 28.9s	remaining: 4.98s
# 1706:	total: 28.9s	remaining: 4.96s
# 1707:	total: 28.9s	remaining: 4.94s
# 1708:	total: 28.9s	remaining: 4.92s
# 1709:	total: 28.9s	remaining: 4.91s
# 1710:	total: 29s	remaining: 4.89s
# 1711:	total: 29s	remaining: 4.88s
# 1712:	total: 29s	remaining: 4.86s
# 1713:	total: 29s	remaining: 4.84s
# 1714:	total: 29s	remaining: 4.82s
# 1715:	total: 29s	remaining: 4.81s
# 1716:	total: 29.1s	remaining: 4.79s
# 1717:	total: 29.1s	remaining: 4.77s
# 1718:	total: 29.1s	remaining: 4.75s
# 1719:	total: 29.1s	remaining: 4.74s
# 1720:	total: 29.1s	remaining: 4.72s
# 1721:	total: 29.1s	remaining: 4.7s
# 1722:	total: 29.2s	remaining: 4.69s
# 1723:	total: 29.2s	remaining: 4.67s
# 1724:	total: 29.2s	remaining: 4.65s
# 1725:	total: 29.2s	remaining: 4.63s
# 1726:	total: 29.2s	remaining: 4.62s
# 1727:	total: 29.2s	remaining: 4.6s
# 1728:	total: 29.2s	remaining: 4.58s
# 1729:	total: 29.3s	remaining: 4.57s
# 1730:	total: 29.3s	remaining: 4.55s
# 1731:	total: 29.3s	remaining: 4.53s
# 1732:	total: 29.3s	remaining: 4.51s
# 1733:	total: 29.3s	remaining: 4.5s
# 1734:	total: 29.3s	remaining: 4.48s
# 1735:	total: 29.4s	remaining: 4.46s
# 1736:	total: 29.4s	remaining: 4.45s
# 1737:	total: 29.4s	remaining: 4.43s
# 1738:	total: 29.4s	remaining: 4.41s
# 1739:	total: 29.4s	remaining: 4.4s
# 1740:	total: 29.4s	remaining: 4.38s
# 1741:	total: 29.5s	remaining: 4.36s
# 1742:	total: 29.5s	remaining: 4.35s
# 1743:	total: 29.5s	remaining: 4.33s
# 1744:	total: 29.5s	remaining: 4.31s
# 1745:	total: 29.5s	remaining: 4.29s
# 1746:	total: 29.5s	remaining: 4.28s
# 1747:	total: 29.6s	remaining: 4.26s
# 1748:	total: 29.6s	remaining: 4.25s
# 1749:	total: 29.6s	remaining: 4.23s
# 1750:	total: 29.6s	remaining: 4.21s
# 1751:	total: 29.6s	remaining: 4.2s
# 1752:	total: 29.7s	remaining: 4.18s
# 1753:	total: 29.7s	remaining: 4.16s
# 1754:	total: 29.7s	remaining: 4.14s
# 1755:	total: 29.7s	remaining: 4.13s
# 1756:	total: 29.7s	remaining: 4.11s
# 1757:	total: 29.7s	remaining: 4.09s
# 1758:	total: 29.8s	remaining: 4.08s
# 1759:	total: 29.8s	remaining: 4.06s
# 1760:	total: 29.8s	remaining: 4.04s
# 1761:	total: 29.8s	remaining: 4.03s
# 1762:	total: 29.8s	remaining: 4.01s
# 1763:	total: 29.8s	remaining: 3.99s
# 1764:	total: 29.9s	remaining: 3.98s
# 1765:	total: 29.9s	remaining: 3.96s
# 1766:	total: 29.9s	remaining: 3.94s
# 1767:	total: 29.9s	remaining: 3.92s
# 1768:	total: 29.9s	remaining: 3.91s
# 1769:	total: 29.9s	remaining: 3.89s
# 1770:	total: 30s	remaining: 3.87s
# 1771:	total: 30s	remaining: 3.86s
# 1772:	total: 30s	remaining: 3.84s
# 1773:	total: 30s	remaining: 3.83s
# 1774:	total: 30s	remaining: 3.81s
# 1775:	total: 30.1s	remaining: 3.79s
# 1776:	total: 30.1s	remaining: 3.77s
# 1777:	total: 30.1s	remaining: 3.76s
# 1778:	total: 30.1s	remaining: 3.74s
# 1779:	total: 30.1s	remaining: 3.72s
# 1780:	total: 30.1s	remaining: 3.71s
# 1781:	total: 30.2s	remaining: 3.69s
# 1782:	total: 30.2s	remaining: 3.67s
# 1783:	total: 30.2s	remaining: 3.66s
# 1784:	total: 30.2s	remaining: 3.64s
# 1785:	total: 30.2s	remaining: 3.62s
# 1786:	total: 30.3s	remaining: 3.61s
# 1787:	total: 30.3s	remaining: 3.59s
# 1788:	total: 30.3s	remaining: 3.57s
# 1789:	total: 30.3s	remaining: 3.56s
# 1790:	total: 30.3s	remaining: 3.54s
# 1791:	total: 30.3s	remaining: 3.52s
# 1792:	total: 30.4s	remaining: 3.5s
# 1793:	total: 30.4s	remaining: 3.49s
# 1794:	total: 30.4s	remaining: 3.47s
# 1795:	total: 30.4s	remaining: 3.45s
# 1796:	total: 30.4s	remaining: 3.44s
# 1797:	total: 30.5s	remaining: 3.42s
# 1798:	total: 30.5s	remaining: 3.4s
# 1799:	total: 30.5s	remaining: 3.39s
# 1800:	total: 30.5s	remaining: 3.37s
# 1801:	total: 30.5s	remaining: 3.35s
# 1802:	total: 30.5s	remaining: 3.34s
# 1803:	total: 30.6s	remaining: 3.32s
# 1804:	total: 30.6s	remaining: 3.3s
# 1805:	total: 30.6s	remaining: 3.29s
# 1806:	total: 30.6s	remaining: 3.27s
# 1807:	total: 30.6s	remaining: 3.25s
# 1808:	total: 30.6s	remaining: 3.23s
# 1809:	total: 30.7s	remaining: 3.22s
# 1810:	total: 30.7s	remaining: 3.2s
# 1811:	total: 30.7s	remaining: 3.18s
# 1812:	total: 30.7s	remaining: 3.17s
# 1813:	total: 30.7s	remaining: 3.15s
# 1814:	total: 30.7s	remaining: 3.13s
# 1815:	total: 30.8s	remaining: 3.12s
# 1816:	total: 30.8s	remaining: 3.1s
# 1817:	total: 30.8s	remaining: 3.08s
# 1818:	total: 30.8s	remaining: 3.07s
# 1819:	total: 30.8s	remaining: 3.05s
# 1820:	total: 30.8s	remaining: 3.03s
# 1821:	total: 30.9s	remaining: 3.02s
# 1822:	total: 30.9s	remaining: 3s
# 1823:	total: 30.9s	remaining: 2.98s
# 1824:	total: 30.9s	remaining: 2.96s
# 1825:	total: 30.9s	remaining: 2.95s
# 1826:	total: 30.9s	remaining: 2.93s
# 1827:	total: 31s	remaining: 2.91s
# 1828:	total: 31s	remaining: 2.9s
# 1829:	total: 31s	remaining: 2.88s
# 1830:	total: 31s	remaining: 2.86s
# 1831:	total: 31s	remaining: 2.85s
# 1832:	total: 31s	remaining: 2.83s
# 1833:	total: 31.1s	remaining: 2.81s
# 1834:	total: 31.1s	remaining: 2.79s
# 1835:	total: 31.1s	remaining: 2.78s
# 1836:	total: 31.1s	remaining: 2.76s
# 1837:	total: 31.1s	remaining: 2.74s
# 1838:	total: 31.2s	remaining: 2.73s
# 1839:	total: 31.2s	remaining: 2.71s
# 1840:	total: 31.2s	remaining: 2.69s
# 1841:	total: 31.2s	remaining: 2.68s
# 1842:	total: 31.2s	remaining: 2.66s
# 1843:	total: 31.2s	remaining: 2.64s
# 1844:	total: 31.3s	remaining: 2.63s
# 1845:	total: 31.3s	remaining: 2.61s
# 1846:	total: 31.3s	remaining: 2.59s
# 1847:	total: 31.3s	remaining: 2.58s
# 1848:	total: 31.3s	remaining: 2.56s
# 1849:	total: 31.3s	remaining: 2.54s
# 1850:	total: 31.4s	remaining: 2.52s
# 1851:	total: 31.4s	remaining: 2.51s
# 1852:	total: 31.4s	remaining: 2.49s
# 1853:	total: 31.4s	remaining: 2.47s
# 1854:	total: 31.4s	remaining: 2.46s
# 1855:	total: 31.4s	remaining: 2.44s
# 1856:	total: 31.5s	remaining: 2.42s
# 1857:	total: 31.5s	remaining: 2.4s
# 1858:	total: 31.5s	remaining: 2.39s
# 1859:	total: 31.5s	remaining: 2.37s
# 1860:	total: 31.5s	remaining: 2.35s
# 1861:	total: 31.5s	remaining: 2.34s
# 1862:	total: 31.6s	remaining: 2.32s
# 1863:	total: 31.6s	remaining: 2.3s
# 1864:	total: 31.6s	remaining: 2.29s
# 1865:	total: 31.6s	remaining: 2.27s
# 1866:	total: 31.6s	remaining: 2.25s
# 1867:	total: 31.6s	remaining: 2.23s
# 1868:	total: 31.7s	remaining: 2.22s
# 1869:	total: 31.7s	remaining: 2.2s
# 1870:	total: 31.7s	remaining: 2.18s
# 1871:	total: 31.7s	remaining: 2.17s
# 1872:	total: 31.7s	remaining: 2.15s
# 1873:	total: 31.7s	remaining: 2.13s
# 1874:	total: 31.8s	remaining: 2.12s
# 1875:	total: 31.8s	remaining: 2.1s
# 1876:	total: 31.8s	remaining: 2.08s
# 1877:	total: 31.8s	remaining: 2.07s
# 1878:	total: 31.8s	remaining: 2.05s
# 1879:	total: 31.9s	remaining: 2.03s
# 1880:	total: 31.9s	remaining: 2.02s
# 1881:	total: 31.9s	remaining: 2s
# 1882:	total: 31.9s	remaining: 1.98s
# 1883:	total: 31.9s	remaining: 1.97s
# 1884:	total: 31.9s	remaining: 1.95s
# 1885:	total: 32s	remaining: 1.93s
# 1886:	total: 32s	remaining: 1.91s
# 1887:	total: 32s	remaining: 1.9s
# 1888:	total: 32s	remaining: 1.88s
# 1889:	total: 32s	remaining: 1.86s
# 1890:	total: 32s	remaining: 1.85s
# 1891:	total: 32.1s	remaining: 1.83s
# 1892:	total: 32.1s	remaining: 1.81s
# 1893:	total: 32.1s	remaining: 1.8s
# 1894:	total: 32.1s	remaining: 1.78s
# 1895:	total: 32.1s	remaining: 1.76s
# 1896:	total: 32.2s	remaining: 1.75s
# 1897:	total: 32.2s	remaining: 1.73s
# 1898:	total: 32.2s	remaining: 1.71s
# 1899:	total: 32.2s	remaining: 1.69s
# 1900:	total: 32.2s	remaining: 1.68s
# 1901:	total: 32.2s	remaining: 1.66s
# 1902:	total: 32.3s	remaining: 1.64s
# 1903:	total: 32.3s	remaining: 1.63s
# 1904:	total: 32.3s	remaining: 1.61s
# 1905:	total: 32.3s	remaining: 1.59s
# 1906:	total: 32.3s	remaining: 1.58s
# 1907:	total: 32.3s	remaining: 1.56s
# 1908:	total: 32.4s	remaining: 1.54s
# 1909:	total: 32.4s	remaining: 1.52s
# 1910:	total: 32.4s	remaining: 1.51s
# 1911:	total: 32.4s	remaining: 1.49s
# 1912:	total: 32.4s	remaining: 1.47s
# 1913:	total: 32.4s	remaining: 1.46s
# 1914:	total: 32.5s	remaining: 1.44s
# 1915:	total: 32.5s	remaining: 1.42s
# 1916:	total: 32.5s	remaining: 1.41s
# 1917:	total: 32.5s	remaining: 1.39s
# 1918:	total: 32.5s	remaining: 1.37s
# 1919:	total: 32.5s	remaining: 1.35s
# 1920:	total: 32.6s	remaining: 1.34s
# 1921:	total: 32.6s	remaining: 1.32s
# 1922:	total: 32.6s	remaining: 1.3s
# 1923:	total: 32.6s	remaining: 1.29s
# 1924:	total: 32.6s	remaining: 1.27s
# 1925:	total: 32.6s	remaining: 1.25s
# 1926:	total: 32.7s	remaining: 1.24s
# 1927:	total: 32.7s	remaining: 1.22s
# 1928:	total: 32.7s	remaining: 1.2s
# 1929:	total: 32.7s	remaining: 1.19s
# 1930:	total: 32.7s	remaining: 1.17s
# 1931:	total: 32.8s	remaining: 1.15s
# 1932:	total: 32.8s	remaining: 1.14s
# 1933:	total: 32.8s	remaining: 1.12s
# 1934:	total: 32.8s	remaining: 1.1s
# 1935:	total: 32.8s	remaining: 1.08s
# 1936:	total: 32.8s	remaining: 1.07s
# 1937:	total: 32.9s	remaining: 1.05s
# 1938:	total: 32.9s	remaining: 1.03s
# 1939:	total: 32.9s	remaining: 1.02s
# 1940:	total: 32.9s	remaining: 1s
# 1941:	total: 32.9s	remaining: 983ms
# 1942:	total: 32.9s	remaining: 966ms
# 1943:	total: 33s	remaining: 949ms
# 1944:	total: 33s	remaining: 932ms
# 1945:	total: 33s	remaining: 915ms
# 1946:	total: 33s	remaining: 898ms
# 1947:	total: 33s	remaining: 882ms
# 1948:	total: 33s	remaining: 865ms
# 1949:	total: 33.1s	remaining: 848ms
# 1950:	total: 33.1s	remaining: 831ms
# 1951:	total: 33.1s	remaining: 814ms
# 1952:	total: 33.1s	remaining: 797ms
# 1953:	total: 33.1s	remaining: 780ms
# 1954:	total: 33.2s	remaining: 763ms
# 1955:	total: 33.2s	remaining: 746ms
# 1956:	total: 33.2s	remaining: 729ms
# 1957:	total: 33.2s	remaining: 712ms
# 1958:	total: 33.2s	remaining: 695ms
# 1959:	total: 33.2s	remaining: 678ms
# 1960:	total: 33.3s	remaining: 661ms
# 1961:	total: 33.3s	remaining: 644ms
# 1962:	total: 33.3s	remaining: 627ms
# 1963:	total: 33.3s	remaining: 611ms
# 1964:	total: 33.3s	remaining: 594ms
# 1965:	total: 33.3s	remaining: 577ms
# 1966:	total: 33.4s	remaining: 560ms
# 1967:	total: 33.4s	remaining: 543ms
# 1968:	total: 33.4s	remaining: 526ms
# 1969:	total: 33.4s	remaining: 509ms
# 1970:	total: 33.4s	remaining: 492ms
# 1971:	total: 33.4s	remaining: 475ms
# 1972:	total: 33.5s	remaining: 458ms
# 1973:	total: 33.5s	remaining: 441ms
# 1974:	total: 33.5s	remaining: 424ms
# 1975:	total: 33.5s	remaining: 407ms
# 1976:	total: 33.5s	remaining: 390ms
# 1977:	total: 33.6s	remaining: 373ms
# 1978:	total: 33.6s	remaining: 356ms
# 1979:	total: 33.6s	remaining: 339ms
# 1980:	total: 33.6s	remaining: 322ms
# 1981:	total: 33.6s	remaining: 305ms
# 1982:	total: 33.6s	remaining: 288ms
# 1983:	total: 33.7s	remaining: 271ms
# 1984:	total: 33.7s	remaining: 254ms
# 1985:	total: 33.7s	remaining: 238ms
# 1986:	total: 33.7s	remaining: 221ms
# 1987:	total: 33.7s	remaining: 204ms
# 1988:	total: 33.7s	remaining: 187ms
# 1989:	total: 33.8s	remaining: 170ms
# 1990:	total: 33.8s	remaining: 153ms
# 1991:	total: 33.8s	remaining: 136ms
# 1992:	total: 33.8s	remaining: 119ms
# 1993:	total: 33.8s	remaining: 102ms
# 1994:	total: 33.8s	remaining: 84.8ms
# 1995:	total: 33.9s	remaining: 67.9ms
# 1996:	total: 33.9s	remaining: 50.9ms
# 1997:	total: 33.9s	remaining: 33.9ms
# 1998:	total: 33.9s	remaining: 17ms
# 1999:	total: 33.9s	remaining: 0us
# Cross-validation scores:[0.86212082 0.86431211 0.86603076 0.86031023 0.8641344 ]

# %%
print('Average cross-validation score: {}'.format(scores.mean()))
# Out:
# Average cross-validation score: 0.8633816657612394

# %%
Average cross-validation score: 0.8632871444807307
The mean accuracy score of cross validation is almost same like original model accuracy score which is 0.8647050735597415. So, accuracy of model may not be improved using Cross-validation.

# %%
#`(iii) Random Forest`

from sklearn.ensemble import RandomForestClassifier

# %%
#Model Training:

start_time = time.time()
classifier_rf=RandomForestClassifier()
classifier_rf.fit(X_train,y_train)
end_time = time.time()

# %%
print("Time Taken to train: {}".format(end_time - start_time))
# Out:
# Time Taken to train: 22.947422742843628

# %%
#Model Testing:
y_pred_rf = classifier_rf.predict(X_test)

# %%
print("Accuracy Score: {}".format(accuracy_score(y_test,y_pred_rf)))
# Out:
# Accuracy Score: 0.8551491819056786

# %%
#Checking for Overfitting and Under Fitting:
print("Train Data Score: {}".format(classifier_rf.score(X_train, y_train)))
print("Test Data Score: {}".format(classifier_rf.score(X_test, y_test)))
# Out:
# Train Data Score: 0.9999914065722535
# Test Data Score: 0.8551491819056786

# %%
Accuracy score for Training Set is almost 1 or 100%, which is quite uncommon. And testing accuracy is 0.85. It seems like model is overfitting, because the generalization for unseen data is not that accurate, when compared with seen data and difference between training - testing accuracy is not minimum.

# %%
Results and Conclusion:
Best Models in terms of accuracy (In my Experiment):

1) Cat Boost Model
2) Logistic Regression
3) Random Forest

Best Models in terms of Computation Time (In my Experiment):

1) Logistic Regression
2) Random Forest
3) Cat Boost Model
Conclusion:

The accuracy score of Cat Boost Model is high when compared with accuracy scores of Logistic Regression and Random Forest. But cat Boost model consumes lot of time to train the model.

In terms of computation time and Accuracy score, logistic Regression model is doing job.

# %%
Saving Classifier Object into Pickle File:

# %%
with open('logreg.pkl', 'wb') as file:
    pickle.dump(classifier_logreg, file)

# %%
with open('catboostclassifier.pkl', 'wb') as file:
    pickle.dump(cat_classifier, file)
